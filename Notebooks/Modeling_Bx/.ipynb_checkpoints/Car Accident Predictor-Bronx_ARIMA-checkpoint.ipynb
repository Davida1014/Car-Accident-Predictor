# %%
# Import packages
import warnings
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.tsa.arima_model import ARIMA
import statsmodels.api as sm
from matplotlib.pylab import rcParams
import itertools
import numpy as np
import tqdm
from tqdm._tqdm_notebook import tqdm_notebook

# Preferred settings
warnings.simplefilter("ignore")
# Out:
# <ipython-input-1-7c1c9c0627ad>:14: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.*` instead of `tqdm._tqdm_notebook.*`
#   from tqdm._tqdm_notebook import tqdm_notebook

# %%
# Import saved data
df_TS = pd.read_csv('Data/df_TS.csv')

# Set date column to datetime object
df_TS['Date'] = pd.to_datetime(df_TS['Date'])

# Set date column as index
df_TS.set_index('Date', inplace=True)

# %% [markdown]
# # Prepare Data

# %%
# Create df of only Bronx data, remove columns unhelpful to time series model 
df_bx = df_TS.drop(columns = ['Injuries', 'Deaths','Accidents_Bkln', 'Accidents_Man', 'Accidents_Qns', 'Accidents_SI',
                               'Accidents_Total'])

# Only use pre-COVID data for time series modeling
df_bx = df_bx.loc[:'2020-3-13']

# %%
# Visualize data, including 30-day rolling mean and standard deviation

roll_mean = df_bx['Accidents_Bx'].rolling(window=30, center=False).mean()
roll_std = df_bx['Accidents_Bx'].rolling(window=30, center=False).std()

plt.plot(df_bx['Accidents_Bx'],color='mediumseagreen', label='Original')
plt.plot(roll_mean, color='mediumblue', label='Rolling Mean')
plt.plot(roll_std, color='orangered', label = 'Rolling Std')
plt.legend(loc='best')
plt.title('Rolling Mean & Standard Deviation')
plt.xlabel('Year')
plt.ylabel('Accidents')
plt.show(block=False)

# Dickey-Fuller test
test = adfuller(df_bx['Accidents_Bx'][1:-1])
dfoutput = pd.Series(test[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
dfoutput
# Out:
# Test Statistic                   -2.067355
# p-value                           0.257842
# #Lags Used                       27.000000
# Number of Observations Used    2783.000000
# dtype: float64

# %% [markdown]
# Based on the above visualization and Dickey-Fuller p-value, we see that this data is not stationary. Before modeling, we will difference the data to see if it can achieve stationarity.

# %% [markdown]
# **Differencing**

# %%
# Difference data
diff_bx = df_bx['Accidents_Bx'].diff()

# Plot differenced data
plt.plot(diff_bx, color='palevioletred', label='Differenced Rolling Weekly Mean')
plt.title('Differenced Weekly Mean, Bronx')
plt.xlabel('Year')
plt.ylabel('Accidents')
plt.show(block=False)

# Dickey-Fuller test
test = adfuller(diff_bx[1:-1])
dfoutput = pd.Series(test[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
dfoutput
# Out:
# Test Statistic                -1.845132e+01
# p-value                        2.153593e-30
# #Lags Used                     2.600000e+01
# Number of Observations Used    2.784000e+03
# dtype: float64

# %% [markdown]
# We see above the differencing once achieved stationarity. We therefore expect our best ARIMA models to have a d value of at least 1.

# %% [markdown]
# # ARIMA Models

# %% [markdown]
# ## Baseline Model: ARIMA with no Exogenous Variables

# %% [markdown]
# **ACF, PACF**

# %%
# ACF
plot_acf(df_bx['Accidents_Bx'], alpha=.05);

# PACF
plot_pacf(df_bx['Accidents_Bx'], alpha=.05, lags=20);

# %% [markdown]
# Based on the above ACF and PACF, when instantiating an ARIMA model, we would expect a relatively large number of MA and AR terms due to the larger number of significant ACF and PACF points.

# %% [markdown]
# **Train-Test Split**

# %%
# Determine split point for 90%/10% train-test split
split_point = int(len(df_bx) * 0.9)
df_bx.iloc[split_point]
# Out:
# Accidents_Bx         102
# Season            Spring
# Day of Week     Thursday
# Weekend                0
# Holiday                0
# Name: 2019-06-06 00:00:00, dtype: object

# %%
# Train-test split
# Based on the above, 2019-06-06 will be the split point for our train and test sets

X = df_bx.index
y = df_bx['Accidents_Bx']

train = df_bx.loc[:'2019-06-06']
test = df_bx.loc['2019-06-06':]

X_train, X_test = train.index , test.index
y_train, y_test = train['Accidents_Bx'] , test['Accidents_Bx']

# %% [markdown]
# **Grid Search**

# %%
# Determine best parameters for ARIMA model

# Define the p, d, and q parameters to take any value between 0 and 4
p = d = q = range(0,4)

# Generate all different combinations of p, d, and q triplets
pdq = list(itertools.product(p, d, q))

# Run a grid with pdq parameters calculated to see corresponding AIC scores
ans_ARIMA = []
for comb in pdq:
    try:
        mod = ARIMA(y_train, order=comb)
        output = mod.fit()
        ans_ARIMA.append([comb, output.aic])
        print('ARIMA {} : AIC Calculated ={}'.format(comb,output.aic))
    except:
        continue
# Out:
# ARIMA (0, 0, 0) : AIC Calculated =23108.4221964567
# ARIMA (0, 0, 1) : AIC Calculated =22339.87709957248
# ARIMA (0, 0, 2) : AIC Calculated =22175.807449196338
# ARIMA (0, 0, 3) : AIC Calculated =21997.468839741683
# ARIMA (0, 1, 0) : AIC Calculated =22443.9617616347
# ARIMA (0, 1, 1) : AIC Calculated =21086.581141232782
# ARIMA (0, 1, 2) : AIC Calculated =21050.860308806197
# ARIMA (0, 1, 3) : AIC Calculated =21027.449645648285
# ARIMA (0, 2, 0) : AIC Calculated =25008.460204045292
# ARIMA (0, 2, 1) : AIC Calculated =22445.935503691362
# ARIMA (0, 2, 2) : AIC Calculated =21096.01495380269
# ARIMA (0, 2, 3) : AIC Calculated =21061.69804665206
# ARIMA (1, 0, 0) : AIC Calculated =21912.936056308787
# ARIMA (1, 0, 1) : AIC Calculated =21096.986520742583
# ARIMA (1, 0, 2) : AIC Calculated =21061.917119887257
# ARIMA (1, 0, 3) : AIC Calculated =21037.946799377187
# ARIMA (1, 1, 0) : AIC Calculated =22045.430874092985
# ARIMA (1, 1, 1) : AIC Calculated =21059.79309254201
# ARIMA (1, 1, 2) : AIC Calculated =21036.497454021493
# ARIMA (1, 1, 3) : AIC Calculated =21029.449634189536
# ARIMA (1, 2, 0) : AIC Calculated =24024.27059278368
# ARIMA (1, 2, 3) : AIC Calculated =21047.760212180838
# ARIMA (2, 0, 0) : AIC Calculated =21771.078641172007
# ARIMA (2, 0, 1) : AIC Calculated =21070.785965308594
# ARIMA (2, 0, 2) : AIC Calculated =21047.396018516505
# ARIMA (2, 0, 3) : AIC Calculated =21039.94472220318
# ARIMA (2, 1, 0) : AIC Calculated =21609.622523400853
# ARIMA (2, 1, 1) : AIC Calculated =21027.752382119506
# ARIMA (2, 1, 2) : AIC Calculated =21025.649468294832
# ARIMA (2, 1, 3) : AIC Calculated =20752.47119574098
# ARIMA (2, 2, 0) : AIC Calculated =23242.28484967224
# ARIMA (3, 0, 0) : AIC Calculated =21487.327477882405
# ARIMA (3, 0, 1) : AIC Calculated =21038.053375049352
# ARIMA (3, 0, 2) : AIC Calculated =21036.091192297878
# ARIMA (3, 1, 0) : AIC Calculated =21433.376313923796
# ARIMA (3, 1, 1) : AIC Calculated =21021.40497279513
# ARIMA (3, 1, 2) : AIC Calculated =21022.919014916853
# ARIMA (3, 1, 3) : AIC Calculated =20698.159856455764
# ARIMA (3, 2, 0) : AIC Calculated =22627.023504733534

# %%
# Find parameters with minimal AIC value
df_AIC = pd.DataFrame(ans_ARIMA, columns=['pdq', 'aic'])
df_AIC.sort_values(by='aic', ascending=True, inplace=True)
df_AIC[:10]
# Out:
#           pdq           aic
# 37  (3, 1, 3)  20698.159856
# 29  (2, 1, 3)  20752.471196
# 35  (3, 1, 1)  21021.404973
# 36  (3, 1, 2)  21022.919015
# 28  (2, 1, 2)  21025.649468
# 7   (0, 1, 3)  21027.449646
# 27  (2, 1, 1)  21027.752382
# 19  (1, 1, 3)  21029.449634
# 33  (3, 0, 2)  21036.091192
# 18  (1, 1, 2)  21036.497454

# %% [markdown]
# **Narrowing Down Parameters**

# %% [markdown]
# Observe lowest 10 AIC score parameter values to determine best model. Make sure p values are significant, and observe RMSEs to determind best overall model.

# %%
for pdq in df_AIC['pdq'][:10]:
    mod = ARIMA(y_train[:-1], order=pdq)
    mod_fit = mod.fit()
    print(mod_fit.summary())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:         D.Accidents_Bx   No. Observations:                 2530
# Model:                 ARIMA(3, 1, 3)   Log Likelihood              -10337.377
# Method:                       css-mle   S.D. of innovations             14.375
# Date:                Thu, 18 Feb 2021   AIC                          20690.754
# Time:                        10:23:57   BIC                          20737.442
# Sample:                    07-02-2012   HQIC                         20707.693
#                          - 06-05-2019
# ========================================================================================
#                            coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0149      0.014      1.101      0.271      -0.012       0.041
# ar.L1.D.Accidents_Bx    -0.2851      0.004    -70.150      0.000      -0.293      -0.277
# ar.L2.D.Accidents_Bx    -0.9286      0.002   -515.634      0.000      -0.932      -0.925
# ar.L3.D.Accidents_Bx     0.1600      0.004     39.578      0.000       0.152       0.168
# ma.L1.D.Accidents_Bx    -0.5164      0.007    -78.030      0.000      -0.529      -0.503
# ma.L2.D.Accidents_Bx     0.5665      0.004    144.271      0.000       0.559       0.574
# ma.L3.D.Accidents_Bx    -0.9538      0.006   -147.510      0.000      -0.967      -0.941
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -0.2226           -0.9750j            1.0001           -0.2857
# AR.2           -0.2226           +0.9750j            1.0001            0.2857
# AR.3            6.2489           -0.0000j            6.2489           -0.0000
# MA.1           -0.2236           -0.9782j            1.0035           -0.2858
# MA.2           -0.2236           +0.9782j            1.0035            0.2858
# MA.3            1.0411           -0.0000j            1.0411           -0.0000
# -----------------------------------------------------------------------------
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:         D.Accidents_Bx   No. Observations:                 2530
# Model:                 ARIMA(2, 1, 3)   Log Likelihood              -10365.422
# Method:                       css-mle   S.D. of innovations             14.535
# Date:                Thu, 18 Feb 2021   AIC                          20744.844
# Time:                        10:24:02   BIC                          20785.696
# Sample:                    07-02-2012   HQIC                         20759.666
#                          - 06-05-2019
# ========================================================================================
#                            coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0153      0.018      0.855      0.393      -0.020       0.050
# ar.L1.D.Accidents_Bx    -0.4452      0.000  -1123.818      0.000      -0.446      -0.444
# ar.L2.D.Accidents_Bx    -0.9999      0.000  -6649.170      0.000      -1.000      -1.000
# ma.L1.D.Accidents_Bx    -0.4916      0.010    -51.321      0.000      -0.510      -0.473
# ma.L2.D.Accidents_Bx     0.5747      0.005    112.657      0.000       0.565       0.585
# ma.L3.D.Accidents_Bx    -0.9326      0.010    -97.774      0.000      -0.951      -0.914
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -0.2226           -0.9750j            1.0001           -0.2857
# AR.2           -0.2226           +0.9750j            1.0001            0.2857
# MA.1           -0.2247           -0.9776j            1.0031           -0.2860
# MA.2           -0.2247           +0.9776j            1.0031            0.2860
# MA.3            1.0657           -0.0000j            1.0657           -0.0000
# -----------------------------------------------------------------------------
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:         D.Accidents_Bx   No. Observations:                 2530
# Model:                 ARIMA(3, 1, 1)   Log Likelihood              -10500.957
# Method:                       css-mle   S.D. of innovations             15.351
# Date:                Thu, 18 Feb 2021   AIC                          21013.915
# Time:                        10:24:03   BIC                          21048.931
# Sample:                    07-02-2012   HQIC                         21026.619
#                          - 06-05-2019
# ========================================================================================
#                            coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0149      0.014      1.053      0.292      -0.013       0.043
# ar.L1.D.Accidents_Bx     0.1258      0.021      5.871      0.000       0.084       0.168
# ar.L2.D.Accidents_Bx    -0.1221      0.021     -5.891      0.000      -0.163      -0.081
# ar.L3.D.Accidents_Bx     0.0614      0.021      2.896      0.004       0.020       0.103
# ma.L1.D.Accidents_Bx    -0.9570      0.008   -124.167      0.000      -0.972      -0.942
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -0.5354           -2.2446j            2.3076           -0.2873
# AR.2           -0.5354           +2.2446j            2.3076            0.2873
# AR.3            3.0594           -0.0000j            3.0594           -0.0000
# MA.1            1.0450           +0.0000j            1.0450            0.0000
# -----------------------------------------------------------------------------
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:         D.Accidents_Bx   No. Observations:                 2530
# Model:                 ARIMA(3, 1, 2)   Log Likelihood              -10500.708
# Method:                       css-mle   S.D. of innovations             15.349
# Date:                Thu, 18 Feb 2021   AIC                          21015.417
# Time:                        10:24:04   BIC                          21056.268
# Sample:                    07-02-2012   HQIC                         21030.239
#                          - 06-05-2019
# ========================================================================================
#                            coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0149      0.014      1.067      0.286      -0.012       0.042
# ar.L1.D.Accidents_Bx     0.2503      0.195      1.284      0.199      -0.132       0.632
# ar.L2.D.Accidents_Bx    -0.1360      0.030     -4.516      0.000      -0.195      -0.077
# ar.L3.D.Accidents_Bx     0.0777      0.031      2.548      0.011       0.018       0.138
# ma.L1.D.Accidents_Bx    -1.0818      0.195     -5.553      0.000      -1.464      -0.700
# ma.L2.D.Accidents_Bx     0.1184      0.185      0.640      0.522      -0.244       0.481
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -0.3800           -2.2320j            2.2642           -0.2768
# AR.2           -0.3800           +2.2320j            2.2642            0.2768
# AR.3            2.5091           -0.0000j            2.5091           -0.0000
# MA.1            1.0436           +0.0000j            1.0436            0.0000
# MA.2            8.0945           +0.0000j            8.0945            0.0000
# -----------------------------------------------------------------------------
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:         D.Accidents_Bx   No. Observations:                 2530
# Model:                 ARIMA(2, 1, 2)   Log Likelihood              -10503.076
# Method:                       css-mle   S.D. of innovations             15.364
# Date:                Thu, 18 Feb 2021   AIC                          21018.152
# Time:                        10:24:05   BIC                          21053.168
# Sample:                    07-02-2012   HQIC                         21030.857
#                          - 06-05-2019
# ========================================================================================
#                            coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0151      0.015      0.988      0.323      -0.015       0.045
# ar.L1.D.Accidents_Bx    -0.0986      0.097     -1.021      0.307      -0.288       0.091
# ar.L2.D.Accidents_Bx    -0.1024      0.025     -4.093      0.000      -0.151      -0.053
# ma.L1.D.Accidents_Bx    -0.7355      0.096     -7.687      0.000      -0.923      -0.548
# ma.L2.D.Accidents_Bx    -0.2050      0.093     -2.215      0.027      -0.386      -0.024
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -0.4813           -3.0876j            3.1249           -0.2746
# AR.2           -0.4813           +3.0876j            3.1249            0.2746
# MA.1            1.0515           +0.0000j            1.0515            0.0000
# MA.2           -4.6399           +0.0000j            4.6399            0.5000
# -----------------------------------------------------------------------------
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:         D.Accidents_Bx   No. Observations:                 2530
# Model:                 ARIMA(0, 1, 3)   Log Likelihood              -10504.980
# Method:                       css-mle   S.D. of innovations             15.375
# Date:                Thu, 18 Feb 2021   AIC                          21019.960
# Time:                        10:24:06   BIC                          21049.140
# Sample:                    07-02-2012   HQIC                         21030.548
#                          - 06-05-2019
# ========================================================================================
#                            coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0150      0.015      1.001      0.317      -0.014       0.044
# ma.L1.D.Accidents_Bx    -0.8335      0.020    -42.384      0.000      -0.872      -0.795
# ma.L2.D.Accidents_Bx    -0.2120      0.024     -8.726      0.000      -0.260      -0.164
# ma.L3.D.Accidents_Bx     0.0943      0.019      5.039      0.000       0.058       0.131
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# MA.1            1.0502           +0.0000j            1.0502            0.0000
# MA.2           -2.6351           +0.0000j            2.6351            0.5000
# MA.3            3.8338           +0.0000j            3.8338            0.0000
# -----------------------------------------------------------------------------
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:         D.Accidents_Bx   No. Observations:                 2530
# Model:                 ARIMA(2, 1, 1)   Log Likelihood              -10505.118
# Method:                       css-mle   S.D. of innovations             15.376
# Date:                Thu, 18 Feb 2021   AIC                          21020.236
# Time:                        10:24:06   BIC                          21049.416
# Sample:                    07-02-2012   HQIC                         21030.823
#                          - 06-05-2019
# ========================================================================================
#                            coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0151      0.016      0.956      0.339      -0.016       0.046
# ar.L1.D.Accidents_Bx     0.1104      0.021      5.205      0.000       0.069       0.152
# ar.L2.D.Accidents_Bx    -0.1227      0.021     -5.833      0.000      -0.164      -0.081
# ma.L1.D.Accidents_Bx    -0.9480      0.009   -107.677      0.000      -0.965      -0.931
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            0.4499           -2.8194j            2.8551           -0.2248
# AR.2            0.4499           +2.8194j            2.8551            0.2248
# MA.1            1.0548           +0.0000j            1.0548            0.0000
# -----------------------------------------------------------------------------
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:         D.Accidents_Bx   No. Observations:                 2530
# Model:                 ARIMA(1, 1, 3)   Log Likelihood              -10504.980
# Method:                       css-mle   S.D. of innovations             15.375
# Date:                Thu, 18 Feb 2021   AIC                          21021.960
# Time:                        10:24:07   BIC                          21056.976
# Sample:                    07-02-2012   HQIC                         21034.665
#                          - 06-05-2019
# ========================================================================================
#                            coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0150      0.015      1.001      0.317      -0.014       0.044
# ar.L1.D.Accidents_Bx     0.0008      0.134      0.006      0.995      -0.262       0.263
# ma.L1.D.Accidents_Bx    -0.8343      0.133     -6.295      0.000      -1.094      -0.575
# ma.L2.D.Accidents_Bx    -0.2113      0.109     -1.933      0.053      -0.426       0.003
# ma.L3.D.Accidents_Bx     0.0944      0.027      3.540      0.000       0.042       0.147
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1         1276.5851           +0.0000j         1276.5851            0.0000
# MA.1            1.0502           +0.0000j            1.0502            0.0000
# MA.2           -2.6370           +0.0000j            2.6370            0.5000
# MA.3            3.8264           +0.0000j            3.8264            0.0000
# -----------------------------------------------------------------------------
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:           Accidents_Bx   No. Observations:                 2531
# Model:                     ARMA(3, 2)   Log Likelihood              -10507.282
# Method:                       css-mle   S.D. of innovations             15.363
# Date:                Thu, 18 Feb 2021   AIC                          21028.564
# Time:                        10:24:09   BIC                          21069.419
# Sample:                    07-01-2012   HQIC                         21043.387
#                          - 06-05-2019
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 75.5721     11.971      6.313      0.000      52.109      99.035
# ar.L1.Accidents_Bx     0.9025      0.091      9.965      0.000       0.725       1.080
# ar.L2.Accidents_Bx    -0.0079      0.104     -0.075      0.940      -0.212       0.197
# ar.L3.Accidents_Bx     0.1042      0.025      4.230      0.000       0.056       0.152
# ma.L1.Accidents_Bx    -0.7366      0.090     -8.180      0.000      -0.913      -0.560
# ma.L2.Accidents_Bx    -0.2010      0.087     -2.309      0.021      -0.372      -0.030
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0010           -0.0000j            1.0010           -0.0000
# AR.2           -0.4627           -3.0620j            3.0968           -0.2739
# AR.3           -0.4627           +3.0620j            3.0968            0.2739
# MA.1            1.0543           +0.0000j            1.0543            0.0000
# MA.2           -4.7198           +0.0000j            4.7198            0.5000
# -----------------------------------------------------------------------------
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:         D.Accidents_Bx   No. Observations:                 2530
# Model:                 ARIMA(1, 1, 2)   Log Likelihood              -10509.506
# Method:                       css-mle   S.D. of innovations             15.403
# Date:                Thu, 18 Feb 2021   AIC                          21029.011
# Time:                        10:24:10   BIC                          21058.191
# Sample:                    07-02-2012   HQIC                         21039.599
#                          - 06-05-2019
# ========================================================================================
#                            coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0148      0.013      1.100      0.271      -0.012       0.041
# ar.L1.D.Accidents_Bx    -0.3485      0.078     -4.476      0.000      -0.501      -0.196
# ma.L1.D.Accidents_Bx    -0.4715      0.072     -6.566      0.000      -0.612      -0.331
# ma.L2.D.Accidents_Bx    -0.4696      0.068     -6.936      0.000      -0.602      -0.337
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -2.8696           +0.0000j            2.8696            0.5000
# MA.1            1.0412           +0.0000j            1.0412            0.0000
# MA.2           -2.0451           +0.0000j            2.0451            0.5000
# -----------------------------------------------------------------------------

# %% [markdown]
# From the above, we see that none of these parameters have significant p-values. We will now look at the next 10 lowest AIC scores in search of our best ARIMA model.

# %%
for pdq in df_AIC['pdq'][10:20]:
    mod = ARIMA(y_train[:-1], order=pdq)
    mod_fit = mod.fit()
    print(mod_fit.summary())
# Out:
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:           Accidents_Bx   No. Observations:                 2531
# Model:                     ARMA(1, 3)   Log Likelihood              -10509.214
# Method:                       css-mle   S.D. of innovations             15.375
# Date:                Thu, 18 Feb 2021   AIC                          21030.429
# Time:                        10:26:04   BIC                          21065.447
# Sample:                    07-01-2012   HQIC                         21043.134
#                          - 06-05-2019
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 75.5322     12.061      6.263      0.000      51.894      99.171
# ar.L1.Accidents_Bx     0.9990      0.001   1234.755      0.000       0.997       1.001
# ma.L1.Accidents_Bx    -0.8328      0.020    -42.304      0.000      -0.871      -0.794
# ma.L2.Accidents_Bx    -0.2115      0.024     -8.714      0.000      -0.259      -0.164
# ma.L3.Accidents_Bx     0.0954      0.019      5.092      0.000       0.059       0.132
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0010           +0.0000j            1.0010            0.0000
# MA.1            1.0530           +0.0000j            1.0530            0.0000
# MA.2           -2.6264           +0.0000j            2.6264            0.5000
# MA.3            3.7900           +0.0000j            3.7900            0.0000
# -----------------------------------------------------------------------------
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:           Accidents_Bx   No. Observations:                 2531
# Model:                     ARMA(3, 1)   Log Likelihood              -10509.253
# Method:                       css-mle   S.D. of innovations             15.375
# Date:                Thu, 18 Feb 2021   AIC                          21030.505
# Time:                        10:26:05   BIC                          21065.524
# Sample:                    07-01-2012   HQIC                         21043.211
#                          - 06-05-2019
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 75.5918     11.736      6.441      0.000      52.591      98.593
# ar.L1.Accidents_Bx     1.1076      0.021     52.083      0.000       1.066       1.149
# ar.L2.Accidents_Bx    -0.2328      0.029     -7.997      0.000      -0.290      -0.176
# ar.L3.Accidents_Bx     0.1241      0.021      5.890      0.000       0.083       0.165
# ma.L1.Accidents_Bx    -0.9452      0.009   -100.667      0.000      -0.964      -0.927
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0011           -0.0000j            1.0011           -0.0000
# AR.2            0.4374           -2.8033j            2.8373           -0.2254
# AR.3            0.4374           +2.8033j            2.8373            0.2254
# MA.1            1.0580           +0.0000j            1.0580            0.0000
# -----------------------------------------------------------------------------
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:           Accidents_Bx   No. Observations:                 2531
# Model:                     ARMA(2, 3)   Log Likelihood              -10509.213
# Method:                       css-mle   S.D. of innovations             15.375
# Date:                Thu, 18 Feb 2021   AIC                          21032.426
# Time:                        10:26:07   BIC                          21073.281
# Sample:                    07-01-2012   HQIC                         21047.249
#                          - 06-05-2019
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 75.5632     12.056      6.268      0.000      51.933      99.193
# ar.L1.Accidents_Bx     1.0055      0.101      9.986      0.000       0.808       1.203
# ar.L2.Accidents_Bx    -0.0065      0.101     -0.064      0.949      -0.204       0.191
# ma.L1.Accidents_Bx    -0.8391      0.100     -8.358      0.000      -1.036      -0.642
# ma.L2.Accidents_Bx    -0.2063      0.084     -2.466      0.014      -0.370      -0.042
# ma.L3.Accidents_Bx     0.0963      0.023      4.103      0.000       0.050       0.142
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0010           +0.0000j            1.0010            0.0000
# AR.2          154.6550           +0.0000j          154.6550            0.0000
# MA.1            1.0531           +0.0000j            1.0531            0.0000
# MA.2           -2.6421           +0.0000j            2.6421            0.5000
# MA.3            3.7314           +0.0000j            3.7314            0.0000
# -----------------------------------------------------------------------------
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:           Accidents_Bx   No. Observations:                 2531
# Model:                     ARMA(2, 2)   Log Likelihood              -10513.941
# Method:                       css-mle   S.D. of innovations             15.404
# Date:                Thu, 18 Feb 2021   AIC                          21039.882
# Time:                        10:26:09   BIC                          21074.900
# Sample:                    07-01-2012   HQIC                         21052.587
#                          - 06-05-2019
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 75.3790     12.701      5.935      0.000      50.485     100.273
# ar.L1.Accidents_Bx     0.6487      0.076      8.548      0.000       0.500       0.797
# ar.L2.Accidents_Bx     0.3502      0.076      4.620      0.000       0.202       0.499
# ma.L1.Accidents_Bx    -0.4684      0.070     -6.679      0.000      -0.606      -0.331
# ma.L2.Accidents_Bx    -0.4700      0.066     -7.126      0.000      -0.599      -0.341
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0008           +0.0000j            1.0008            0.0000
# AR.2           -2.8532           +0.0000j            2.8532            0.5000
# MA.1            1.0431           +0.0000j            1.0431            0.0000
# MA.2           -2.0396           +0.0000j            2.0396            0.5000
# -----------------------------------------------------------------------------
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:        D2.Accidents_Bx   No. Observations:                 2529
# Model:                 ARIMA(1, 2, 3)   Log Likelihood              -10513.197
# Method:                       css-mle   S.D. of innovations             15.407
# Date:                Thu, 18 Feb 2021   AIC                          21038.395
# Time:                        10:26:29   BIC                          21073.408
# Sample:                    07-03-2012   HQIC                         21051.099
#                          - 06-05-2019
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                  4.061e-07   1.78e-05      0.023      0.982   -3.45e-05    3.53e-05
# ar.L1.D2.Accidents_Bx    -0.3008      0.019    -15.836      0.000      -0.338      -0.264
# ma.L1.D2.Accidents_Bx    -1.5178        nan        nan        nan         nan         nan
# ma.L2.D2.Accidents_Bx     0.0892      0.001     64.746      0.000       0.086       0.092
# ma.L3.D2.Accidents_Bx     0.4287      0.001    297.875      0.000       0.426       0.431
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -3.3247           +0.0000j            3.3247            0.5000
# MA.1            1.0000           +0.0000j            1.0000            0.0000
# MA.2            1.0384           +0.0000j            1.0384            0.0000
# MA.3           -2.2465           +0.0000j            2.2465            0.5000
# -----------------------------------------------------------------------------
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:         D.Accidents_Bx   No. Observations:                 2530
# Model:                 ARIMA(0, 1, 2)   Log Likelihood              -10517.674
# Method:                       css-mle   S.D. of innovations             15.452
# Date:                Thu, 18 Feb 2021   AIC                          21043.349
# Time:                        10:26:30   BIC                          21066.692
# Sample:                    07-02-2012   HQIC                         21051.818
#                          - 06-05-2019
# ========================================================================================
#                            coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0148      0.013      1.143      0.253      -0.011       0.040
# ma.L1.D.Accidents_Bx    -0.8188      0.022    -37.041      0.000      -0.862      -0.775
# ma.L2.D.Accidents_Bx    -0.1396      0.022     -6.245      0.000      -0.183      -0.096
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# MA.1            1.0377           +0.0000j            1.0377            0.0000
# MA.2           -6.9030           +0.0000j            6.9030            0.5000
# -----------------------------------------------------------------------------
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:         D.Accidents_Bx   No. Observations:                 2530
# Model:                 ARIMA(1, 1, 1)   Log Likelihood              -10522.139
# Method:                       css-mle   S.D. of innovations             15.480
# Date:                Thu, 18 Feb 2021   AIC                          21052.278
# Time:                        10:26:30   BIC                          21075.622
# Sample:                    07-02-2012   HQIC                         21060.748
#                          - 06-05-2019
# ========================================================================================
#                            coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0148      0.013      1.125      0.260      -0.011       0.041
# ar.L1.D.Accidents_Bx     0.1122      0.021      5.388      0.000       0.071       0.153
# ma.L1.D.Accidents_Bx    -0.9625      0.006   -160.020      0.000      -0.974      -0.951
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            8.9091           +0.0000j            8.9091            0.0000
# MA.1            1.0390           +0.0000j            1.0390            0.0000
# -----------------------------------------------------------------------------
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:        D2.Accidents_Bx   No. Observations:                 2529
# Model:                 ARIMA(0, 2, 3)   Log Likelihood              -10521.441
# Method:                       css-mle   S.D. of innovations             15.464
# Date:                Thu, 18 Feb 2021   AIC                          21052.881
# Time:                        10:26:35   BIC                          21082.059
# Sample:                    07-03-2012   HQIC                         21063.468
#                          - 06-05-2019
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                  1.739e-07   2.64e-05      0.007      0.995   -5.15e-05    5.19e-05
# ma.L1.D2.Accidents_Bx    -1.8183      0.001  -3455.405      0.000      -1.819      -1.817
# ma.L2.D2.Accidents_Bx     0.6797      0.001    489.541      0.000       0.677       0.682
# ma.L3.D2.Accidents_Bx     0.1386      0.001    108.314      0.000       0.136       0.141
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# MA.1            1.0014           +0.0000j            1.0014            0.0000
# MA.2            1.0376           +0.0000j            1.0376            0.0000
# MA.3           -6.9427           +0.0000j            6.9427            0.5000
# -----------------------------------------------------------------------------
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:           Accidents_Bx   No. Observations:                 2531
# Model:                     ARMA(1, 2)   Log Likelihood              -10522.188
# Method:                       css-mle   S.D. of innovations             15.454
# Date:                Thu, 18 Feb 2021   AIC                          21054.375
# Time:                        10:26:36   BIC                          21083.557
# Sample:                    07-01-2012   HQIC                         21064.963
#                          - 06-05-2019
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 75.2697     12.928      5.822      0.000      49.932     100.608
# ar.L1.Accidents_Bx     0.9993      0.001   1534.113      0.000       0.998       1.001
# ma.L1.Accidents_Bx    -0.8180      0.022    -36.941      0.000      -0.861      -0.775
# ma.L2.Accidents_Bx    -0.1385      0.022     -6.192      0.000      -0.182      -0.095
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0007           +0.0000j            1.0007            0.0000
# MA.1            1.0395           +0.0000j            1.0395            0.0000
# MA.2           -6.9467           +0.0000j            6.9467            0.5000
# -----------------------------------------------------------------------------
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:           Accidents_Bx   No. Observations:                 2531
# Model:                     ARMA(2, 1)   Log Likelihood              -10526.621
# Method:                       css-mle   S.D. of innovations             15.481
# Date:                Thu, 18 Feb 2021   AIC                          21063.241
# Time:                        10:26:37   BIC                          21092.423
# Sample:                    07-01-2012   HQIC                         21073.829
#                          - 06-05-2019
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 75.3750     12.837      5.872      0.000      50.215     100.535
# ar.L1.Accidents_Bx     1.1105      0.020     55.814      0.000       1.072       1.149
# ar.L2.Accidents_Bx    -0.1112      0.020     -5.603      0.000      -0.150      -0.072
# ma.L1.Accidents_Bx    -0.9607      0.006   -154.694      0.000      -0.973      -0.949
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0007           +0.0000j            1.0007            0.0000
# AR.2            8.9893           +0.0000j            8.9893            0.0000
# MA.1            1.0409           +0.0000j            1.0409            0.0000
# -----------------------------------------------------------------------------

# %% [markdown]
# From the above, we see that the following parameters have significant p-values:
#
# (1,0,3)
#
# (3,0,1)
#
# (2,0,2)
#
# (1,0,2)
#
# (2,0,1)
#
# We will compare RMSE values for these parameters to determine our best ARIMA model.

# %% [markdown]
# **Determine Best ARIMA Model**

# %%
# Create RMSE function
def RMSE(pred):
    return np.sqrt(((pred-y_test)**2).mean())

# For loop to apply RMSE function to significant parameters
for pdq in [(1,0,3),(3,0,1),(2,0,2),(1,0,2),(2,0,1)]:
    mod = ARIMA(y_train[:-1], order=pdq)
    mod_fit = mod.fit()
    mod_pred = mod_fit.predict(start='2019-06-06', end='2020-03-13', dynamic=False)
    print(pdq,': RMSE: ', RMSE(mod_pred), 'AIC: ', mod_fit.aic)
# Out:
# (1, 0, 3) : RMSE:  18.704527770395476 AIC:  21030.428777020312
# (3, 0, 1) : RMSE:  18.684566618251615 AIC:  21030.505436797564
# (2, 0, 2) : RMSE:  18.67210468599582 AIC:  21039.88157879749
# (1, 0, 2) : RMSE:  18.630368932103426 AIC:  21054.375480553423
# (2, 0, 1) : RMSE:  18.648381871859858 AIC:  21063.241250437302

# %% [markdown]
# The above models have very similar RMSEs and AICs. Since they are so close in all ways, we will prioritize a slightly lower RMSE in parameters (1,0,2) since it most directly relates to prediction accuracy.

# %%
# Define baseline model for future comparison
base = ARIMA(y_train[:-1], order=(1,0,2))
base_fit = base.fit()
base_pred = base_fit.predict(start='2019-06-06', end='2020-03-13', dynamic=False)
base_RMSE = RMSE(base_pred)
base_AIC = base_fit.aic

print('Baseline model RMSE: ', base_RMSE)
print('Baseline model RMSE adj for range: ',
      base_RMSE/(df_bx['Accidents_Bx'].max()-df_bx['Accidents_Bx'].min()))
print('Baseline model AIC: ', base_AIC)
# Out:
# Baseline model RMSE:  18.630368932103426
# Baseline model RMSE adj for range:  0.0917752164143026
# Baseline model AIC:  21054.375480553423

# %% [markdown]
# ## Model #2: Introducing Exogenous Variables: ARIMAX Model

# %% [markdown]
# Now that we have our baseline ARIMA model, we will try incorporating exogenous variables with an ARIMAX model.

# %% [markdown]
# **Clean Data for ARIMAX Model**

# %%
# Turn exogenous variables into integers so they work in the model
# Season
df_bx['Season'] = np.where(df_bx['Season']=='Fall', 1, df_bx['Season'])
df_bx['Season'] = np.where(df_bx['Season']=='Winter', 2, df_bx['Season'])
df_bx['Season'] = np.where(df_bx['Season']=='Spring', 3, df_bx['Season'])
df_bx['Season'] = np.where(df_bx['Season']=='Summer', 4, df_bx['Season'])

# Day of Week
df_bx['Day of Week'] = np.where(df_bx['Day of Week']=='Sunday', 1, df_bx['Day of Week'])
df_bx['Day of Week'] = np.where(df_bx['Day of Week']=='Monday', 2, df_bx['Day of Week'])
df_bx['Day of Week'] = np.where(df_bx['Day of Week']=='Tuesday', 3, df_bx['Day of Week'])
df_bx['Day of Week'] = np.where(df_bx['Day of Week']=='Wednesday', 4, df_bx['Day of Week'])
df_bx['Day of Week'] = np.where(df_bx['Day of Week']=='Thursday', 5, df_bx['Day of Week'])
df_bx['Day of Week'] = np.where(df_bx['Day of Week']=='Friday', 6, df_bx['Day of Week'])
df_bx['Day of Week'] = np.where(df_bx['Day of Week']=='Saturday', 7, df_bx['Day of Week'])

# Weekend (these turned into strings when the data was imported from the csv)
df_bx['Weekend'] = np.where(df_bx['Weekend']=='0', 0, df_bx['Weekend'])
df_bx['Weekend'] = np.where(df_bx['Weekend']=='1', 1, df_bx['Weekend'])

# Holiday (these turned into strings when the data was imported from the csv)
df_bx['Holiday'] = np.where(df_bx['Holiday']=='0', 0, df_bx['Holiday'])
df_bx['Holiday'] = np.where(df_bx['Holiday']=='1', 1, df_bx['Holiday'])

# %% [markdown]
# **Redefine Train-Test Split with Cleaned Data**

# %%
# Train-test split
# Based on the above, 2019-06-06 will be the split point for our train and test sets

X = df_bx.index
y = df_bx['Accidents_Bx']

train = df_bx.loc[:'2019-06-06']
test = df_bx.loc['2019-06-06':]

X_train, X_test = train.index , test.index
y_train, y_test = train['Accidents_Bx'] , test['Accidents_Bx']

# %%
# Make list of lists of exogenous data to be used in the model
list_of_lists = []
for column in list(train.iloc[:,1:].columns):
    list_of_lists.append(list(train[column]))
    
exog=np.column_stack(list_of_lists)

# %% [markdown]
# **Grid Search**

# %%
# Determine best parameters for ARIMAX model

# Define the p, d, and q parameters to take any value between 0 and 4
p = d = q = range(0,4)

# Generate all different combinations of p, d, and q triplets
pdq = list(itertools.product(p, d, q))

# Run a grid with pdq parameters calculated to see corresponding AIC scores
ans_ARIMAX2 = []
for comb in pdq:
    try:
        mod = sm.tsa.ARIMA(endog=y_train,
                           exog=exog,
                           order=comb)
        output = mod.fit()
        ans_ARIMAX2.append([comb, output.aic])
        print('ARIMAX {} : AIC Calculated ={}'.format(comb,output.aic))
    except:
        continue
# Out:
# ARIMAX (0, 0, 0) : AIC Calculated =22846.008777865274
# ARIMAX (0, 0, 1) : AIC Calculated =21974.676630208894
# ARIMAX (0, 0, 2) : AIC Calculated =21683.197177272585
# ARIMAX (0, 0, 3) : AIC Calculated =21489.723383187105
# ARIMAX (0, 1, 0) : AIC Calculated =21945.12327252293
# ARIMAX (0, 1, 1) : AIC Calculated =20616.10009714066
# ARIMAX (0, 1, 2) : AIC Calculated =20601.362518153703
# ARIMAX (0, 1, 3) : AIC Calculated =20598.055707578897
# ARIMAX (0, 2, 0) : AIC Calculated =24782.62344232424
# ARIMAX (0, 2, 1) : AIC Calculated =22221.15884674155
# ARIMAX (0, 2, 2) : AIC Calculated =20790.61441115327
# ARIMAX (0, 2, 3) : AIC Calculated =20779.680889861003
# ARIMAX (1, 0, 0) : AIC Calculated =21312.268068283836
# ARIMAX (1, 0, 1) : AIC Calculated =20447.186806419155
# ARIMAX (1, 0, 2) : AIC Calculated =20421.524154781146
# ARIMAX (1, 0, 3) : AIC Calculated =20421.214972165457
# ARIMAX (1, 1, 0) : AIC Calculated =21469.394346068253
# ARIMAX (1, 1, 1) : AIC Calculated =20603.256247836485
# ARIMAX (1, 1, 2) : AIC Calculated =20598.720803845456
# ARIMAX (1, 1, 3) : AIC Calculated =20599.508870122485
# ARIMAX (1, 2, 0) : AIC Calculated =23728.603454562915
# ARIMAX (1, 2, 2) : AIC Calculated =20811.95307070401
# ARIMAX (1, 2, 3) : AIC Calculated =20798.327146244577
# ARIMAX (2, 0, 0) : AIC Calculated =21064.77558188829
# ARIMAX (2, 0, 1) : AIC Calculated =20423.731714841088
# ARIMAX (2, 0, 2) : AIC Calculated =20421.211120511492
# ARIMAX (2, 0, 3) : AIC Calculated =20423.041100252496
# ARIMAX (2, 1, 0) : AIC Calculated =21092.894600095053
# ARIMAX (2, 1, 1) : AIC Calculated =20598.926301512987
# ARIMAX (2, 1, 2) : AIC Calculated =20598.873906453417
# ARIMAX (2, 1, 3) : AIC Calculated =20443.835860588195
# ARIMAX (2, 2, 0) : AIC Calculated =22961.65237930725
# ARIMAX (2, 2, 1) : AIC Calculated =21255.147731690322
# ARIMAX (2, 2, 2) : AIC Calculated =20774.62886207016
# ARIMAX (2, 2, 3) : AIC Calculated =20769.639153275697
# ARIMAX (3, 0, 0) : AIC Calculated =20840.302225356987
# ARIMAX (3, 0, 1) : AIC Calculated =20422.055352779455
# ARIMAX (3, 0, 2) : AIC Calculated =20422.941183476163
# ARIMAX (3, 0, 3) : AIC Calculated =20414.20103083337
# ARIMAX (3, 1, 0) : AIC Calculated =20892.432580481516
# ARIMAX (3, 1, 1) : AIC Calculated =20591.966500656934
# ARIMAX (3, 1, 2) : AIC Calculated =20582.572948488018
# ARIMAX (3, 1, 3) : AIC Calculated =20429.536064710283
# ARIMAX (3, 2, 0) : AIC Calculated =22252.498375125233
# ARIMAX (3, 2, 1) : AIC Calculated =21035.82902444465
# ARIMAX (3, 2, 2) : AIC Calculated =20833.00843645246
# ARIMAX (3, 2, 3) : AIC Calculated =20800.22009055023

# %%
# Find parameters with minimal AIC value
df_AIC = pd.DataFrame(ans_ARIMAX2, columns=['pdq', 'aic'])
df_AIC.sort_values(by='aic', ascending=True, inplace=True)
df_AIC[:10]
# Out:
#           pdq           aic
# 38  (3, 0, 3)  20414.201031
# 25  (2, 0, 2)  20421.211121
# 15  (1, 0, 3)  20421.214972
# 14  (1, 0, 2)  20421.524155
# 36  (3, 0, 1)  20422.055353
# 37  (3, 0, 2)  20422.941183
# 26  (2, 0, 3)  20423.041100
# 24  (2, 0, 1)  20423.731715
# 42  (3, 1, 3)  20429.536065
# 30  (2, 1, 3)  20443.835861

# %% [markdown]
# **Determining Best Parameters**

# %% [markdown]
# Observe lowest 10 AIC score parameter values to determine best model. Make sure p values are significant, and observe RMSEs to determind best overall model.

# %%
for pdq in df_AIC['pdq'][:10]:
    mod = sm.tsa.ARIMA(endog=y_train,
                       exog=exog,
                       order=pdq)
    mod_fit = mod.fit()
    print(mod_fit.summary())
# Out:
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:           Accidents_Bx   No. Observations:                 2532
# Model:                     ARMA(3, 3)   Log Likelihood              -10195.101
# Method:                       css-mle   S.D. of innovations             13.559
# Date:                Thu, 18 Feb 2021   AIC                          20414.201
# Time:                        10:41:11   BIC                          20484.242
# Sample:                    07-01-2012   HQIC                         20439.613
#                          - 06-06-2019
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 73.9272     11.063      6.682      0.000      52.244      95.610
# x1                    -0.3729      0.553     -0.674      0.501      -1.458       0.712
# x2                     1.7602      0.138     12.781      0.000       1.490       2.030
# x3                   -11.8348      0.700    -16.908      0.000     -13.207     -10.463
# x4                   -17.6064      1.533    -11.483      0.000     -20.612     -14.601
# ar.L1.Accidents_Bx     0.3501      0.157      2.233      0.026       0.043       0.657
# ar.L2.Accidents_Bx    -0.0277      0.185     -0.150      0.881      -0.390       0.335
# ar.L3.Accidents_Bx     0.6744      0.080      8.450      0.000       0.518       0.831
# ma.L1.Accidents_Bx    -0.2026      0.166     -1.222      0.222      -0.528       0.122
# ma.L2.Accidents_Bx    -0.0209      0.162     -0.129      0.897      -0.338       0.296
# ma.L3.Accidents_Bx    -0.6176      0.070     -8.793      0.000      -0.755      -0.480
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0013           -0.0000j            1.0013           -0.0000
# AR.2           -0.4801           -1.1181j            1.2168           -0.3146
# AR.3           -0.4801           +1.1181j            1.2168            0.3146
# MA.1            1.0711           -0.0000j            1.0711           -0.0000
# MA.2           -0.5525           -1.0983j            1.2295           -0.3242
# MA.3           -0.5525           +1.0983j            1.2295            0.3242
# -----------------------------------------------------------------------------
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:           Accidents_Bx   No. Observations:                 2532
# Model:                     ARMA(2, 2)   Log Likelihood              -10200.606
# Method:                       css-mle   S.D. of innovations             13.588
# Date:                Thu, 18 Feb 2021   AIC                          20421.211
# Time:                        10:41:16   BIC                          20479.579
# Sample:                    07-01-2012   HQIC                         20442.388
#                          - 06-06-2019
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 73.5942     11.837      6.217      0.000      50.393      96.795
# x1                    -0.2827      0.538     -0.526      0.599      -1.337       0.771
# x2                     1.8084      0.136     13.293      0.000       1.542       2.075
# x3                   -12.6058      0.620    -20.344      0.000     -13.820     -11.391
# x4                   -17.2689      1.542    -11.200      0.000     -20.291     -14.247
# ar.L1.Accidents_Bx     0.7722      0.125      6.154      0.000       0.526       1.018
# ar.L2.Accidents_Bx     0.2265      0.125      1.808      0.071      -0.019       0.472
# ma.L1.Accidents_Bx    -0.6046      0.121     -4.985      0.000      -0.842      -0.367
# ma.L2.Accidents_Bx    -0.3215      0.112     -2.870      0.004      -0.541      -0.102
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0011           +0.0000j            1.0011            0.0000
# AR.2           -4.4109           +0.0000j            4.4109            0.5000
# MA.1            1.0584           +0.0000j            1.0584            0.0000
# MA.2           -2.9391           +0.0000j            2.9391            0.5000
# -----------------------------------------------------------------------------
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:           Accidents_Bx   No. Observations:                 2532
# Model:                     ARMA(1, 3)   Log Likelihood              -10200.607
# Method:                       css-mle   S.D. of innovations             13.588
# Date:                Thu, 18 Feb 2021   AIC                          20421.215
# Time:                        10:41:21   BIC                          20479.583
# Sample:                    07-01-2012   HQIC                         20442.391
#                          - 06-06-2019
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 73.6544     11.721      6.284      0.000      50.681      96.627
# x1                    -0.2979      0.541     -0.551      0.582      -1.358       0.762
# x2                     1.8063      0.136     13.233      0.000       1.539       2.074
# x3                   -12.6094      0.623    -20.249      0.000     -13.830     -11.389
# x4                   -17.3098      1.545    -11.201      0.000     -20.339     -14.281
# ar.L1.Accidents_Bx     0.9989      0.001   1136.471      0.000       0.997       1.001
# ma.L1.Accidents_Bx    -0.8314      0.020    -41.307      0.000      -0.871      -0.792
# ma.L2.Accidents_Bx    -0.1369      0.026     -5.320      0.000      -0.187      -0.086
# ma.L3.Accidents_Bx     0.0297      0.020      1.520      0.128      -0.009       0.068
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0011           +0.0000j            1.0011            0.0000
# MA.1            1.0603           +0.0000j            1.0603            0.0000
# MA.2           -4.1327           +0.0000j            4.1327            0.5000
# MA.3            7.6749           +0.0000j            7.6749            0.0000
# -----------------------------------------------------------------------------
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:           Accidents_Bx   No. Observations:                 2532
# Model:                     ARMA(1, 2)   Log Likelihood              -10201.762
# Method:                       css-mle   S.D. of innovations             13.595
# Date:                Thu, 18 Feb 2021   AIC                          20421.524
# Time:                        10:41:24   BIC                          20474.055
# Sample:                    07-01-2012   HQIC                         20440.583
#                          - 06-06-2019
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 73.4070     12.087      6.073      0.000      49.716      97.098
# x1                    -0.2444      0.534     -0.458      0.647      -1.291       0.802
# x2                     1.8236      0.136     13.423      0.000       1.557       2.090
# x3                   -12.7396      0.614    -20.743      0.000     -13.943     -11.536
# x4                   -17.0756      1.539    -11.096      0.000     -20.092     -14.059
# ar.L1.Accidents_Bx     0.9990      0.001   1238.213      0.000       0.997       1.001
# ma.L1.Accidents_Bx    -0.8288      0.021    -39.970      0.000      -0.869      -0.788
# ma.L2.Accidents_Bx    -0.1134      0.021     -5.335      0.000      -0.155      -0.072
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0010           +0.0000j            1.0010            0.0000
# MA.1            1.0545           +0.0000j            1.0545            0.0000
# MA.2           -8.3628           +0.0000j            8.3628            0.5000
# -----------------------------------------------------------------------------
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:           Accidents_Bx   No. Observations:                 2532
# Model:                     ARMA(3, 1)   Log Likelihood              -10201.028
# Method:                       css-mle   S.D. of innovations             13.591
# Date:                Thu, 18 Feb 2021   AIC                          20422.055
# Time:                        10:41:29   BIC                          20480.423
# Sample:                    07-01-2012   HQIC                         20443.232
#                          - 06-06-2019
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 73.6877     11.640      6.330      0.000      50.873      96.502
# x1                    -0.3068      0.543     -0.565      0.572      -1.371       0.757
# x2                     1.8102      0.137     13.240      0.000       1.542       2.078
# x3                   -12.6504      0.624    -20.268      0.000     -13.874     -11.427
# x4                   -17.2790      1.546    -11.178      0.000     -20.309     -14.249
# ar.L1.Accidents_Bx     1.1078      0.022     49.440      0.000       1.064       1.152
# ar.L2.Accidents_Bx    -0.1509      0.030     -5.055      0.000      -0.209      -0.092
# ar.L3.Accidents_Bx     0.0421      0.022      1.912      0.056      -0.001       0.085
# ma.L1.Accidents_Bx    -0.9419      0.010    -92.451      0.000      -0.962      -0.922
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0011           -0.0000j            1.0011           -0.0000
# AR.2            1.2936           -4.6987j            4.8736           -0.2072
# AR.3            1.2936           +4.6987j            4.8736            0.2072
# MA.1            1.0617           +0.0000j            1.0617            0.0000
# -----------------------------------------------------------------------------
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:           Accidents_Bx   No. Observations:                 2532
# Model:                     ARMA(3, 2)   Log Likelihood              -10200.471
# Method:                       css-mle   S.D. of innovations             13.588
# Date:                Thu, 18 Feb 2021   AIC                          20422.941
# Time:                        10:41:36   BIC                          20487.146
# Sample:                    07-01-2012   HQIC                         20446.235
#                          - 06-06-2019
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 73.6624     11.705      6.293      0.000      50.721      96.604
# x1                    -0.3005      0.541     -0.555      0.579      -1.362       0.761
# x2                     1.8041      0.136     13.222      0.000       1.537       2.072
# x3                   -12.5762      0.626    -20.083      0.000     -13.804     -11.349
# x4                   -17.3247      1.545    -11.210      0.000     -20.354     -14.296
# ar.L1.Accidents_Bx     0.8597      0.178      4.843      0.000       0.512       1.208
# ar.L2.Accidents_Bx     0.1201      0.200      0.601      0.548      -0.272       0.512
# ar.L3.Accidents_Bx     0.0189      0.031      0.602      0.547      -0.043       0.080
# ma.L1.Accidents_Bx    -0.6932      0.177     -3.914      0.000      -1.040      -0.346
# ma.L2.Accidents_Bx    -0.2354      0.169     -1.397      0.163      -0.566       0.095
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0011           -0.0000j            1.0011           -0.0000
# AR.2           -3.6747           -6.2671j            7.2650           -0.3344
# AR.3           -3.6747           +6.2671j            7.2650            0.3344
# MA.1            1.0606           +0.0000j            1.0606            0.0000
# MA.2           -4.0052           +0.0000j            4.0052            0.5000
# -----------------------------------------------------------------------------
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:           Accidents_Bx   No. Observations:                 2532
# Model:                     ARMA(2, 3)   Log Likelihood              -10200.521
# Method:                       css-mle   S.D. of innovations             13.588
# Date:                Thu, 18 Feb 2021   AIC                          20423.041
# Time:                        10:41:42   BIC                          20487.246
# Sample:                    07-01-2012   HQIC                         20446.335
#                          - 06-06-2019
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 73.6408     11.748      6.268      0.000      50.615      96.666
# x1                    -0.2947      0.540     -0.545      0.585      -1.354       0.764
# x2                     1.8056      0.136     13.247      0.000       1.538       2.073
# x3                   -12.5866      0.624    -20.167      0.000     -13.810     -11.363
# x4                   -17.3055      1.544    -11.206      0.000     -20.332     -14.279
# ar.L1.Accidents_Bx     0.8768      0.201      4.364      0.000       0.483       1.271
# ar.L2.Accidents_Bx     0.1220      0.201      0.608      0.543      -0.271       0.515
# ma.L1.Accidents_Bx    -0.7100      0.201     -3.534      0.000      -1.104      -0.316
# ma.L2.Accidents_Bx    -0.2381      0.167     -1.428      0.153      -0.565       0.089
# ma.L3.Accidents_Bx     0.0168      0.030      0.551      0.581      -0.043       0.077
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0011           +0.0000j            1.0011            0.0000
# AR.2           -8.1863           +0.0000j            8.1863            0.5000
# MA.1            1.0598           +0.0000j            1.0598            0.0000
# MA.2           -3.4004           +0.0000j            3.4004            0.5000
# MA.3           16.5084           +0.0000j           16.5084            0.0000
# -----------------------------------------------------------------------------
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:           Accidents_Bx   No. Observations:                 2532
# Model:                     ARMA(2, 1)   Log Likelihood              -10202.866
# Method:                       css-mle   S.D. of innovations             13.600
# Date:                Thu, 18 Feb 2021   AIC                          20423.732
# Time:                        10:41:45   BIC                          20476.263
# Sample:                    07-01-2012   HQIC                         20442.791
#                          - 06-06-2019
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 73.3237     12.140      6.040      0.000      49.530      97.117
# x1                    -0.2330      0.533     -0.437      0.662      -1.278       0.812
# x2                     1.8332      0.135     13.552      0.000       1.568       2.098
# x3                   -12.7350      0.612    -20.816      0.000     -13.934     -11.536
# x4                   -16.9074      1.533    -11.032      0.000     -19.911     -13.904
# ar.L1.Accidents_Bx     1.1112      0.022     51.358      0.000       1.069       1.154
# ar.L2.Accidents_Bx    -0.1120      0.022     -5.201      0.000      -0.154      -0.070
# ma.L1.Accidents_Bx    -0.9491      0.008   -116.531      0.000      -0.965      -0.933
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0010           +0.0000j            1.0010            0.0000
# AR.2            8.9195           +0.0000j            8.9195            0.0000
# MA.1            1.0536           +0.0000j            1.0536            0.0000
# -----------------------------------------------------------------------------
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:         D.Accidents_Bx   No. Observations:                 2531
# Model:                 ARIMA(3, 1, 3)   Log Likelihood              -10202.768
# Method:                       css-mle   S.D. of innovations             13.612
# Date:                Thu, 18 Feb 2021   AIC                          20429.536
# Time:                        10:41:56   BIC                          20499.573
# Sample:                    07-02-2012   HQIC                         20454.947
#                          - 06-06-2019
# ========================================================================================
#                            coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    6.1004      0.610     10.003      0.000       4.905       7.296
# x1                      -0.0326      0.019     -1.680      0.093      -0.071       0.005
# x2                      -0.7363      0.144     -5.111      0.000      -1.019      -0.454
# x3                     -10.3443      0.656    -15.769      0.000     -11.630      -9.059
# x4                      -3.1364      0.583     -5.379      0.000      -4.279      -1.994
# ar.L1.D.Accidents_Bx    -0.3539      0.014    -25.938      0.000      -0.381      -0.327
# ar.L2.D.Accidents_Bx    -0.9591      0.006   -157.985      0.000      -0.971      -0.947
# ar.L3.D.Accidents_Bx     0.0913      0.014      6.704      0.000       0.065       0.118
# ma.L1.D.Accidents_Bx    -0.4966      0.010    -49.611      0.000      -0.516      -0.477
# ma.L2.D.Accidents_Bx     0.5748      0.005    111.173      0.000       0.565       0.585
# ma.L3.D.Accidents_Bx    -0.9334      0.010    -94.215      0.000      -0.953      -0.914
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -0.2227           -0.9750j            1.0001           -0.2857
# AR.2           -0.2227           +0.9750j            1.0001            0.2857
# AR.3           10.9516           -0.0000j           10.9516           -0.0000
# MA.1           -0.2237           -0.9786j            1.0038           -0.2858
# MA.2           -0.2237           +0.9786j            1.0038            0.2858
# MA.3            1.0632           -0.0000j            1.0632           -0.0000
# -----------------------------------------------------------------------------
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:         D.Accidents_Bx   No. Observations:                 2531
# Model:                 ARIMA(2, 1, 3)   Log Likelihood              -10210.918
# Method:                       css-mle   S.D. of innovations             13.657
# Date:                Thu, 18 Feb 2021   AIC                          20443.836
# Time:                        10:42:02   BIC                          20508.036
# Sample:                    07-02-2012   HQIC                         20467.129
#                          - 06-06-2019
# ========================================================================================
#                            coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    5.9646      0.578     10.312      0.000       4.831       7.098
# x1                      -0.0312      0.023     -1.377      0.168      -0.076       0.013
# x2                      -0.6961      0.136     -5.107      0.000      -0.963      -0.429
# x3                     -10.4113      0.618    -16.840      0.000     -11.623      -9.200
# x4                      -3.4143      0.609     -5.607      0.000      -4.608      -2.221
# ar.L1.D.Accidents_Bx    -0.4453      0.001   -737.470      0.000      -0.446      -0.444
# ar.L2.D.Accidents_Bx    -0.9997      0.000  -2920.216      0.000      -1.000      -0.999
# ma.L1.D.Accidents_Bx    -0.4733      0.012    -39.861      0.000      -0.497      -0.450
# ma.L2.D.Accidents_Bx     0.5834      0.006     95.898      0.000       0.571       0.595
# ma.L3.D.Accidents_Bx    -0.9121      0.012    -76.281      0.000      -0.936      -0.889
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -0.2227           -0.9750j            1.0001           -0.2857
# AR.2           -0.2227           +0.9750j            1.0001            0.2857
# MA.1           -0.2244           -0.9783j            1.0037           -0.2859
# MA.2           -0.2244           +0.9783j            1.0037            0.2859
# MA.3            1.0883           -0.0000j            1.0883           -0.0000
# -----------------------------------------------------------------------------

# %% [markdown]
# We don't see any significant p values above, so will look at the next 10 lowest AIC scores.

# %%
for pdq in df_AIC['pdq'][10:20]:
    mod = sm.tsa.ARIMA(endog=y_train,
                       exog=exog,
                       order=pdq)
    mod_fit = mod.fit()
    print(mod_fit.summary())
# Out:
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:           Accidents_Bx   No. Observations:                 2532
# Model:                     ARMA(1, 1)   Log Likelihood              -10215.593
# Method:                       css-mle   S.D. of innovations             13.669
# Date:                Thu, 18 Feb 2021   AIC                          20447.187
# Time:                        10:43:15   BIC                          20493.881
# Sample:                    07-01-2012   HQIC                         20464.128
#                          - 06-06-2019
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 73.6483     10.646      6.918      0.000      52.782      94.515
# x1                    -0.3827      0.562     -0.681      0.496      -1.484       0.719
# x2                     1.8487      0.132     14.033      0.000       1.590       2.107
# x3                   -12.1877      0.582    -20.935      0.000     -13.329     -11.047
# x4                   -16.3407      1.508    -10.839      0.000     -19.295     -13.386
# ar.L1.Accidents_Bx     0.9985      0.001    921.719      0.000       0.996       1.001
# ma.L1.Accidents_Bx    -0.9279      0.010    -89.025      0.000      -0.948      -0.907
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0015           +0.0000j            1.0015            0.0000
# MA.1            1.0777           +0.0000j            1.0777            0.0000
# -----------------------------------------------------------------------------
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:         D.Accidents_Bx   No. Observations:                 2531
# Model:                 ARIMA(3, 1, 2)   Log Likelihood              -10280.286
# Method:                       css-mle   S.D. of innovations             14.046
# Date:                Thu, 18 Feb 2021   AIC                          20582.573
# Time:                        10:43:22   BIC                          20646.773
# Sample:                    07-02-2012   HQIC                         20605.866
#                          - 06-06-2019
# ========================================================================================
#                            coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    6.9152      0.572     12.086      0.000       5.794       8.037
# x1                      -0.0371      0.017     -2.144      0.032      -0.071      -0.003
# x2                      -0.7743      0.134     -5.765      0.000      -1.037      -0.511
# x3                     -12.6653      0.636    -19.910      0.000     -13.912     -11.419
# x4                      -2.8067      0.557     -5.036      0.000      -3.899      -1.714
# ar.L1.D.Accidents_Bx     0.7758      0.106      7.326      0.000       0.568       0.983
# ar.L2.D.Accidents_Bx    -0.1054      0.027     -3.950      0.000      -0.158      -0.053
# ar.L3.D.Accidents_Bx     0.1068      0.022      4.826      0.000       0.063       0.150
# ma.L1.D.Accidents_Bx    -1.6414      0.105    -15.698      0.000      -1.846      -1.436
# ma.L2.D.Accidents_Bx     0.6511      0.100      6.502      0.000       0.455       0.847
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.2364           -0.0000j            1.2364           -0.0000
# AR.2           -0.1248           -2.7491j            2.7519           -0.2572
# AR.3           -0.1248           +2.7491j            2.7519            0.2572
# MA.1            1.0304           +0.0000j            1.0304            0.0000
# MA.2            1.4906           +0.0000j            1.4906            0.0000
# -----------------------------------------------------------------------------
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:         D.Accidents_Bx   No. Observations:                 2531
# Model:                 ARIMA(3, 1, 1)   Log Likelihood              -10285.983
# Method:                       css-mle   S.D. of innovations             14.078
# Date:                Thu, 18 Feb 2021   AIC                          20591.967
# Time:                        10:43:25   BIC                          20650.330
# Sample:                    07-02-2012   HQIC                         20613.142
#                          - 06-06-2019
# ========================================================================================
#                            coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    6.9401      0.585     11.873      0.000       5.794       8.086
# x1                      -0.0302      0.018     -1.683      0.092      -0.065       0.005
# x2                      -0.7735      0.138     -5.624      0.000      -1.043      -0.504
# x3                     -12.8251      0.643    -19.945      0.000     -14.085     -11.565
# x4                      -2.7794      0.555     -5.004      0.000      -3.868      -1.691
# ar.L1.D.Accidents_Bx     0.0918      0.022      4.097      0.000       0.048       0.136
# ar.L2.D.Accidents_Bx    -0.0501      0.022     -2.314      0.021      -0.092      -0.008
# ar.L3.D.Accidents_Bx     0.0678      0.022      3.028      0.002       0.024       0.112
# ma.L1.D.Accidents_Bx    -0.9506      0.010    -95.582      0.000      -0.970      -0.931
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -0.8915           -2.2481j            2.4184           -0.3101
# AR.2           -0.8915           +2.2481j            2.4184            0.3101
# AR.3            2.5211           -0.0000j            2.5211           -0.0000
# MA.1            1.0519           +0.0000j            1.0519            0.0000
# -----------------------------------------------------------------------------
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:         D.Accidents_Bx   No. Observations:                 2531
# Model:                 ARIMA(0, 1, 3)   Log Likelihood              -10290.028
# Method:                       css-mle   S.D. of innovations             14.101
# Date:                Thu, 18 Feb 2021   AIC                          20598.056
# Time:                        10:43:28   BIC                          20650.583
# Sample:                    07-02-2012   HQIC                         20617.114
#                          - 06-06-2019
# ========================================================================================
#                            coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    7.1111      0.607     11.715      0.000       5.921       8.301
# x1                      -0.0291      0.019     -1.503      0.133      -0.067       0.009
# x2                      -0.7813      0.143     -5.447      0.000      -1.062      -0.500
# x3                     -13.3081      0.651    -20.431      0.000     -14.585     -12.031
# x4                      -2.9141      0.577     -5.052      0.000      -4.045      -1.784
# ma.L1.D.Accidents_Bx    -0.8554      0.020    -42.677      0.000      -0.895      -0.816
# ma.L2.D.Accidents_Bx    -0.1256      0.026     -4.878      0.000      -0.176      -0.075
# ma.L3.D.Accidents_Bx     0.0441      0.019      2.303      0.021       0.007       0.082
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# MA.1            1.0649           +0.0000j            1.0649            0.0000
# MA.2           -3.8070           +0.0000j            3.8070            0.5000
# MA.3            5.5875           +0.0000j            5.5875            0.0000
# -----------------------------------------------------------------------------
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:         D.Accidents_Bx   No. Observations:                 2531
# Model:                 ARIMA(1, 1, 2)   Log Likelihood              -10290.360
# Method:                       css-mle   S.D. of innovations             14.103
# Date:                Thu, 18 Feb 2021   AIC                          20598.721
# Time:                        10:43:32   BIC                          20651.248
# Sample:                    07-02-2012   HQIC                         20617.779
#                          - 06-06-2019
# ========================================================================================
#                            coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    7.1279      0.605     11.781      0.000       5.942       8.314
# x1                      -0.0292      0.019     -1.568      0.117      -0.066       0.007
# x2                      -0.7827      0.143     -5.468      0.000      -1.063      -0.502
# x3                     -13.3563      0.645    -20.717      0.000     -14.620     -12.093
# x4                      -2.8274      0.559     -5.054      0.000      -3.924      -1.731
# ar.L1.D.Accidents_Bx    -0.3242      0.128     -2.542      0.011      -0.574      -0.074
# ma.L1.D.Accidents_Bx    -0.5287      0.123     -4.315      0.000      -0.769      -0.289
# ma.L2.D.Accidents_Bx    -0.3927      0.113     -3.471      0.001      -0.614      -0.171
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -3.0843           +0.0000j            3.0843            0.5000
# MA.1            1.0588           +0.0000j            1.0588            0.0000
# MA.2           -2.4053           +0.0000j            2.4053            0.5000
# -----------------------------------------------------------------------------
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:         D.Accidents_Bx   No. Observations:                 2531
# Model:                 ARIMA(2, 1, 2)   Log Likelihood              -10289.437
# Method:                       css-mle   S.D. of innovations             14.098
# Date:                Thu, 18 Feb 2021   AIC                          20598.874
# Time:                        10:43:36   BIC                          20657.238
# Sample:                    07-02-2012   HQIC                         20620.049
#                          - 06-06-2019
# ========================================================================================
#                            coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    7.0770      0.605     11.705      0.000       5.892       8.262
# x1                      -0.0292      0.020     -1.492      0.136      -0.068       0.009
# x2                      -0.7797      0.143     -5.467      0.000      -1.059      -0.500
# x3                     -13.2068      0.656    -20.123      0.000     -14.493     -11.920
# x4                      -2.9410      0.581     -5.064      0.000      -4.079      -1.803
# ar.L1.D.Accidents_Bx    -0.1668      0.159     -1.047      0.295      -0.479       0.145
# ar.L2.D.Accidents_Bx    -0.0420      0.028     -1.507      0.132      -0.097       0.013
# ma.L1.D.Accidents_Bx    -0.6915      0.158     -4.370      0.000      -1.002      -0.381
# ma.L2.D.Accidents_Bx    -0.2310      0.151     -1.534      0.125      -0.526       0.064
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -1.9857           -4.4574j            4.8797           -0.3167
# AR.2           -1.9857           +4.4574j            4.8797            0.3167
# MA.1            1.0663           +0.0000j            1.0663            0.0000
# MA.2           -4.0595           +0.0000j            4.0595            0.5000
# -----------------------------------------------------------------------------
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:         D.Accidents_Bx   No. Observations:                 2531
# Model:                 ARIMA(2, 1, 1)   Log Likelihood              -10290.463
# Method:                       css-mle   S.D. of innovations             14.104
# Date:                Thu, 18 Feb 2021   AIC                          20598.926
# Time:                        10:43:39   BIC                          20651.454
# Sample:                    07-02-2012   HQIC                         20617.984
#                          - 06-06-2019
# ========================================================================================
#                            coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    7.1182      0.608     11.709      0.000       5.927       8.310
# x1                      -0.0291      0.020     -1.470      0.142      -0.068       0.010
# x2                      -0.7822      0.144     -5.450      0.000      -1.064      -0.501
# x3                     -13.3149      0.657    -20.259      0.000     -14.603     -12.027
# x4                      -2.9572      0.586     -5.049      0.000      -4.105      -1.809
# ar.L1.D.Accidents_Bx     0.0774      0.023      3.324      0.001       0.032       0.123
# ar.L2.D.Accidents_Bx    -0.0561      0.023     -2.494      0.013      -0.100      -0.012
# ma.L1.D.Accidents_Bx    -0.9362      0.012    -76.948      0.000      -0.960      -0.912
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            0.6894           -4.1646j            4.2213           -0.2239
# AR.2            0.6894           +4.1646j            4.2213            0.2239
# MA.1            1.0681           +0.0000j            1.0681            0.0000
# -----------------------------------------------------------------------------
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:         D.Accidents_Bx   No. Observations:                 2531
# Model:                 ARIMA(1, 1, 3)   Log Likelihood              -10289.754
# Method:                       css-mle   S.D. of innovations             14.100
# Date:                Thu, 18 Feb 2021   AIC                          20599.509
# Time:                        10:43:42   BIC                          20657.873
# Sample:                    07-02-2012   HQIC                         20620.684
#                          - 06-06-2019
# ========================================================================================
#                            coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    7.0959      0.605     11.733      0.000       5.911       8.281
# x1                      -0.0292      0.019     -1.514      0.130      -0.067       0.009
# x2                      -0.7810      0.143     -5.468      0.000      -1.061      -0.501
# x3                     -13.2594      0.652    -20.334      0.000     -14.537     -11.981
# x4                      -2.9055      0.575     -5.056      0.000      -4.032      -1.779
# ar.L1.D.Accidents_Bx    -0.1470      0.194     -0.757      0.449      -0.528       0.234
# ma.L1.D.Accidents_Bx    -0.7102      0.193     -3.676      0.000      -1.089      -0.332
# ma.L2.D.Accidents_Bx    -0.2508      0.165     -1.523      0.128      -0.574       0.072
# ma.L3.D.Accidents_Bx     0.0329      0.027      1.240      0.215      -0.019       0.085
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -6.8035           +0.0000j            6.8035            0.5000
# MA.1            1.0640           +0.0000j            1.0640            0.0000
# MA.2           -2.9911           +0.0000j            2.9911            0.5000
# MA.3            9.5546           +0.0000j            9.5546            0.0000
# -----------------------------------------------------------------------------
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:         D.Accidents_Bx   No. Observations:                 2531
# Model:                 ARIMA(0, 1, 2)   Log Likelihood              -10292.681
# Method:                       css-mle   S.D. of innovations             14.116
# Date:                Thu, 18 Feb 2021   AIC                          20601.363
# Time:                        10:43:45   BIC                          20648.053
# Sample:                    07-02-2012   HQIC                         20618.303
#                          - 06-06-2019
# ========================================================================================
#                            coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    7.1959      0.607     11.861      0.000       6.007       8.385
# x1                      -0.0292      0.018     -1.613      0.107      -0.065       0.006
# x2                      -0.7876      0.144     -5.484      0.000      -1.069      -0.506
# x3                     -13.5343      0.646    -20.938      0.000     -14.801     -12.267
# x4                      -2.7552      0.552     -4.993      0.000      -3.837      -1.674
# ma.L1.D.Accidents_Bx    -0.8531      0.021    -40.314      0.000      -0.895      -0.812
# ma.L2.D.Accidents_Bx    -0.0905      0.022     -4.140      0.000      -0.133      -0.048
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# MA.1            1.0544           +0.0000j            1.0544            0.0000
# MA.2          -10.4844           +0.0000j           10.4844            0.5000
# -----------------------------------------------------------------------------
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:         D.Accidents_Bx   No. Observations:                 2531
# Model:                 ARIMA(1, 1, 1)   Log Likelihood              -10293.628
# Method:                       css-mle   S.D. of innovations             14.121
# Date:                Thu, 18 Feb 2021   AIC                          20603.256
# Time:                        10:43:47   BIC                          20649.947
# Sample:                    07-02-2012   HQIC                         20620.197
#                          - 06-06-2019
# ========================================================================================
#                            coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    7.1967      0.603     11.929      0.000       6.014       8.379
# x1                      -0.0292      0.018     -1.609      0.108      -0.065       0.006
# x2                      -0.7895      0.143     -5.532      0.000      -1.069      -0.510
# x3                     -13.5102      0.644    -20.978      0.000     -14.772     -12.248
# x4                      -2.7553      0.553     -4.986      0.000      -3.838      -1.672
# ar.L1.D.Accidents_Bx     0.0861      0.022      3.883      0.000       0.043       0.130
# ma.L1.D.Accidents_Bx    -0.9483      0.009   -108.445      0.000      -0.965      -0.931
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           11.6134           +0.0000j           11.6134            0.0000
# MA.1            1.0545           +0.0000j            1.0545            0.0000
# -----------------------------------------------------------------------------

# %% [markdown]
# Of the above, only parameters (3,1,2) have significant p-values. We will look at the next 10 lowest AIC values to see if we can find any others.

# %%
for pdq in df_AIC['pdq'][20:30]:
    mod = sm.tsa.ARIMA(endog=y_train,
                       exog=exog,
                       order=pdq)
    mod_fit = mod.fit()
    print(mod_fit.summary())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:         D.Accidents_Bx   No. Observations:                 2531
# Model:                 ARIMA(0, 1, 1)   Log Likelihood              -10301.050
# Method:                       css-mle   S.D. of innovations             14.163
# Date:                Thu, 18 Feb 2021   AIC                          20616.100
# Time:                        10:46:14   BIC                          20656.955
# Sample:                    07-02-2012   HQIC                         20630.923
#                          - 06-06-2019
# ========================================================================================
#                            coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    7.0962      0.577     12.302      0.000       5.966       8.227
# x1                      -0.0290      0.021     -1.410      0.158      -0.069       0.011
# x2                      -0.7948      0.136     -5.828      0.000      -1.062      -0.528
# x3                     -13.0541      0.603    -21.640      0.000     -14.236     -11.872
# x4                      -3.0250      0.578     -5.230      0.000      -4.159      -1.891
# ma.L1.D.Accidents_Bx    -0.9314      0.010    -91.263      0.000      -0.951      -0.911
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# MA.1            1.0736           +0.0000j            1.0736            0.0000
# -----------------------------------------------------------------------------
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:        D2.Accidents_Bx   No. Observations:                 2530
# Model:                 ARIMA(2, 2, 3)   Log Likelihood              -10373.820
# Method:                       css-mle   S.D. of innovations             14.567
# Date:                Thu, 18 Feb 2021   AIC                          20769.639
# Time:                        10:46:22   BIC                          20833.835
# Sample:                    07-03-2012   HQIC                         20792.931
#                          - 06-06-2019
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                     8.7605        nan        nan        nan         nan         nan
# x1                        0.0003      0.000      2.053      0.040    1.54e-05       0.001
# x2                       -2.0490        nan        nan        nan         nan         nan
# x3                       -1.9850        nan        nan        nan         nan         nan
# x4                        0.0488      0.016      2.971      0.003       0.017       0.081
# ar.L1.D2.Accidents_Bx    -0.3442      0.020    -17.307      0.000      -0.383      -0.305
# ar.L2.D2.Accidents_Bx    -0.0693      0.016     -4.406      0.000      -0.100      -0.038
# ma.L1.D2.Accidents_Bx    -1.5294      0.003   -521.842      0.000      -1.535      -1.524
# ma.L2.D2.Accidents_Bx     0.1524        nan        nan        nan         nan         nan
# ma.L3.D2.Accidents_Bx     0.3771        nan        nan        nan         nan         nan
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -2.4835           -2.8742j            3.7985           -0.3634
# AR.2           -2.4835           +2.8742j            3.7985            0.3634
# MA.1            1.0016           +0.0000j            1.0016            0.0000
# MA.2            1.0695           +0.0000j            1.0695            0.0000
# MA.3           -2.4752           +0.0000j            2.4752            0.5000
# -----------------------------------------------------------------------------
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:        D2.Accidents_Bx   No. Observations:                 2530
# Model:                 ARIMA(2, 2, 2)   Log Likelihood              -10377.314
# Method:                       css-mle   S.D. of innovations             14.588
# Date:                Thu, 18 Feb 2021   AIC                          20774.629
# Time:                        10:46:39   BIC                          20832.989
# Sample:                    07-03-2012   HQIC                         20795.803
#                          - 06-06-2019
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                     8.5592        nan        nan        nan         nan         nan
# x1                        0.0003      0.000      1.003      0.316      -0.000       0.001
# x2                       -1.9956        nan        nan        nan         nan         nan
# x3                       -2.0263        nan        nan        nan         nan         nan
# x4                        0.0460      0.018      2.562      0.010       0.011       0.081
# ar.L1.D2.Accidents_Bx     0.0527      0.020      2.608      0.009       0.013       0.092
# ar.L2.D2.Accidents_Bx    -0.0934      0.020     -4.636      0.000      -0.133      -0.054
# ma.L1.D2.Accidents_Bx    -1.9337      0.004   -461.779      0.000      -1.942      -1.925
# ma.L2.D2.Accidents_Bx     0.9338      0.004    225.225      0.000       0.926       0.942
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            0.2821           -3.2596j            3.2718           -0.2363
# AR.2            0.2821           +3.2596j            3.2718            0.2363
# MA.1            1.0025           +0.0000j            1.0025            0.0000
# MA.2            1.0682           +0.0000j            1.0682            0.0000
# -----------------------------------------------------------------------------
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:        D2.Accidents_Bx   No. Observations:                 2530
# Model:                 ARIMA(0, 2, 3)   Log Likelihood              -10380.840
# Method:                       css-mle   S.D. of innovations             14.603
# Date:                Thu, 18 Feb 2021   AIC                          20779.681
# Time:                        10:46:46   BIC                          20832.205
# Sample:                    07-03-2012   HQIC                         20798.738
#                          - 06-06-2019
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                     9.8717        nan        nan        nan         nan         nan
# x1                     4.427e-05   4.56e-05      0.972      0.331    -4.5e-05       0.000
# x2                       -2.3073        nan        nan        nan         nan         nan
# x3                       -2.2536      0.001  -3224.028      0.000      -2.255      -2.252
# x4                        0.0356      0.011      3.106      0.002       0.013       0.058
# ma.L1.D2.Accidents_Bx    -1.8706      0.000  -4932.344      0.000      -1.871      -1.870
# ma.L2.D2.Accidents_Bx     0.7862      0.001    862.468      0.000       0.784       0.788
# ma.L3.D2.Accidents_Bx     0.0845      0.001    102.545      0.000       0.083       0.086
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# MA.1            1.0010           +0.0000j            1.0010            0.0000
# MA.2            1.0420           +0.0000j            1.0420            0.0000
# MA.3          -11.3495           +0.0000j           11.3495            0.5000
# -----------------------------------------------------------------------------
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:        D2.Accidents_Bx   No. Observations:                 2530
# Model:                 ARIMA(0, 2, 2)   Log Likelihood              -10387.307
# Method:                       css-mle   S.D. of innovations             14.638
# Date:                Thu, 18 Feb 2021   AIC                          20790.614
# Time:                        10:46:49   BIC                          20837.302
# Sample:                    07-03-2012   HQIC                         20807.554
#                          - 06-06-2019
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                     9.7273        nan        nan        nan         nan         nan
# x1                    -4.881e-05   4.89e-05     -0.998      0.318      -0.000     4.7e-05
# x2                       -2.2733        nan        nan        nan         nan         nan
# x3                       -2.2219      0.001  -2076.108      0.000      -2.224      -2.220
# x4                        0.0297      0.014      2.124      0.034       0.002       0.057
# ma.L1.D2.Accidents_Bx    -1.9432        nan        nan        nan         nan         nan
# ma.L2.D2.Accidents_Bx     0.9432        nan        nan        nan         nan         nan
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# MA.1            1.0000           +0.0000j            1.0000            0.0000
# MA.2            1.0602           +0.0000j            1.0602            0.0000
# -----------------------------------------------------------------------------
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:        D2.Accidents_Bx   No. Observations:                 2530
# Model:                 ARIMA(1, 2, 3)   Log Likelihood              -10389.164
# Method:                       css-mle   S.D. of innovations             14.653
# Date:                Thu, 18 Feb 2021   AIC                          20798.327
# Time:                        10:46:53   BIC                          20856.687
# Sample:                    07-03-2012   HQIC                         20819.502
#                          - 06-06-2019
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    12.3973        nan        nan        nan         nan         nan
# x1                     2.358e-05      0.000      0.177      0.859      -0.000       0.000
# x2                       -2.8492        nan        nan        nan         nan         nan
# x3                       -3.5057        nan        nan        nan         nan         nan
# x4                        0.0352      0.011      3.142      0.002       0.013       0.057
# ar.L1.D2.Accidents_Bx    -0.0794      0.020     -4.006      0.000      -0.118      -0.041
# ma.L1.D2.Accidents_Bx    -1.7889        nan        nan        nan         nan         nan
# ma.L2.D2.Accidents_Bx     0.6207        nan        nan        nan         nan         nan
# ma.L3.D2.Accidents_Bx     0.1683        nan        nan        nan         nan         nan
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1          -12.6000           +0.0000j           12.6000            0.5000
# MA.1            1.0034           +0.0000j            1.0034            0.0000
# MA.2            1.0342           +0.0000j            1.0342            0.0000
# MA.3           -5.7253           +0.0000j            5.7253            0.5000
# -----------------------------------------------------------------------------
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:        D2.Accidents_Bx   No. Observations:                 2530
# Model:                 ARIMA(3, 2, 3)   Log Likelihood              -10388.110
# Method:                       css-mle   S.D. of innovations             14.652
# Date:                Thu, 18 Feb 2021   AIC                          20800.220
# Time:                        10:46:57   BIC                          20870.252
# Sample:                    07-03-2012   HQIC                         20825.629
#                          - 06-06-2019
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                     6.5706        nan        nan        nan         nan         nan
# x1                        0.0003      0.000      0.782      0.434      -0.001       0.001
# x2                       -1.5992        nan        nan        nan         nan         nan
# x3                       -0.6171        nan        nan        nan         nan         nan
# x4                        0.0485      0.022      2.251      0.024       0.006       0.091
# ar.L1.D2.Accidents_Bx    -0.2262      0.023     -9.687      0.000      -0.272      -0.180
# ar.L2.D2.Accidents_Bx    -0.0839      0.029     -2.907      0.004      -0.140      -0.027
# ar.L3.D2.Accidents_Bx     0.0358      0.023      1.580      0.114      -0.009       0.080
# ma.L1.D2.Accidents_Bx    -1.6473      0.011   -153.078      0.000      -1.668      -1.626
# ma.L2.D2.Accidents_Bx     0.3748      0.033     11.474      0.000       0.311       0.439
# ma.L3.D2.Accidents_Bx     0.2728      0.029      9.441      0.000       0.216       0.329
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -1.2485           -2.0516j            2.4016           -0.3370
# AR.2           -1.2485           +2.0516j            2.4016            0.3370
# AR.3            4.8363           -0.0000j            4.8363           -0.0000
# MA.1            1.0043           +0.0000j            1.0043            0.0000
# MA.2            1.0613           +0.0000j            1.0613            0.0000
# MA.3           -3.4398           +0.0000j            3.4398            0.5000
# -----------------------------------------------------------------------------
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:        D2.Accidents_Bx   No. Observations:                 2530
# Model:                 ARIMA(1, 2, 2)   Log Likelihood              -10396.977
# Method:                       css-mle   S.D. of innovations             14.700
# Date:                Thu, 18 Feb 2021   AIC                          20811.953
# Time:                        10:47:03   BIC                          20864.477
# Sample:                    07-03-2012   HQIC                         20831.010
#                          - 06-06-2019
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    12.6011        nan        nan        nan         nan         nan
# x1                        0.0010   9.91e-05      9.725      0.000       0.001       0.001
# x2                       -2.8846        nan        nan        nan         nan         nan
# x3                       -3.7373        nan        nan        nan         nan         nan
# x4                        0.0810      0.017      4.715      0.000       0.047       0.115
# ar.L1.D2.Accidents_Bx     0.0641      0.020      3.223      0.001       0.025       0.103
# ma.L1.D2.Accidents_Bx    -1.9337      0.001  -2311.717      0.000      -1.935      -1.932
# ma.L2.D2.Accidents_Bx     0.9338      0.001   1118.603      0.000       0.932       0.935
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           15.5938           +0.0000j           15.5938            0.0000
# MA.1            1.0009           +0.0000j            1.0009            0.0000
# MA.2            1.0699           +0.0000j            1.0699            0.0000
# -----------------------------------------------------------------------------
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:        D2.Accidents_Bx   No. Observations:                 2530
# Model:                 ARIMA(3, 2, 2)   Log Likelihood              -10405.504
# Method:                       css-mle   S.D. of innovations             14.746
# Date:                Thu, 18 Feb 2021   AIC                          20833.008
# Time:                        10:47:15   BIC                          20897.204
# Sample:                    07-03-2012   HQIC                         20856.300
#                          - 06-06-2019
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                     5.0235        nan        nan        nan         nan         nan
# x1                        0.0005      0.000      1.825      0.068   -3.77e-05       0.001
# x2                       -1.0609        nan        nan        nan         nan         nan
# x3                       -2.7402        nan        nan        nan         nan         nan
# x4                        0.0574      0.021      2.737      0.006       0.016       0.099
# ar.L1.D2.Accidents_Bx     0.0845      0.020      4.252      0.000       0.046       0.123
# ar.L2.D2.Accidents_Bx    -0.1196      0.020     -6.055      0.000      -0.158      -0.081
# ar.L3.D2.Accidents_Bx     0.0862      0.020      4.341      0.000       0.047       0.125
# ma.L1.D2.Accidents_Bx    -1.9263        nan        nan        nan         nan         nan
# ma.L2.D2.Accidents_Bx     0.9263        nan        nan        nan         nan         nan
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -0.6360           -1.9893j            2.0885           -0.2992
# AR.2           -0.6360           +1.9893j            2.0885            0.2992
# AR.3            2.6592           -0.0000j            2.6592           -0.0000
# MA.1            1.0001           +0.0000j            1.0001            0.0000
# MA.2            1.0795           +0.0000j            1.0795            0.0000
# -----------------------------------------------------------------------------
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:           Accidents_Bx   No. Observations:                 2532
# Model:                     ARMA(3, 0)   Log Likelihood              -10411.151
# Method:                       css-mle   S.D. of innovations             14.771
# Date:                Thu, 18 Feb 2021   AIC                          20840.302
# Time:                        10:47:16   BIC                          20892.833
# Sample:                    07-01-2012   HQIC                         20859.361
#                          - 06-06-2019
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 71.8023      3.324     21.603      0.000      65.288      78.317
# x1                     0.0439      1.082      0.041      0.968      -2.076       2.164
# x2                     1.7817      0.122     14.548      0.000       1.542       2.022
# x3                   -11.5470      0.567    -20.382      0.000     -12.657     -10.437
# x4                   -16.2405      1.542    -10.529      0.000     -19.264     -13.217
# ar.L1.Accidents_Bx     0.3655      0.019     18.997      0.000       0.328       0.403
# ar.L2.Accidents_Bx     0.1737      0.020      8.522      0.000       0.134       0.214
# ar.L3.Accidents_Bx     0.3029      0.020     15.506      0.000       0.265       0.341
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0916           -0.0000j            1.0916           -0.0000
# AR.2           -0.8325           -1.5268j            1.7390           -0.3294
# AR.3           -0.8325           +1.5268j            1.7390            0.3294
# -----------------------------------------------------------------------------

# %% [markdown]
# We still do not see any significant p-values in any of the models above, so we will consider the model with parameters (3,1,2) to be our best ARIMAX model. We will now compare its RMSE and AIC values to our baseline ARIMA model.

# %% [markdown]
# All of the above models have very similar RMSEs. We will therefore choose our best model based on AIC, which puts parameters (1,1,3) slightly ahead of the others. We will define this as our ARIMAX model and compare it to our baseline ARIMA model.

# %%
# Define ARIMAX model
ARIMAX = sm.tsa.ARIMA(endog=y_train, exog=exog, order=(1,1,3))
ARIMAX_fit = ARIMAX.fit()
ARIMAX_pred = ARIMAX_fit.predict(start='2019-06-06', end='2020-03-13', exog = test.iloc[:,1:], dynamic=False)
ARIMAX_RMSE = RMSE(ARIMAX_pred)
ARIMAX_AIC = ARIMAX_fit.aic

# Compare ARIMA and ARIMAX model RMSEs and AICs

print('ARIMA model RMSE: ', base_RMSE)
print('ARIMA model AIC: ', base_AIC)

print('ARIMAX model RMSE: ', ARIMAX_RMSE)
print('ARIMAX model AIC: ', ARIMAX_AIC)
# Out:
# ARIMA model RMSE:  18.630368932103426
# ARIMA model AIC:  21054.375480553423
# ARIMAX model RMSE:  87.47260277112184
# ARIMAX model AIC:  20599.508870122485

# %% [markdown]
# We see from the above that though our baseline model has a worse AIC score, it performs significantly better with RMSE. Since RMSE is what tells us more clearly how far off our predictions are, we will consider this the better model.

# %% [markdown]
# ## Model #3: Introducing Seasonality: SARIMA Model

# %% [markdown]
# Or data is seasonal, so we would expect a SARIMA model to produce better results than our baseline ARIMA one.

# %% [markdown]
# **Resample Weekly Data**

# %% [markdown]
# Since data is seasonal by year, our period value would ordinarily be 365 observations. This is too large for a SARIMA model, so will create a df with weekly data and instead use a period value of 52.

# %%
# Create df of weekly data
df_bx_wk = df_bx.resample('W')
df_bx_wk_mean = df_bx_wk.mean()

# %%
# When we introduce exogenous data, the weekend column won't be valuable--remove it
df_bx_wk_mean.drop(columns=['Weekend'], inplace=True)

# Change holiday column to be a 1 if there is any holiday that week,
# ie if the value is greater than 0
df_bx_wk_mean['Holiday'] = np.where(df_bx_wk_mean['Holiday']>0, 1, 0)

# Add in Season
df_bx_wk_mean['Season'] = 0

def season(month,season):
    df_bx_wk_mean['Season'] = np.where((df_bx_wk_mean.index.month==month),
                                         season,df_bx_wk_mean['Season'])

for month in range (1,4):
    season(month,2)
    
for month in range (4,7):
    season(month,3)
    
for month in range (7,10):
    season(month,4)

for month in range (10,13):
    season(month,1)

# Holiday
df_bx_wk_mean['Holiday'] = np.where(df_bx_wk_mean['Holiday']=='0',
                                      0, df_bx_wk_mean['Holiday'])
df_bx_wk_mean['Holiday'] = np.where(df_bx_wk_mean['Holiday']=='1',
                                      1, df_bx_wk_mean['Holiday'])

# Observe new df head
df_bx_wk_mean.head()
# Out:
#             Accidents_Bx  Holiday  Season
# Date
# 2012-07-01     43.000000        0       4
# 2012-07-08     61.000000        1       4
# 2012-07-15     56.428571        0       4
# 2012-07-22     54.285714        0       4
# 2012-07-29     57.571429        0       4

# %%
# Plot weekly data compared to daily
plt.plot(df_bx['Accidents_Bx'],color='mediumseagreen', label='Original')
plt.plot(df_bx_wk_mean['Accidents_Bx'], color='mediumblue', label='Weekly Mean')
plt.legend(loc='best')
plt.title('Weekly Mean, Bronx')
plt.xlabel('Year')
plt.ylabel('Accidents')
plt.show(block=False)

# Dickey-Fuller test
test = adfuller(df_bx_wk_mean['Accidents_Bx'][:-1])
dfoutput = pd.Series(test[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
dfoutput
# Out:
# Test Statistic                  -1.402566
# p-value                          0.581045
# #Lags Used                      11.000000
# Number of Observations Used    390.000000
# dtype: float64

# %% [markdown]
# Based on the above Dickey-Fuller p-value, this data is not stationary. We will difference this data to attempt stationarity.

# %% [markdown]
# **Differencing**

# %%
# Difference data
diff = df_bx_wk_mean['Accidents_Bx'].diff()

# Plot differenced data
plt.plot(diff, color='palevioletred', label='Differenced Rolling Weekly Mean')
plt.title('Differenced Weekly Mean, Bronx')
plt.xlabel('Year')
plt.ylabel('Accidents')
plt.show(block=False)

# Dickey-Fuller test
test = adfuller(diff[1:-1])
dfoutput = pd.Series(test[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
dfoutput
# Out:
# Test Statistic                -7.673728e+00
# p-value                        1.568795e-11
# #Lags Used                     1.000000e+01
# Number of Observations Used    3.900000e+02
# dtype: float64

# %% [markdown]
# Differencing once achieved stationarity, so we would expect our SARIMA model to have a d value of at least 1.

# %% [markdown]
# **ACF, PACF for Weekly Data**

# %%
# ACF for weekly data
plot_acf(df_bx_wk_mean['Accidents_Bx'], alpha=.05);

# PACF for weekly data
plot_pacf(df_bx_wk_mean['Accidents_Bx'], alpha=.05, lags=20);

# %% [markdown]
# **Redo Train-Test Split for Weekly Data**

# %%
# Determine split point for 90%/10% train-test split
split_point = int(len(df_bx_wk_mean) * 0.9)
df_bx_wk_mean.iloc[split_point]
# Out:
# Accidents_Bx    102.857143
# Holiday           0.000000
# Season            3.000000
# Name: 2019-06-09 00:00:00, dtype: float64

# %%
# Train-test split
# Based on the above, 2019-06-06 will be the split point for our train and test sets

X = df_bx_wk_mean.index
y = df_bx_wk_mean['Accidents_Bx']

train = df_bx_wk_mean.loc[:'2019-06-06']
test = df_bx_wk_mean.loc['2019-06-06':]

X_train, X_test = train.index , test.index
y_train, y_test = train['Accidents_Bx'] , test['Accidents_Bx']

# %% [markdown]
# **Grid Search for SARIMA Model**

# %%
# Determine best parameters for SARIMA model

# Define the p, d, and q parameters to take any value between 0 and 2
# Using smaller range due to many combinations
p = d = q = range(0,2)

# Generate all different combinations of p, d, and q triplets
pdq = list(itertools.product(p,d,q))

# Generate all different combinations of seasonal p, d, q triplets
# Choose s value of 52 because data is now weekly and a cycle is one year

pdqs = [(x[0],x[1],x[2], 52) for x in pdq]

# Run a grid search with pdq parameters calculated to see corresponding AIC scores
ans_SARIMA = []
for comb in pdq:
    for combs in tqdm_notebook(pdqs):
        try:
            mod = sm.tsa.statespace.SARIMAX(y_train,
                                            order=comb,
                                            seasonal_order=combs,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False)

            output = mod.fit()
            ans_SARIMA.append([comb, combs, output.aic])
            print('ARIMA {} x {}52 : AIC Calculated ={}'.format(comb, combs, output.aic))
        except:
            continue
# Out:
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# ARIMA (0, 0, 0) x (0, 0, 0, 52)52 : AIC Calculated =4166.052236730766
# ARIMA (0, 0, 0) x (0, 0, 1, 52)52 : AIC Calculated =3312.456423713361
# ARIMA (0, 0, 0) x (0, 1, 0, 52)52 : AIC Calculated =2503.0700585025943
# ARIMA (0, 0, 0) x (0, 1, 1, 52)52 : AIC Calculated =2114.7842053443374
# ARIMA (0, 0, 0) x (1, 0, 0, 52)52 : AIC Calculated =2470.9449798999276
# ARIMA (0, 0, 0) x (1, 0, 1, 52)52 : AIC Calculated =2422.39349105962
# ARIMA (0, 0, 0) x (1, 1, 0, 52)52 : AIC Calculated =2122.875852053738
# ARIMA (0, 0, 0) x (1, 1, 1, 52)52 : AIC Calculated =2115.4491688573453
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# ARIMA (0, 0, 1) x (0, 0, 0, 52)52 : AIC Calculated =3716.637336829587
# ARIMA (0, 0, 1) x (0, 0, 1, 52)52 : AIC Calculated =2958.2649988794965
# ARIMA (0, 0, 1) x (0, 1, 0, 52)52 : AIC Calculated =2365.5612560594413
# ARIMA (0, 0, 1) x (0, 1, 1, 52)52 : AIC Calculated =1998.560664718926
# ARIMA (0, 0, 1) x (1, 0, 0, 52)52 : AIC Calculated =2362.811612263953
# ARIMA (0, 0, 1) x (1, 0, 1, 52)52 : AIC Calculated =2293.640568252208
# ARIMA (0, 0, 1) x (1, 1, 0, 52)52 : AIC Calculated =2014.27823153815
# ARIMA (0, 0, 1) x (1, 1, 1, 52)52 : AIC Calculated =2000.560538890241
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# ARIMA (0, 1, 0) x (0, 0, 0, 52)52 : AIC Calculated =2548.1594914058614
# ARIMA (0, 1, 0) x (0, 0, 1, 52)52 : AIC Calculated =2194.8276126831865
# ARIMA (0, 1, 0) x (0, 1, 0, 52)52 : AIC Calculated =2318.43586470452
# ARIMA (0, 1, 0) x (0, 1, 1, 52)52 : AIC Calculated =1861.7727802394272
# ARIMA (0, 1, 0) x (1, 0, 0, 52)52 : AIC Calculated =2196.1106664704785
# ARIMA (0, 1, 0) x (1, 0, 1, 52)52 : AIC Calculated =2191.3180933017247
# ARIMA (0, 1, 0) x (1, 1, 0, 52)52 : AIC Calculated =1898.3974484326195
# ARIMA (0, 1, 0) x (1, 1, 1, 52)52 : AIC Calculated =1871.221915610396
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# ARIMA (0, 1, 1) x (0, 0, 0, 52)52 : AIC Calculated =2429.060254377212
# ARIMA (0, 1, 1) x (0, 0, 1, 52)52 : AIC Calculated =2092.9013674846256
# ARIMA (0, 1, 1) x (0, 1, 0, 52)52 : AIC Calculated =2215.8778542739683
# ARIMA (0, 1, 1) x (0, 1, 1, 52)52 : AIC Calculated =1766.0336345933292
# ARIMA (0, 1, 1) x (1, 0, 0, 52)52 : AIC Calculated =2101.001558286274
# ARIMA (0, 1, 1) x (1, 0, 1, 52)52 : AIC Calculated =2089.6226737129596
# ARIMA (0, 1, 1) x (1, 1, 0, 52)52 : AIC Calculated =1817.390955075846
# ARIMA (0, 1, 1) x (1, 1, 1, 52)52 : AIC Calculated =1783.1929065051615
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# ARIMA (1, 0, 0) x (0, 0, 0, 52)52 : AIC Calculated =2560.3107479183673
# ARIMA (1, 0, 0) x (0, 0, 1, 52)52 : AIC Calculated =2202.410246319459
# ARIMA (1, 0, 0) x (0, 1, 0, 52)52 : AIC Calculated =2281.2582627321576
# ARIMA (1, 0, 0) x (0, 1, 1, 52)52 : AIC Calculated =1861.0621371330942
# ARIMA (1, 0, 0) x (1, 0, 0, 52)52 : AIC Calculated =2196.933591769614
# ARIMA (1, 0, 0) x (1, 0, 1, 52)52 : AIC Calculated =2215.8982314552577
# ARIMA (1, 0, 0) x (1, 1, 0, 52)52 : AIC Calculated =1879.0589305984918
# ARIMA (1, 0, 0) x (1, 1, 1, 52)52 : AIC Calculated =1863.0228942591796
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# ARIMA (1, 0, 1) x (0, 0, 0, 52)52 : AIC Calculated =2436.95548855167
# ARIMA (1, 0, 1) x (0, 0, 1, 52)52 : AIC Calculated =2100.9603150092953
# ARIMA (1, 0, 1) x (0, 1, 0, 52)52 : AIC Calculated =2223.0516267687926
# ARIMA (1, 0, 1) x (0, 1, 1, 52)52 : AIC Calculated =1773.7028850519891
# ARIMA (1, 0, 1) x (1, 0, 0, 52)52 : AIC Calculated =2102.8273417841647
# ARIMA (1, 0, 1) x (1, 0, 1, 52)52 : AIC Calculated =2097.7514853636894
# ARIMA (1, 0, 1) x (1, 1, 0, 52)52 : AIC Calculated =1818.7484054233446
# ARIMA (1, 0, 1) x (1, 1, 1, 52)52 : AIC Calculated =1790.6888324048691
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# ARIMA (1, 1, 0) x (0, 0, 0, 52)52 : AIC Calculated =2500.65526190929
# ARIMA (1, 1, 0) x (0, 0, 1, 52)52 : AIC Calculated =2155.977294143926
# ARIMA (1, 1, 0) x (0, 1, 0, 52)52 : AIC Calculated =2283.3997773411875
# ARIMA (1, 1, 0) x (0, 1, 1, 52)52 : AIC Calculated =1825.9080758775501
# ARIMA (1, 1, 0) x (1, 0, 0, 52)52 : AIC Calculated =2151.9418989352416
# ARIMA (1, 1, 0) x (1, 0, 1, 52)52 : AIC Calculated =2153.000519401051
# ARIMA (1, 1, 0) x (1, 1, 0, 52)52 : AIC Calculated =1854.7864026439765
# ARIMA (1, 1, 0) x (1, 1, 1, 52)52 : AIC Calculated =1836.9695421593465
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# ARIMA (1, 1, 1) x (0, 0, 0, 52)52 : AIC Calculated =2423.711013494717
# ARIMA (1, 1, 1) x (0, 0, 1, 52)52 : AIC Calculated =2086.978805572883
# ARIMA (1, 1, 1) x (0, 1, 0, 52)52 : AIC Calculated =2204.772088351596
# ARIMA (1, 1, 1) x (0, 1, 1, 52)52 : AIC Calculated =1762.57163655478
# ARIMA (1, 1, 1) x (1, 0, 0, 52)52 : AIC Calculated =2088.125778337351
# ARIMA (1, 1, 1) x (1, 0, 1, 52)52 : AIC Calculated =2082.6031795890003
# ARIMA (1, 1, 1) x (1, 1, 0, 52)52 : AIC Calculated =1800.0017694178853
# ARIMA (1, 1, 1) x (1, 1, 1, 52)52 : AIC Calculated =1764.5711970211187

# %%
# Find parameters with minimal AIC value
SARIMA_AIC = pd.DataFrame(ans_SARIMA, columns=['pdq', 'pdqs', 'aic'])
SARIMA_AIC.sort_values(by='aic', ascending=True, inplace=True)
SARIMA_AIC[:10]
# Out:
#           pdq           pdqs          aic
# 59  (1, 1, 1)  (0, 1, 1, 52)  1762.571637
# 63  (1, 1, 1)  (1, 1, 1, 52)  1764.571197
# 27  (0, 1, 1)  (0, 1, 1, 52)  1766.033635
# 43  (1, 0, 1)  (0, 1, 1, 52)  1773.702885
# 31  (0, 1, 1)  (1, 1, 1, 52)  1783.192907
# 47  (1, 0, 1)  (1, 1, 1, 52)  1790.688832
# 62  (1, 1, 1)  (1, 1, 0, 52)  1800.001769
# 30  (0, 1, 1)  (1, 1, 0, 52)  1817.390955
# 46  (1, 0, 1)  (1, 1, 0, 52)  1818.748405
# 51  (1, 1, 0)  (0, 1, 1, 52)  1825.908076

# %% [markdown]
# **Narrowing Down Parameter Values**

# %% [markdown]
# Observe lowest 10 AIC score parameter values to determine best model. Make sure p values are significant, and observe RMSEs to determind best overall model.

# %%
for index,row in SARIMA_AIC[:10].iterrows():
    mod = sm.tsa.statespace.SARIMAX(y_train,
                                    order=SARIMA_AIC['pdq'][index],
                                    seasonal_order=SARIMA_AIC['pdqs'][index],
                                    enforce_stationarity=False,
                                    enforce_invertibility=False)

    mod_fit = mod.fit()
    print(mod_fit.summary())
# Out:
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                       Accidents_Bx   No. Observations:                  362
# Model:             SARIMAX(1, 1, 1)x(0, 1, 1, 52)   Log Likelihood                -877.286
# Date:                            Thu, 18 Feb 2021   AIC                           1762.572
# Time:                                    11:02:26   BIC                           1776.737
# Sample:                                07-01-2012   HQIC                          1768.269
#                                      - 06-02-2019
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.1747      0.070      2.496      0.013       0.038       0.312
# ma.L1         -0.8388      0.042    -20.044      0.000      -0.921      -0.757
# ma.S.L52      -0.7232      0.079     -9.119      0.000      -0.879      -0.568
# sigma2        53.5240      4.850     11.036      0.000      44.018      63.030
# ===================================================================================
# Ljung-Box (Q):                       40.76   Jarque-Bera (JB):                 1.96
# Prob(Q):                              0.44   Prob(JB):                         0.38
# Heteroskedasticity (H):               0.96   Skew:                             0.19
# Prob(H) (two-sided):                  0.86   Kurtosis:                         3.18
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                       Accidents_Bx   No. Observations:                  362
# Model:             SARIMAX(1, 1, 1)x(1, 1, 1, 52)   Log Likelihood                -877.286
# Date:                            Thu, 18 Feb 2021   AIC                           1764.571
# Time:                                    11:02:38   BIC                           1782.278
# Sample:                                07-01-2012   HQIC                          1771.693
#                                      - 06-02-2019
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.1747      0.070      2.491      0.013       0.037       0.312
# ma.L1         -0.8388      0.043    -19.706      0.000      -0.922      -0.755
# ar.S.L52   -3.548e-05      0.088     -0.000      1.000      -0.173       0.173
# ma.S.L52      -0.7231      0.109     -6.662      0.000      -0.936      -0.510
# sigma2        53.5294      4.975     10.759      0.000      43.778      63.281
# ===================================================================================
# Ljung-Box (Q):                       40.76   Jarque-Bera (JB):                 1.96
# Prob(Q):                              0.44   Prob(JB):                         0.38
# Heteroskedasticity (H):               0.96   Skew:                             0.19
# Prob(H) (two-sided):                  0.86   Kurtosis:                         3.18
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                       Accidents_Bx   No. Observations:                  362
# Model:             SARIMAX(0, 1, 1)x(0, 1, 1, 52)   Log Likelihood                -880.017
# Date:                            Thu, 18 Feb 2021   AIC                           1766.034
# Time:                                    11:02:42   BIC                           1776.657
# Sample:                                07-01-2012   HQIC                          1770.307
#                                      - 06-02-2019
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.7819      0.033    -23.557      0.000      -0.847      -0.717
# ma.S.L52      -0.7458      0.083     -9.028      0.000      -0.908      -0.584
# sigma2        54.2015      4.888     11.089      0.000      44.621      63.782
# ===================================================================================
# Ljung-Box (Q):                       47.22   Jarque-Bera (JB):                 2.85
# Prob(Q):                              0.20   Prob(JB):                         0.24
# Heteroskedasticity (H):               1.06   Skew:                             0.23
# Prob(H) (two-sided):                  0.80   Kurtosis:                         3.24
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                       Accidents_Bx   No. Observations:                  362
# Model:             SARIMAX(1, 0, 1)x(0, 1, 1, 52)   Log Likelihood                -882.851
# Date:                            Thu, 18 Feb 2021   AIC                           1773.703
# Time:                                    11:02:50   BIC                           1787.884
# Sample:                                07-01-2012   HQIC                          1779.406
#                                      - 06-02-2019
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9959      0.005    181.338      0.000       0.985       1.007
# ma.L1         -0.7783      0.034    -22.844      0.000      -0.845      -0.712
# ma.S.L52      -0.7440      0.086     -8.696      0.000      -0.912      -0.576
# sigma2        53.9456      4.911     10.985      0.000      44.320      63.571
# ===================================================================================
# Ljung-Box (Q):                       48.09   Jarque-Bera (JB):                 2.90
# Prob(Q):                              0.18   Prob(JB):                         0.23
# Heteroskedasticity (H):               1.05   Skew:                             0.23
# Prob(H) (two-sided):                  0.83   Kurtosis:                         3.25
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                       Accidents_Bx   No. Observations:                  362
# Model:             SARIMAX(0, 1, 1)x(1, 1, 1, 52)   Log Likelihood                -887.596
# Date:                            Thu, 18 Feb 2021   AIC                           1783.193
# Time:                                    11:02:56   BIC                           1797.358
# Sample:                                07-01-2012   HQIC                          1788.891
#                                      - 06-02-2019
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.7671      0.034    -22.791      0.000      -0.833      -0.701
# ar.S.L52      -0.2304      0.092     -2.509      0.012      -0.410      -0.050
# ma.S.L52      -0.5105      0.105     -4.853      0.000      -0.717      -0.304
# sigma2        58.1772      5.203     11.182      0.000      47.980      68.374
# ===================================================================================
# Ljung-Box (Q):                       41.98   Jarque-Bera (JB):                 2.19
# Prob(Q):                              0.39   Prob(JB):                         0.33
# Heteroskedasticity (H):               1.01   Skew:                             0.20
# Prob(H) (two-sided):                  0.95   Kurtosis:                         3.22
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                       Accidents_Bx   No. Observations:                  362
# Model:             SARIMAX(1, 0, 1)x(1, 1, 1, 52)   Log Likelihood                -890.344
# Date:                            Thu, 18 Feb 2021   AIC                           1790.689
# Time:                                    11:03:08   BIC                           1808.415
# Sample:                                07-01-2012   HQIC                          1797.818
#                                      - 06-02-2019
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9948      0.006    156.374      0.000       0.982       1.007
# ma.L1         -0.7611      0.035    -21.512      0.000      -0.830      -0.692
# ar.S.L52      -0.2267      0.092     -2.462      0.014      -0.407      -0.046
# ma.S.L52      -0.5142      0.107     -4.784      0.000      -0.725      -0.304
# sigma2        57.7308      5.179     11.147      0.000      47.580      67.881
# ===================================================================================
# Ljung-Box (Q):                       41.79   Jarque-Bera (JB):                 2.32
# Prob(Q):                              0.39   Prob(JB):                         0.31
# Heteroskedasticity (H):               1.01   Skew:                             0.20
# Prob(H) (two-sided):                  0.95   Kurtosis:                         3.24
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                        Accidents_Bx   No. Observations:                  362
# Model:             SARIMAX(1, 1, 1)x(1, 1, [], 52)   Log Likelihood                -896.001
# Date:                             Thu, 18 Feb 2021   AIC                           1800.002
# Time:                                     11:03:12   BIC                           1814.182
# Sample:                                 07-01-2012   HQIC                          1805.705
#                                       - 06-02-2019
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.2114      0.073      2.910      0.004       0.069       0.354
# ma.L1         -0.8480      0.040    -20.991      0.000      -0.927      -0.769
# ar.S.L52      -0.4751      0.057     -8.320      0.000      -0.587      -0.363
# sigma2        64.0671      5.392     11.881      0.000      53.498      74.636
# ===================================================================================
# Ljung-Box (Q):                       37.49   Jarque-Bera (JB):                 0.60
# Prob(Q):                              0.58   Prob(JB):                         0.74
# Heteroskedasticity (H):               0.97   Skew:                             0.02
# Prob(H) (two-sided):                  0.89   Kurtosis:                         3.24
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                        Accidents_Bx   No. Observations:                  362
# Model:             SARIMAX(0, 1, 1)x(1, 1, [], 52)   Log Likelihood                -905.695
# Date:                             Thu, 18 Feb 2021   AIC                           1817.391
# Time:                                     11:03:15   BIC                           1828.038
# Sample:                                 07-01-2012   HQIC                          1821.673
#                                       - 06-02-2019
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.7830      0.034    -23.237      0.000      -0.849      -0.717
# ar.S.L52      -0.4729      0.056     -8.451      0.000      -0.583      -0.363
# sigma2        67.1293      5.590     12.010      0.000      56.174      78.085
# ===================================================================================
# Ljung-Box (Q):                       45.38   Jarque-Bera (JB):                 0.68
# Prob(Q):                              0.26   Prob(JB):                         0.71
# Heteroskedasticity (H):               0.98   Skew:                             0.01
# Prob(H) (two-sided):                  0.94   Kurtosis:                         3.25
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                        Accidents_Bx   No. Observations:                  362
# Model:             SARIMAX(1, 0, 1)x(1, 1, [], 52)   Log Likelihood                -905.374
# Date:                             Thu, 18 Feb 2021   AIC                           1818.748
# Time:                                     11:03:19   BIC                           1832.945
# Sample:                                 07-01-2012   HQIC                          1824.457
#                                       - 06-02-2019
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9936      0.008    130.138      0.000       0.979       1.009
# ma.L1         -0.7746      0.036    -21.320      0.000      -0.846      -0.703
# ar.S.L52      -0.4726      0.056     -8.405      0.000      -0.583      -0.362
# sigma2        66.9532      5.582     11.994      0.000      56.012      77.894
# ===================================================================================
# Ljung-Box (Q):                       45.34   Jarque-Bera (JB):                 0.64
# Prob(Q):                              0.26   Prob(JB):                         0.73
# Heteroskedasticity (H):               0.97   Skew:                             0.01
# Prob(H) (two-sided):                  0.90   Kurtosis:                         3.24
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                         Accidents_Bx   No. Observations:                  362
# Model:             SARIMAX(1, 1, 0)x(0, 1, [1], 52)   Log Likelihood                -909.954
# Date:                              Thu, 18 Feb 2021   AIC                           1825.908
# Time:                                      11:03:23   BIC                           1836.544
# Sample:                                  07-01-2012   HQIC                          1830.186
#                                        - 06-02-2019
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.3579      0.046     -7.769      0.000      -0.448      -0.268
# ma.S.L52      -0.7130      0.074     -9.587      0.000      -0.859      -0.567
# sigma2        67.5145      5.755     11.730      0.000      56.234      78.795
# ===================================================================================
# Ljung-Box (Q):                       82.66   Jarque-Bera (JB):                 3.19
# Prob(Q):                              0.00   Prob(JB):                         0.20
# Heteroskedasticity (H):               0.85   Skew:                             0.01
# Prob(H) (two-sided):                  0.47   Kurtosis:                         3.55
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# Based on the above, we see that the following parameters yield significant p-values:
#
# (1,1,1)x(0,1,1,52)
#
# (0,1,1)x(0,1,1,52)
#
# (1,0,1)x(0,1,1,52)
#
# (0,1,1)x(1,1,1,52)
#
# (1,0,1)x(1,1,1,52)
#
# (1,1,1)x(1,1,0,52)
#
# (0,1,1)x(1,1,0,52)
#
# (1,0,1)x(1,1,0,52)
#
# (1,1,0)x(0,1,1,52)
#
# We wil observe RMSE and AIC values for these parameters to determine our best working model.

# %%
# For loop to apply RMSE function to significant parameters
for (pdq,pdqs) in [((1,1,1),(0,1,1,52)),((0,1,1),(0,1,1,52)),((1,0,1),(0,1,1,52)),((0,1,1),(1,1,1,52)),
                  ((1,0,1),(1,1,1,52)),((1,1,1),(1,1,0,52)),((0,1,1),(1,1,0,52)),((1,0,1),(1,1,0,52)),
                  ((1,1,0),(0,1,1,52))]:
    mod = sm.tsa.statespace.SARIMAX(y_train,
                                    order=pdq,
                                    seasonal_order=pdqs,
                                    enforce_stationarity=False,
                                    enforce_invertibility=False)
    mod_fit = mod.fit()
    mod_pred = mod_fit.predict(start='2019-06-06', end='2020-03-13',dynamic=False)
    print(pdq, 'x', pdqs,': RMSE: ', RMSE(mod_pred), 'AIC: ', mod_fit.aic)
# Out:
# (1, 1, 1) x (0, 1, 1, 52) : RMSE:  8.027410017541705 AIC:  1762.57163655478
# (0, 1, 1) x (0, 1, 1, 52) : RMSE:  8.022815458095188 AIC:  1766.0336345933292
# (1, 0, 1) x (0, 1, 1, 52) : RMSE:  7.6004180853405465 AIC:  1773.7028850519891
# (0, 1, 1) x (1, 1, 1, 52) : RMSE:  7.89376965193364 AIC:  1783.1929065051615
# (1, 0, 1) x (1, 1, 1, 52) : RMSE:  7.800584347734421 AIC:  1790.6888324048691
# (1, 1, 1) x (1, 1, 0, 52) : RMSE:  7.159588027079446 AIC:  1800.0017694178853
# (0, 1, 1) x (1, 1, 0, 52) : RMSE:  7.11405578357931 AIC:  1817.390955075846
# (1, 0, 1) x (1, 1, 0, 52) : RMSE:  7.44956461116976 AIC:  1818.7484054233446
# (1, 1, 0) x (0, 1, 1, 52) : RMSE:  8.140771140404324 AIC:  1825.9080758775501

# %% [markdown]
# Based on its best RMSE value and only slightly worse AIC value, we see that parameters (0,1,1) x (1,1,0) gives us our best SARIMA model. We will define this as our SARIMA model and compare it to our baseline ARIMA model.
#
# In order to compare RMSEs between daily and weekly data, we will divide RMSEs by the range of the number of accidents in each dataset. A smaller RMSE-to-range ratio will tell us which is our better RMSE. These will be labeled "Adjusted RMSE".

# %%
SARIMA = sm.tsa.statespace.SARIMAX(y_train,
                                   order=(0,1,1),
                                   seasonal_order=(1,1,0,52),
                                   enforce_stationarity=False,
                                   enforce_invertibility=False)
SARIMA_fit = SARIMA.fit()
SARIMA_pred = SARIMA_fit.predict(start='2019-06-06', end='2020-03-13',dynamic=False)
print('SARIMA RMSE: ', RMSE(SARIMA_pred))
print('Adjusted SARIMA RMSE: ',
      RMSE(SARIMA_pred)/(df_bx_wk_mean['Accidents_Bx'].max()-df_bx_wk_mean['Accidents_Bx'].min()))
print('SARIMA AIC: ', SARIMA_fit.aic)

print('ARIMA RMSE: ', base_RMSE)
print('Adjusted ARIMA RMSE: ',
      base_RMSE/(df_bx['Accidents_Bx'].max()-df_bx['Accidents_Bx'].min()))
print('ARIMA AIC: ', base_AIC)
# Out:
# SARIMA RMSE:  7.11405578357931
# Adjusted SARIMA RMSE:  0.08571151546481097
# SARIMA AIC:  1817.390955075846
# ARIMA RMSE:  18.630368932103426
# Adjusted ARIMA RMSE:  0.0917752164143026
# ARIMA AIC:  21054.375480553423

# %% [markdown]
# It is hard to determine which of the above models is better. Before narrowing down between these, let's take a look at a SARIMAX model to add into the mix.

# %% [markdown]
# ## Model #4: Incorporating Both Exogenous and Seasonal Variables: SARIMAX Model

# %% [markdown]
# Attempting a SARIMAX model incorporating both holiday and season variables as exogenous data did not yield any usable models. The p-value associated with "season" were consistently extremely high. Therefore re-ran only incorporating holiday as the exogenous variable. Other exogenous variables used in the earlier ARIMAX model are not replicable on a weekly basis.

# %% [markdown]
# **Grid Search**

# %%
# Determine best parameters for SARIMAX model
# Define the p, d, and q parameters to take any value between 0 and 2
p = d = q = range(0,2)

# Generate all different combinations of p, d, and q triplets
pdq = list(itertools.product(p,d,q))

# Generate all different combinations of seasonal p, d, q triplets
# Choose s value of 365 because data is daily and a cycle is one year

pdqs = [(x[0],x[1],x[2], 52) for x in pdq]

# Run a grid search with pdq parameters calculated to see corresponding AIC scores
ans_SARIMAX = []
for comb in pdq:
    for combs in tqdm_notebook(pdqs):
        try:
            mod = sm.tsa.statespace.SARIMAX(y_train,
                                            exog = train.iloc[:,1],
                                            order=comb,
                                            seasonal_order=combs,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False)

            output = mod.fit()
            ans_SARIMAX.append([comb, combs, output.aic])
            print('SARIMAX {} x {}52 : AIC Calculated ={}'.format(comb, combs, output.aic))
        except:
            continue
# Out:
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# SARIMAX (0, 0, 0) x (0, 0, 0, 52)52 : AIC Calculated =4109.9177328505675
# SARIMAX (0, 0, 0) x (0, 0, 1, 52)52 : AIC Calculated =3290.2292617639887
# SARIMAX (0, 0, 0) x (0, 1, 0, 52)52 : AIC Calculated =2499.994114171451
# SARIMAX (0, 0, 0) x (0, 1, 1, 52)52 : AIC Calculated =2111.3813463415945
# SARIMAX (0, 0, 0) x (1, 0, 0, 52)52 : AIC Calculated =2466.7086414505525
# SARIMAX (0, 0, 0) x (1, 0, 1, 52)52 : AIC Calculated =2458.366996267248
# SARIMAX (0, 0, 0) x (1, 1, 0, 52)52 : AIC Calculated =2119.611898509901
# SARIMAX (0, 0, 0) x (1, 1, 1, 52)52 : AIC Calculated =2112.2818611255443
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# SARIMAX (0, 0, 1) x (0, 0, 0, 52)52 : AIC Calculated =3716.5175755771634
# SARIMAX (0, 0, 1) x (0, 0, 1, 52)52 : AIC Calculated =2960.1919348962792
# SARIMAX (0, 0, 1) x (0, 1, 0, 52)52 : AIC Calculated =2360.9832123313026
# SARIMAX (0, 0, 1) x (0, 1, 1, 52)52 : AIC Calculated =1993.2794137061715
# SARIMAX (0, 0, 1) x (1, 0, 0, 52)52 : AIC Calculated =2357.37041797938
# SARIMAX (0, 0, 1) x (1, 0, 1, 52)52 : AIC Calculated =2342.5690882108916
# SARIMAX (0, 0, 1) x (1, 1, 0, 52)52 : AIC Calculated =2008.7865848124925
# SARIMAX (0, 0, 1) x (1, 1, 1, 52)52 : AIC Calculated =1993.0117423416273
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# SARIMAX (0, 1, 0) x (0, 0, 0, 52)52 : AIC Calculated =2506.990980953385
# SARIMAX (0, 1, 0) x (0, 0, 1, 52)52 : AIC Calculated =2160.0783881774123
# SARIMAX (0, 1, 0) x (0, 1, 0, 52)52 : AIC Calculated =2306.584336669189
# SARIMAX (0, 1, 0) x (0, 1, 1, 52)52 : AIC Calculated =1836.6425456616075
# SARIMAX (0, 1, 0) x (1, 0, 0, 52)52 : AIC Calculated =2163.3534649163357
# SARIMAX (0, 1, 0) x (1, 0, 1, 52)52 : AIC Calculated =2157.508543898404
# SARIMAX (0, 1, 0) x (1, 1, 0, 52)52 : AIC Calculated =1881.412983472447
# SARIMAX (0, 1, 0) x (1, 1, 1, 52)52 : AIC Calculated =1846.4621062386145
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# SARIMAX (0, 1, 1) x (0, 0, 0, 52)52 : AIC Calculated =2394.8440161620647
# SARIMAX (0, 1, 1) x (0, 0, 1, 52)52 : AIC Calculated =2065.2841401021324
# SARIMAX (0, 1, 1) x (0, 1, 0, 52)52 : AIC Calculated =2202.9790631715923
# SARIMAX (0, 1, 1) x (0, 1, 1, 52)52 : AIC Calculated =1743.2791285730564
# SARIMAX (0, 1, 1) x (1, 0, 0, 52)52 : AIC Calculated =2074.560558772775
# SARIMAX (0, 1, 1) x (1, 0, 1, 52)52 : AIC Calculated =2062.8888485761636
# SARIMAX (0, 1, 1) x (1, 1, 0, 52)52 : AIC Calculated =1802.511990214743
# SARIMAX (0, 1, 1) x (1, 1, 1, 52)52 : AIC Calculated =1762.9166236919623
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# SARIMAX (1, 0, 0) x (0, 0, 0, 52)52 : AIC Calculated =2523.0326415592635
# SARIMAX (1, 0, 0) x (0, 0, 1, 52)52 : AIC Calculated =2169.132563963221
# SARIMAX (1, 0, 0) x (0, 1, 0, 52)52 : AIC Calculated =2270.8853003675436
# SARIMAX (1, 0, 0) x (0, 1, 1, 52)52 : AIC Calculated =1838.7727222621418
# SARIMAX (1, 0, 0) x (1, 0, 0, 52)52 : AIC Calculated =2164.6057745151093
# SARIMAX (1, 0, 0) x (1, 0, 1, 52)52 : AIC Calculated =2195.7204013414103
# SARIMAX (1, 0, 0) x (1, 1, 0, 52)52 : AIC Calculated =1863.6862920876456
# SARIMAX (1, 0, 0) x (1, 1, 1, 52)52 : AIC Calculated =1848.1433619603852
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# SARIMAX (1, 0, 1) x (0, 0, 0, 52)52 : AIC Calculated =2633.142844722423
# SARIMAX (1, 0, 1) x (0, 0, 1, 52)52 : AIC Calculated =2074.614330077584
# SARIMAX (1, 0, 1) x (0, 1, 0, 52)52 : AIC Calculated =2210.0977684504724
# SARIMAX (1, 0, 1) x (0, 1, 1, 52)52 : AIC Calculated =1750.9036356156705
# SARIMAX (1, 0, 1) x (1, 0, 0, 52)52 : AIC Calculated =2076.330777129919
# SARIMAX (1, 0, 1) x (1, 0, 1, 52)52 : AIC Calculated =2192.615965188771
# SARIMAX (1, 0, 1) x (1, 1, 0, 52)52 : AIC Calculated =1803.8559000648872
# SARIMAX (1, 0, 1) x (1, 1, 1, 52)52 : AIC Calculated =1770.2874503714258
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# SARIMAX (1, 1, 0) x (0, 0, 0, 52)52 : AIC Calculated =2458.798382085346
# SARIMAX (1, 1, 0) x (0, 0, 1, 52)52 : AIC Calculated =2122.7310326355932
# SARIMAX (1, 1, 0) x (0, 1, 0, 52)52 : AIC Calculated =2270.4694652325497
# SARIMAX (1, 1, 0) x (0, 1, 1, 52)52 : AIC Calculated =1800.129012013745
# SARIMAX (1, 1, 0) x (1, 0, 0, 52)52 : AIC Calculated =2119.985865561414
# SARIMAX (1, 1, 0) x (1, 0, 1, 52)52 : AIC Calculated =2121.029916220174
# SARIMAX (1, 1, 0) x (1, 1, 0, 52)52 : AIC Calculated =1838.092571489015
# SARIMAX (1, 1, 0) x (1, 1, 1, 52)52 : AIC Calculated =1813.980621248922
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# SARIMAX (1, 1, 1) x (0, 0, 0, 52)52 : AIC Calculated =2388.4913294850603
# SARIMAX (1, 1, 1) x (0, 0, 1, 52)52 : AIC Calculated =2058.1798416618776
# SARIMAX (1, 1, 1) x (0, 1, 0, 52)52 : AIC Calculated =2192.91465171497
# SARIMAX (1, 1, 1) x (0, 1, 1, 52)52 : AIC Calculated =1739.9447337155375
# SARIMAX (1, 1, 1) x (1, 0, 0, 52)52 : AIC Calculated =2061.104194844236
# SARIMAX (1, 1, 1) x (1, 0, 1, 52)52 : AIC Calculated =2054.7963755487385
# SARIMAX (1, 1, 1) x (1, 1, 0, 52)52 : AIC Calculated =1784.788603534675
# SARIMAX (1, 1, 1) x (1, 1, 1, 52)52 : AIC Calculated =1741.9442255726135

# %%
# Find parameters with minimal AIC value
SARIMAX_AIC = pd.DataFrame(ans_SARIMAX, columns=['pdq', 'pdqs', 'aic'])
SARIMAX_AIC.sort_values(by='aic', ascending=True, inplace=True)
SARIMAX_AIC[:10]
# Out:
#           pdq           pdqs          aic
# 59  (1, 1, 1)  (0, 1, 1, 52)  1739.944734
# 63  (1, 1, 1)  (1, 1, 1, 52)  1741.944226
# 27  (0, 1, 1)  (0, 1, 1, 52)  1743.279129
# 43  (1, 0, 1)  (0, 1, 1, 52)  1750.903636
# 31  (0, 1, 1)  (1, 1, 1, 52)  1762.916624
# 47  (1, 0, 1)  (1, 1, 1, 52)  1770.287450
# 62  (1, 1, 1)  (1, 1, 0, 52)  1784.788604
# 51  (1, 1, 0)  (0, 1, 1, 52)  1800.129012
# 30  (0, 1, 1)  (1, 1, 0, 52)  1802.511990
# 46  (1, 0, 1)  (1, 1, 0, 52)  1803.855900

# %% [markdown]
# **Narrowing Down Model Parameters**

# %% [markdown]
# Observe lowest 10 AIC score parameter values to determine best model. Make sure p values are significant, and observe RMSEs to determind best overall model.

# %%
for index,row in SARIMAX_AIC[:10].iterrows():
    mod = sm.tsa.statespace.SARIMAX(y_train,
                                    exog = train.iloc[:,1],
                                    order=SARIMAX_AIC['pdq'][index],
                                    seasonal_order=SARIMAX_AIC['pdqs'][index],
                                    enforce_stationarity=False,
                                    enforce_invertibility=False)

    
    
    mod_fit = mod.fit()
    print(mod_fit.summary())
# Out:
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                       Accidents_Bx   No. Observations:                  362
# Model:             SARIMAX(1, 1, 1)x(0, 1, 1, 52)   Log Likelihood                -864.972
# Date:                            Thu, 18 Feb 2021   AIC                           1739.945
# Time:                                    11:57:40   BIC                           1757.651
# Sample:                                07-01-2012   HQIC                          1747.067
#                                      - 06-02-2019
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Holiday       -6.0997      1.249     -4.883      0.000      -8.548      -3.652
# ar.L1          0.1771      0.071      2.503      0.012       0.038       0.316
# ma.L1         -0.8292      0.044    -18.735      0.000      -0.916      -0.742
# ma.S.L52      -0.7993      0.113     -7.078      0.000      -1.021      -0.578
# sigma2        46.9536      4.908      9.566      0.000      37.333      56.574
# ===================================================================================
# Ljung-Box (Q):                       47.83   Jarque-Bera (JB):                 2.65
# Prob(Q):                              0.18   Prob(JB):                         0.27
# Heteroskedasticity (H):               0.81   Skew:                             0.17
# Prob(H) (two-sided):                  0.32   Kurtosis:                         3.36
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                       Accidents_Bx   No. Observations:                  362
# Model:             SARIMAX(1, 1, 1)x(1, 1, 1, 52)   Log Likelihood                -864.972
# Date:                            Thu, 18 Feb 2021   AIC                           1741.944
# Time:                                    11:57:57   BIC                           1763.192
# Sample:                                07-01-2012   HQIC                          1750.491
#                                      - 06-02-2019
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Holiday       -6.0993      1.251     -4.874      0.000      -8.552      -3.647
# ar.L1          0.1771      0.071      2.502      0.012       0.038       0.316
# ma.L1         -0.8292      0.045    -18.274      0.000      -0.918      -0.740
# ar.S.L52   -4.129e-05      0.077     -0.001      1.000      -0.150       0.150
# ma.S.L52      -0.7992      0.136     -5.896      0.000      -1.065      -0.534
# sigma2        46.9548      5.123      9.165      0.000      36.913      56.996
# ===================================================================================
# Ljung-Box (Q):                       47.83   Jarque-Bera (JB):                 2.65
# Prob(Q):                              0.18   Prob(JB):                         0.27
# Heteroskedasticity (H):               0.81   Skew:                             0.17
# Prob(H) (two-sided):                  0.32   Kurtosis:                         3.36
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                       Accidents_Bx   No. Observations:                  362
# Model:             SARIMAX(0, 1, 1)x(0, 1, 1, 52)   Log Likelihood                -867.640
# Date:                            Thu, 18 Feb 2021   AIC                           1743.279
# Time:                                    11:58:06   BIC                           1757.444
# Sample:                                07-01-2012   HQIC                          1748.977
#                                      - 06-02-2019
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Holiday       -6.4267      1.270     -5.059      0.000      -8.917      -3.937
# ma.L1         -0.7655      0.036    -21.510      0.000      -0.835      -0.696
# ma.S.L52      -0.8310      0.129     -6.423      0.000      -1.085      -0.577
# sigma2        47.0921      5.471      8.608      0.000      36.369      57.815
# ===================================================================================
# Ljung-Box (Q):                       55.04   Jarque-Bera (JB):                 3.06
# Prob(Q):                              0.06   Prob(JB):                         0.22
# Heteroskedasticity (H):               0.88   Skew:                             0.22
# Prob(H) (two-sided):                  0.57   Kurtosis:                         3.32
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                       Accidents_Bx   No. Observations:                  362
# Model:             SARIMAX(1, 0, 1)x(0, 1, 1, 52)   Log Likelihood                -870.452
# Date:                            Thu, 18 Feb 2021   AIC                           1750.904
# Time:                                    11:58:18   BIC                           1768.630
# Sample:                                07-01-2012   HQIC                          1758.033
#                                      - 06-02-2019
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Holiday       -6.4224      1.279     -5.021      0.000      -8.929      -3.915
# ar.L1          0.9961      0.005    183.119      0.000       0.985       1.007
# ma.L1         -0.7622      0.036    -20.974      0.000      -0.833      -0.691
# ma.S.L52      -0.8282      0.132     -6.297      0.000      -1.086      -0.570
# sigma2        46.9196      5.512      8.512      0.000      36.115      57.724
# ===================================================================================
# Ljung-Box (Q):                       56.26   Jarque-Bera (JB):                 3.00
# Prob(Q):                              0.05   Prob(JB):                         0.22
# Heteroskedasticity (H):               0.88   Skew:                             0.21
# Prob(H) (two-sided):                  0.54   Kurtosis:                         3.32
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                       Accidents_Bx   No. Observations:                  362
# Model:             SARIMAX(0, 1, 1)x(1, 1, 1, 52)   Log Likelihood                -876.458
# Date:                            Thu, 18 Feb 2021   AIC                           1762.917
# Time:                                    11:58:27   BIC                           1780.623
# Sample:                                07-01-2012   HQIC                          1770.039
#                                      - 06-02-2019
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Holiday       -6.3919      1.312     -4.870      0.000      -8.964      -3.819
# ma.L1         -0.7498      0.036    -20.673      0.000      -0.821      -0.679
# ar.S.L52      -0.2196      0.086     -2.548      0.011      -0.389      -0.051
# ma.S.L52      -0.5818      0.112     -5.189      0.000      -0.802      -0.362
# sigma2        52.1649      4.881     10.687      0.000      42.598      61.732
# ===================================================================================
# Ljung-Box (Q):                       54.00   Jarque-Bera (JB):                 2.39
# Prob(Q):                              0.07   Prob(JB):                         0.30
# Heteroskedasticity (H):               0.86   Skew:                             0.17
# Prob(H) (two-sided):                  0.48   Kurtosis:                         3.32
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                       Accidents_Bx   No. Observations:                  362
# Model:             SARIMAX(1, 0, 1)x(1, 1, 1, 52)   Log Likelihood                -879.144
# Date:                            Thu, 18 Feb 2021   AIC                           1770.287
# Time:                                    11:58:42   BIC                           1791.559
# Sample:                                07-01-2012   HQIC                          1778.843
#                                      - 06-02-2019
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Holiday       -6.3838      1.321     -4.833      0.000      -8.973      -3.795
# ar.L1          0.9948      0.006    157.366      0.000       0.982       1.007
# ma.L1         -0.7439      0.038    -19.642      0.000      -0.818      -0.670
# ar.S.L52      -0.2156      0.087     -2.483      0.013      -0.386      -0.045
# ma.S.L52      -0.5862      0.115     -5.117      0.000      -0.811      -0.362
# sigma2        51.7328      4.892     10.575      0.000      42.145      61.321
# ===================================================================================
# Ljung-Box (Q):                       53.99   Jarque-Bera (JB):                 2.43
# Prob(Q):                              0.07   Prob(JB):                         0.30
# Heteroskedasticity (H):               0.85   Skew:                             0.17
# Prob(H) (two-sided):                  0.46   Kurtosis:                         3.34
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                        Accidents_Bx   No. Observations:                  362
# Model:             SARIMAX(1, 1, 1)x(1, 1, [], 52)   Log Likelihood                -887.394
# Date:                             Thu, 18 Feb 2021   AIC                           1784.789
# Time:                                     11:58:50   BIC                           1802.514
# Sample:                                 07-01-2012   HQIC                          1791.918
#                                       - 06-02-2019
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Holiday       -5.8826      1.402     -4.194      0.000      -8.631      -3.134
# ar.L1          0.2152      0.071      3.013      0.003       0.075       0.355
# ma.L1         -0.8428      0.040    -20.852      0.000      -0.922      -0.764
# ar.S.L52      -0.4848      0.057     -8.569      0.000      -0.596      -0.374
# sigma2        59.9079      4.846     12.362      0.000      50.409      69.406
# ===================================================================================
# Ljung-Box (Q):                       49.46   Jarque-Bera (JB):                 2.22
# Prob(Q):                              0.15   Prob(JB):                         0.33
# Heteroskedasticity (H):               0.85   Skew:                            -0.01
# Prob(H) (two-sided):                  0.46   Kurtosis:                         3.46
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                         Accidents_Bx   No. Observations:                  362
# Model:             SARIMAX(1, 1, 0)x(0, 1, [1], 52)   Log Likelihood                -896.065
# Date:                              Thu, 18 Feb 2021   AIC                           1800.129
# Time:                                      11:58:55   BIC                           1814.310
# Sample:                                  07-01-2012   HQIC                          1805.832
#                                        - 06-02-2019
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Holiday       -6.1468      1.093     -5.626      0.000      -8.288      -4.005
# ar.L1         -0.3485      0.046     -7.645      0.000      -0.438      -0.259
# ma.S.L52      -0.8117      0.115     -7.083      0.000      -1.036      -0.587
# sigma2        57.8972      6.482      8.932      0.000      45.192      70.602
# ===================================================================================
# Ljung-Box (Q):                       98.71   Jarque-Bera (JB):                 3.68
# Prob(Q):                              0.00   Prob(JB):                         0.16
# Heteroskedasticity (H):               0.70   Skew:                            -0.02
# Prob(H) (two-sided):                  0.10   Kurtosis:                         3.59
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                        Accidents_Bx   No. Observations:                  362
# Model:             SARIMAX(0, 1, 1)x(1, 1, [], 52)   Log Likelihood                -897.256
# Date:                             Thu, 18 Feb 2021   AIC                           1802.512
# Time:                                     11:59:01   BIC                           1816.708
# Sample:                                 07-01-2012   HQIC                          1808.221
#                                       - 06-02-2019
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Holiday       -6.3447      1.476     -4.297      0.000      -9.238      -3.451
# ma.L1         -0.7731      0.036    -21.748      0.000      -0.843      -0.703
# ar.S.L52      -0.4803      0.055     -8.686      0.000      -0.589      -0.372
# sigma2        62.8721      5.105     12.317      0.000      52.867      72.877
# ===================================================================================
# Ljung-Box (Q):                       57.23   Jarque-Bera (JB):                 1.66
# Prob(Q):                              0.04   Prob(JB):                         0.44
# Heteroskedasticity (H):               0.86   Skew:                             0.00
# Prob(H) (two-sided):                  0.49   Kurtosis:                         3.39
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                        Accidents_Bx   No. Observations:                  362
# Model:             SARIMAX(1, 0, 1)x(1, 1, [], 52)   Log Likelihood                -896.928
# Date:                             Thu, 18 Feb 2021   AIC                           1803.856
# Time:                                     11:59:16   BIC                           1821.601
# Sample:                                 07-01-2012   HQIC                          1810.992
#                                       - 06-02-2019
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Holiday       -6.3339      1.485     -4.267      0.000      -9.244      -3.424
# ar.L1          0.9934      0.008    123.806      0.000       0.978       1.009
# ma.L1         -0.7645      0.038    -19.859      0.000      -0.840      -0.689
# ar.S.L52      -0.4801      0.056     -8.631      0.000      -0.589      -0.371
# sigma2        62.6969      5.095     12.305      0.000      52.711      72.683
# ===================================================================================
# Ljung-Box (Q):                       57.20   Jarque-Bera (JB):                 1.62
# Prob(Q):                              0.04   Prob(JB):                         0.45
# Heteroskedasticity (H):               0.85   Skew:                            -0.00
# Prob(H) (two-sided):                  0.46   Kurtosis:                         3.39
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# Based on the above, we see that the following parameters have significant p values:
#
# (1,1,1)x(0,1,1,52)
#
# (0,1,1)x(0,1,1,52)
#
# (1,0,1)x(0,1,1,52)
#
# (0,1,1)x(1,1,1,52)
#
# (1,0,1)x(1,1,1,52)
#
# (1,1,1)x(1,1,0,52)
#
# (1,1,0)x(0,1,1,52)
#
# (0,1,1)x(1,1,0,52)
#
# (1,0,1)x(1,1,0,52)

# %% [markdown]
# We will observe these models' RMSE and AIC score to determine which is our best SARIMAX model.

# %% [markdown]
# **Determine Best SARIMAX Model**

# %%
mod = sm.tsa.statespace.SARIMAX(y_train,
                                exog = train.iloc[:,1:],
                                order=(0,1,1),
                                seasonal_order=(0,1,1,52),
                                enforce_stationarity=False,
                                enforce_invertibility=False)
mod_fit = mod.fit()
mod_pred = mod_fit.predict(start='2019-06-06', end='2020-03-13', exog = test.iloc[:,1:],
                           traindynamic=False)

# %%
# For loop to apply RMSE function to significant parameters
for (pdq,pdqs) in [((1,1,1),(0,1,1,52)),((0,1,1),(0,1,1,52)),((1,0,1),(0,1,1,52)),((0,1,1),(1,1,1,52)),
                  ((1,0,1),(1,1,1,52)),((1,1,1),(1,1,0,52)),((1,1,0),(0,1,1,52)),((0,1,1),(1,1,0,52)),
                   ((1,0,1),(1,1,0,52))]:
    mod = sm.tsa.statespace.SARIMAX(y_train,
                                    exog = train.iloc[:,1],
                                    order=pdq,
                                    seasonal_order=pdqs,
                                    enforce_stationarity=False,
                                    enforce_invertibility=False)
    mod_fit = mod.fit()
    mod_pred = mod_fit.predict(start='2019-06-06', end='2020-03-13', exog = test.iloc[:,1],
                               dynamic=False)
    print(pdq, 'x', pdqs,': RMSE: ', RMSE(mod_pred), 'AIC: ', mod_fit.aic)
# Out:
# (1, 1, 1) x (0, 1, 1, 52) : RMSE:  7.974118738952567 AIC:  1739.9447337155375
# (0, 1, 1) x (0, 1, 1, 52) : RMSE:  8.015737709980039 AIC:  1743.2791285730564
# (1, 0, 1) x (0, 1, 1, 52) : RMSE:  7.336555546701323 AIC:  1750.9036356156705
# (0, 1, 1) x (1, 1, 1, 52) : RMSE:  7.98401387885894 AIC:  1762.9166236919623
# (1, 0, 1) x (1, 1, 1, 52) : RMSE:  7.639553682986478 AIC:  1770.2874503714258
# (1, 1, 1) x (1, 1, 0, 52) : RMSE:  7.038325065611281 AIC:  1784.788603534675
# (1, 1, 0) x (0, 1, 1, 52) : RMSE:  8.542482676984227 AIC:  1800.129012013745
# (0, 1, 1) x (1, 1, 0, 52) : RMSE:  7.006720013666838 AIC:  1802.511990214743
# (1, 0, 1) x (1, 1, 0, 52) : RMSE:  7.384325784116075 AIC:  1803.8559000648872

# %% [markdown]
# Based on the above, the model with parameters (0,1,1) x (1,1,0,52) is our best SARIMAX model. It has the best RMSE, and even though it has nearly the worst AIC, it is by a small margin and we are prioritizing RMSE.
#
# Now we will define this as our SARIMAX model and compare to our SARIMA and ARIMA models.

# %%
SARIMAX = sm.tsa.statespace.SARIMAX(y_train,
                                    exog = train.iloc[:,1],
                                    order=(0,1,1),
                                    seasonal_order=(1,1,0,52),
                                    enforce_stationarity=False,
                                    enforce_invertibility=False)
SARIMAX_fit = SARIMAX.fit()
SARIMAX_pred = SARIMAX_fit.predict(start='2019-06-06', end='2020-03-13', exog = test.iloc[:,1],
                                   dynamic=False)

SARIMAX_RMSE = RMSE(SARIMAX_pred)
SARIMAX_adj_RMSE = SARIMAX_RMSE/(df_bx_wk_mean['Accidents_Bx'].max()-df_bx_wk_mean['Accidents_Bx'].min())
SARIMAX_AIC = SARIMAX_fit.aic


print('ARIMA RMSE: ', base_RMSE)
print('Adjusted ARIMA RMSE: ',
      base_RMSE/(df_bx['Accidents_Bx'].max()-df_bx['Accidents_Bx'].min()))
print('ARIMA AIC: ', base_AIC)

print('SARIMA RMSE: ', RMSE(SARIMA_pred))
print('Adjusted SARIMA RMSE: ',
      RMSE(SARIMA_pred)/(df_bx_wk_mean['Accidents_Bx'].max()-df_bx_wk_mean['Accidents_Bx'].min()))
print('SARIMA AIC: ', SARIMA_fit.aic)

print('SARIMAX RMSE: ', SARIMAX_RMSE)
print('Adjusted SARIMAX RMSE: ', SARIMAX_adj_RMSE)
print('SARIMAX AIC: ', SARIMAX_AIC)
# Out:
# ARIMA RMSE:  18.630368932103426
# Adjusted ARIMA RMSE:  0.0917752164143026
# ARIMA AIC:  21054.375480553423
# SARIMA RMSE:  7.11405578357931
# Adjusted SARIMA RMSE:  0.08571151546481097
# SARIMA AIC:  1817.390955075846
# SARIMAX RMSE:  7.006720013666838
# Adjusted SARIMAX RMSE:  0.08441831341767275
# SARIMAX AIC:  1802.511990214743

# %% [markdown]
# We see from the above that our SARIMAX model is better than our SARIMA model, both in terms of RMSE and AIC. Between our ARIMA and SARIMAX models, our ARIMA model is more useful for the following reasons:
#
# - Although its adjusted RMSE is slightly higher than SARIMAX, it is much more useful to know how many accidents are predicted per day rather than by week. This applies to individuals assessing their own risk as well as officials allocating resources on a daily basis rather than weekly basis. This practical benefit outweighs the slightly worse RMSE.
# - Although its AIC score is significantly higher, we cannot compare AIC scores between these two different types of models. This metric is more useful when comparing parameter options within the same model type.

# %% [markdown]
# **Of our models until this point, the baseline ARIMA model is our best model**

# %% [markdown]
# # Final Model Analysis

# %% [markdown]
# Now that we have determined our best model based on RMSE and AIC, let's dig into it a bit more deeply.

# %% [markdown]
# **Model Metrics**

# %%
# Visualize residuals/error
residuals = pd.DataFrame(base_fit.resid)
residuals.plot(color='royalblue')
plt.show();

# %%
# Check for linearity
residuals = pd.DataFrame(base_fit.resid)
residuals.plot(kind='kde', color='royalblue')
plt.show()

# %% [markdown]
# Based on the first graph above, we see residuals centered and concentrated at 0, though with more variance than is ideal. With a mean at approximately 0, the second graph shows that our model is mostly linear.

# %% [markdown]
# **Test Predictions**

# %% [markdown]
# We know that this ARIMA model yielded our best test predictions from its RMSE and AIC score, but let's visualize our predictions compared to the true data.

# %%
# Plot real vs predicted values
fix,ax = plt.subplots(figsize=(15, 8))

# Plot observed values
ax = df_bx['Accidents_Bx'].plot(label='Observed', color='sandybrown')

# Plot predicted train values
base_pred_train = base_fit.predict(start='2012-07-01', end='2020-03-13', dynamic=False)
base_pred_train.plot(ax=ax, label='Train Predictions', alpha=0.9, color='purple')

# Plot predicted values
base_pred.plot(ax=ax, label='Test Predictions', alpha=0.9, color='mediumseagreen')

# Set axes labels and title
ax.set_xlabel('Year', size=12)
ax.set_ylabel('Car Accidents',size=12)
ax.set_title('Real vs Predicted Bronx Car Accidents,', size=15)

plt.legend()
plt.show()

# %% [markdown]
# # Forecasting

# %% [markdown]
# Now that we see how our data performed on our train and test data, it is time to apply it to the future.

# %% [markdown]
# ## July 1, 2021 through the end of 2021

# %% [markdown]
# As discussed in the EDA notebook, we will use our current model to predict accident numbers starting on July 1, 2021, assuming a 25% decrease from our model predictions.

# %%
# Create df including all Brooklyn data, not only pre-Covid like we've been using for modeling
df_bx_total = df_TS.drop(columns = ['Injuries', 'Deaths','Accidents_Bkln', 'Accidents_Man', 'Accidents_Qns', 'Accidents_SI',
                               'Accidents_Total'])

# %%
# Generate forcast from 3/14/20-12/31/2022
forecast = base_fit.forecast(steps=658)
pred_values = pd.DataFrame(forecast[0])
pred_values['Date'] = pd.date_range(start='2020-03-14', periods=658)
pred_values.set_index(pred_values['Date'],inplace=True)
pred_values = pred_values[0]
pred_values.drop(columns=['Date',0],inplace=True)
pred_values

# Plot forecast
fix,ax = plt.subplots(figsize=(15, 8))
ax = df_bx_total['Accidents_Bx']['2019-01-01':].plot(label='Observed', color='sandybrown')
pred_values.plot(ax=ax, label='Forecast',color='mediumseagreen')

ax.set_xlabel('Date')
ax.set_ylabel('Car Accidents')

plt.legend()
plt.show()

# %% [markdown]
# The above shows us what our predictions would have been through the end of 2021, if it hadn't been for the COVID-19 pandemic. Now let's look at what our actual predictions are, given what we do know about te pandemic and related predictions discussed earlier.

# %%
# Create df of adjusted COVID predictions
# Starting 7/1/21, 75% of original predictions
TS_pred_cov = pred_values['2021-07-01':] * 0.75

# Create linear data connecting last known data point and predicted data linearly
# Create df for connection data
connection = pd.DataFrame(pd.date_range(start='2021-01-30', end='2021-06-30'))
connection['Date'] = pd.DataFrame(pd.date_range(start='2021-01-30', end='2021-06-30'))

# Find how much the accident count will rise each day
# There are 152 days between 1/29/21 and 7/1/21
daily_interval=(TS_pred_cov['2021-07-01'] - df_bx_total['Accidents_Bx']['2021-01-29'])/152

# Add daily interval to each date in connection df
connection_forecasts = []
i = df_bx_total['Accidents_Bx']['2021-01-29']
for num in range(0,152):
    i+=daily_interval
    connection_forecasts.append(i)

# Add list of forecasts to connection df
connection['Forecast'] = connection_forecasts

# Make date index of connection df
connection.set_index('Date', inplace=True)
connection.drop(columns=0,inplace=True)

#Observe connection df
connection
# Out:
#              Forecast
# Date
# 2021-01-30  38.185166
# 2021-01-31  38.370333
# 2021-02-01  38.555499
# 2021-02-02  38.740665
# 2021-02-03  38.925832
# ...               ...
# 2021-06-26  65.404618
# 2021-06-27  65.589784
# 2021-06-28  65.774950
# 2021-06-29  65.960117
# 2021-06-30  66.145283
#
# [152 rows x 1 columns]

# %%
fix,ax = plt.subplots(figsize=(15, 8))

# Plot known data
ax = df_bx_total['Accidents_Bx']['2019-01-01':].plot(label='Observed', color='sandybrown')

# Plot predicted data based on model, starting 7/1/20, 75% of model prediction
TS_pred_cov.plot(ax=ax, label='Forecast',color='mediumseagreen')

# Plot linear connection
connection.plot(ax=ax, color='mediumseagreen')

ax.set_xlabel('Date')
ax.set_ylabel('Car Accidents')

plt.legend()
plt.show()

# %% [markdown]
# The above shows our best predictions for car accidents in The Bronx with an ARIMA-type model. In a separate notebook, we will create a Facebook Prophet model and compare it to this one.

# %% [markdown]
# # Export Data

# %% [markdown]
# In our FB Prophet notebook, we found that our ARIMA model was the best one for our Bronx data. We will therefore export data from this model to use on our Streamlit dashboard.

# %%
# Create one df combining known and predicted accident frequencies
# Round forecasts to integers 
data_preds_bx = pd.concat([df_bx_total['Accidents_Bx'],round(connection['Forecast']),round(TS_pred_cov)])
data_preds_bx.to_csv('Data/data_preds_bx.csv')
