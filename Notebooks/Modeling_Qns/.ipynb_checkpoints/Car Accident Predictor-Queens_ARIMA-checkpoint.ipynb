# %%
# Import packages
import warnings
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.tsa.arima_model import ARIMA
import statsmodels.api as sm
from matplotlib.pylab import rcParams
import itertools
import numpy as np
import tqdm
from tqdm._tqdm_notebook import tqdm_notebook

# Preferred settings
warnings.simplefilter("ignore")
# Out:
# <ipython-input-1-7c1c9c0627ad>:14: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.*` instead of `tqdm._tqdm_notebook.*`
#   from tqdm._tqdm_notebook import tqdm_notebook

# %%
# Import saved data
df_TS = pd.read_csv('Data/df_TS.csv')

# Set date column to datetime object
df_TS['Date'] = pd.to_datetime(df_TS['Date'])

# Set date column as index
df_TS.set_index('Date', inplace=True)

# %% [markdown]
# # Prepare Data

# %%
# Create df of only Queens data, remove columns unhelpful to time series model 
df_qns = df_TS.drop(columns = ['Injuries', 'Deaths','Accidents_Bx', 'Accidents_Man', 'Accidents_Bkln', 'Accidents_SI',
                               'Accidents_Total'])

# Only use pre-COVID data for time series modeling
df_qns = df_qns.loc[:'2020-3-13']

# %%
# Visualize data, including 30-day rolling mean and standard deviation

roll_mean = df_qns['Accidents_Qns'].rolling(window=30, center=False).mean()
roll_std = df_qns['Accidents_Qns'].rolling(window=30, center=False).std()

plt.plot(df_qns['Accidents_Qns'],color='mediumseagreen', label='Original')
plt.plot(roll_mean, color='mediumblue', label='Rolling Mean')
plt.plot(roll_std, color='orangered', label = 'Rolling Std')
plt.legend(loc='best')
plt.title('Rolling Mean & Standard Deviation')
plt.xlabel('Year')
plt.ylabel('Accidents')
plt.show(block=False)

# Dickey-Fuller test
test = adfuller(df_qns['Accidents_Qns'][1:-1])
dfoutput = pd.Series(test[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
dfoutput
# Out:
# Test Statistic                   -2.995153
# p-value                           0.035350
# #Lags Used                       27.000000
# Number of Observations Used    2783.000000
# dtype: float64

# %% [markdown]
# Based on the above visualization and Dickey-Fuller p-value, we see that this data is stationary. We will therefore not perform differencing, a log transformation, or any other transformation on the data before fitting a model.

# %% [markdown]
# # ARIMA Models

# %% [markdown]
# ## Baseline Model: ARIMA with no Exogenous Variables

# %% [markdown]
# **ACF, PACF**

# %%
# ACF
plot_acf(df_qns['Accidents_Qns'], alpha=.05);

# PACF
plot_pacf(df_qns['Accidents_Qns'], alpha=.05, lags=20);

# %% [markdown]
# Based on the above ACF and PACF, when instantiating an ARIMA model, we would expect a relatively large number of MA terms due to the larger number of significant ACF points and a relatively small number of AR terms due to the small number of significant PACF points.

# %% [markdown]
# **Train-Test Split**

# %%
# Determine split point for 90%/10% train-test split
split_point = int(len(df_qns) * 0.9)
df_qns.iloc[split_point]
# Out:
# Accidents_Qns         204
# Season             Spring
# Day of Week      Thursday
# Weekend                 0
# Holiday                 0
# Name: 2019-06-06 00:00:00, dtype: object

# %%
# Train-test split
# Based on the above, 2019-06-06 will be the split point for our train and test sets

X = df_qns.index
y = df_qns['Accidents_Qns']

train = df_qns.loc[:'2019-06-06']
test = df_qns.loc['2019-06-06':]

X_train, X_test = train.index , test.index
y_train, y_test = train['Accidents_Qns'] , test['Accidents_Qns']

# %% [markdown]
# **Grid Search**

# %%
# Determine best parameters for ARIMA model

# Define the p, d, and q parameters to take any value between 0 and 4
p = d = q = range(0,4)

# Generate all different combinations of p, d, and q triplets
pdq = list(itertools.product(p, d, q))

# Run a grid with pdq parameters calculated to see corresponding AIC scores
ans_ARIMA = []
for comb in pdq:
    try:
        mod = ARIMA(y_train, order=comb)
        output = mod.fit()
        ans_ARIMA.append([comb, output.aic])
        print('ARIMA {} : AIC Calculated ={}'.format(comb,output.aic))
    except:
        continue
# Out:
# ARIMA (0, 0, 0) : AIC Calculated =24658.01612499942
# ARIMA (0, 0, 1) : AIC Calculated =24121.210082765923
# ARIMA (0, 0, 2) : AIC Calculated =24029.629212313153
# ARIMA (0, 0, 3) : AIC Calculated =23945.523773867917
# ARIMA (0, 1, 0) : AIC Calculated =24629.201410826492
# ARIMA (0, 1, 1) : AIC Calculated =23538.408959189095
# ARIMA (0, 1, 2) : AIC Calculated =23434.883418496192
# ARIMA (0, 1, 3) : AIC Calculated =23435.38917055569
# ARIMA (0, 2, 0) : AIC Calculated =27149.08456531061
# ARIMA (0, 2, 1) : AIC Calculated =24630.309873455168
# ARIMA (0, 2, 2) : AIC Calculated =23547.170627631458
# ARIMA (0, 2, 3) : AIC Calculated =23443.154108147075
# ARIMA (1, 0, 0) : AIC Calculated =23919.775346076905
# ARIMA (1, 0, 1) : AIC Calculated =23544.967798361442
# ARIMA (1, 0, 2) : AIC Calculated =23444.561114673557
# ARIMA (1, 0, 3) : AIC Calculated =23444.798884327633
# ARIMA (1, 1, 0) : AIC Calculated =24283.228251761608
# ARIMA (1, 1, 1) : AIC Calculated =23445.948201939307
# ARIMA (1, 1, 2) : AIC Calculated =23435.54532928561
# ARIMA (1, 1, 3) : AIC Calculated =23437.36691524414
# ARIMA (1, 2, 0) : AIC Calculated =26155.518735419617
# ARIMA (2, 0, 0) : AIC Calculated =23866.893630455244
# ARIMA (2, 0, 1) : AIC Calculated =23455.873540526023
# ARIMA (2, 0, 2) : AIC Calculated =23445.016113438065
# ARIMA (2, 0, 3) : AIC Calculated =23446.22046344442
# ARIMA (2, 1, 0) : AIC Calculated =23975.650131104318
# ARIMA (2, 1, 1) : AIC Calculated =23436.81946160943
# ARIMA (2, 1, 2) : AIC Calculated =23437.097214071466
# ARIMA (2, 1, 3) : AIC Calculated =23399.02849778914
# ARIMA (2, 2, 0) : AIC Calculated =25488.248391042544
# ARIMA (3, 0, 0) : AIC Calculated =23746.31824130173
# ARIMA (3, 0, 1) : AIC Calculated =23446.008922264744
# ARIMA (3, 0, 2) : AIC Calculated =23446.41326612504
# ARIMA (3, 0, 3) : AIC Calculated =23407.076675038563
# ARIMA (3, 1, 0) : AIC Calculated =23839.597757942705
# ARIMA (3, 1, 1) : AIC Calculated =23435.12341128917
# ARIMA (3, 1, 2) : AIC Calculated =23437.05999062953
# ARIMA (3, 1, 3) : AIC Calculated =23144.08265976238
# ARIMA (3, 2, 0) : AIC Calculated =24990.152725548003

# %%
# Find parameters with minimal AIC value
df_AIC = pd.DataFrame(ans_ARIMA, columns=['pdq', 'aic'])
df_AIC.sort_values(by='aic', ascending=True, inplace=True)
df_AIC[:10]
# Out:
#           pdq           aic
# 37  (3, 1, 3)  23144.082660
# 28  (2, 1, 3)  23399.028498
# 33  (3, 0, 3)  23407.076675
# 6   (0, 1, 2)  23434.883418
# 35  (3, 1, 1)  23435.123411
# 7   (0, 1, 3)  23435.389171
# 18  (1, 1, 2)  23435.545329
# 26  (2, 1, 1)  23436.819462
# 36  (3, 1, 2)  23437.059991
# 27  (2, 1, 2)  23437.097214

# %% [markdown]
# **Narrowing Down Parameters**

# %% [markdown]
# Observe lowest 10 AIC score parameter values to determine best model. Make sure p values are significant, and observe RMSEs to determind best overall model.

# %%
for pdq in df_AIC['pdq'][:10]:
    mod = ARIMA(y_train[:-1], order=pdq)
    mod_fit = mod.fit()
    print(mod_fit.summary())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:        D.Accidents_Qns   No. Observations:                 2530
# Model:                 ARIMA(3, 1, 3)   Log Likelihood              -11559.461
# Method:                       css-mle   S.D. of innovations             23.288
# Date:                Tue, 16 Feb 2021   AIC                          23134.921
# Time:                        11:24:48   BIC                          23181.609
# Sample:                    07-02-2012   HQIC                         23151.861
#                          - 06-05-2019
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                     0.0197      0.022      0.889      0.374      -0.024       0.063
# ar.L1.D.Accidents_Qns    -0.1890      0.000   -378.334      0.000      -0.190      -0.188
# ar.L2.D.Accidents_Qns    -0.8860      0.000  -4438.623      0.000      -0.886      -0.886
# ar.L3.D.Accidents_Qns     0.2560      0.000    578.541      0.000       0.255       0.257
# ma.L1.D.Accidents_Qns    -0.5231      0.006    -81.405      0.000      -0.536      -0.511
# ma.L2.D.Accidents_Qns     0.5729      0.006     91.118      0.000       0.561       0.585
# ma.L3.D.Accidents_Qns    -0.9637      0.008   -125.395      0.000      -0.979      -0.949
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -0.2225           -0.9749j            1.0000           -0.2857
# AR.2           -0.2225           +0.9749j            1.0000            0.2857
# AR.3            3.9065           -0.0000j            3.9065           -0.0000
# MA.1           -0.2210           -0.9758j            1.0005           -0.2855
# MA.2           -0.2210           +0.9758j            1.0005            0.2855
# MA.3            1.0366           -0.0000j            1.0366           -0.0000
# -----------------------------------------------------------------------------
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:        D.Accidents_Qns   No. Observations:                 2530
# Model:                 ARIMA(2, 1, 3)   Log Likelihood              -11687.610
# Method:                       css-mle   S.D. of innovations             24.538
# Date:                Tue, 16 Feb 2021   AIC                          23389.219
# Time:                        11:24:49   BIC                          23430.071
# Sample:                    07-02-2012   HQIC                         23404.041
#                          - 06-05-2019
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                     0.0204      0.030      0.686      0.492      -0.038       0.079
# ar.L1.D.Accidents_Qns    -0.6419      0.057    -11.360      0.000      -0.753      -0.531
# ar.L2.D.Accidents_Qns    -0.7008      0.043    -16.446      0.000      -0.784      -0.617
# ma.L1.D.Accidents_Qns    -0.1317      0.059     -2.228      0.026      -0.248      -0.016
# ma.L2.D.Accidents_Qns    -0.0416      0.059     -0.703      0.482      -0.158       0.074
# ma.L3.D.Accidents_Qns    -0.6851      0.035    -19.371      0.000      -0.754      -0.616
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -0.4580           -1.1032j            1.1945           -0.3126
# AR.2           -0.4580           +1.1032j            1.1945            0.3126
# MA.1            1.0591           -0.0000j            1.0591           -0.0000
# MA.2           -0.5599           -1.0318j            1.1740           -0.3291
# MA.3           -0.5599           +1.0318j            1.1740            0.3291
# -----------------------------------------------------------------------------
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:          Accidents_Qns   No. Observations:                 2531
# Model:                     ARMA(3, 3)   Log Likelihood              -11690.578
# Method:                       css-mle   S.D. of innovations             24.524
# Date:                Tue, 16 Feb 2021   AIC                          23397.155
# Time:                        11:24:50   BIC                          23443.846
# Sample:                    07-01-2012   HQIC                         23414.096
#                          - 06-05-2019
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                 150.5271      9.063     16.609      0.000     132.764     168.290
# ar.L1.Accidents_Qns     0.3585      0.058      6.228      0.000       0.246       0.471
# ar.L2.Accidents_Qns    -0.0696      0.074     -0.947      0.344      -0.214       0.075
# ar.L3.Accidents_Qns     0.7035      0.042     16.804      0.000       0.621       0.786
# ma.L1.Accidents_Qns    -0.1314      0.061     -2.166      0.030      -0.250      -0.013
# ma.L2.Accidents_Qns    -0.0293      0.061     -0.481      0.630      -0.149       0.090
# ma.L3.Accidents_Qns    -0.6815      0.035    -19.540      0.000      -0.750      -0.613
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0033           -0.0000j            1.0033           -0.0000
# AR.2           -0.4522           -1.1011j            1.1903           -0.3120
# AR.3           -0.4522           +1.1011j            1.1903            0.3120
# MA.1            1.0664           -0.0000j            1.0664           -0.0000
# MA.2           -0.5547           -1.0336j            1.1730           -0.3284
# MA.3           -0.5547           +1.0336j            1.1730            0.3284
# -----------------------------------------------------------------------------
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:        D.Accidents_Qns   No. Observations:                 2530
# Model:                 ARIMA(0, 1, 2)   Log Likelihood              -11708.759
# Method:                       css-mle   S.D. of innovations             24.744
# Date:                Tue, 16 Feb 2021   AIC                          23425.519
# Time:                        11:24:51   BIC                          23448.863
# Sample:                    07-02-2012   HQIC                         23433.989
#                          - 06-05-2019
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                     0.0197      0.023      0.850      0.395      -0.026       0.065
# ma.L1.D.Accidents_Qns    -0.7378      0.020    -37.232      0.000      -0.777      -0.699
# ma.L2.D.Accidents_Qns    -0.2155      0.020    -10.689      0.000      -0.255      -0.176
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# MA.1            1.0397           +0.0000j            1.0397            0.0000
# MA.2           -4.4629           +0.0000j            4.4629            0.5000
# -----------------------------------------------------------------------------
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:        D.Accidents_Qns   No. Observations:                 2530
# Model:                 ARIMA(3, 1, 1)   Log Likelihood              -11706.891
# Method:                       css-mle   S.D. of innovations             24.726
# Date:                Tue, 16 Feb 2021   AIC                          23425.782
# Time:                        11:24:51   BIC                          23460.798
# Sample:                    07-02-2012   HQIC                         23438.487
#                          - 06-05-2019
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                     0.0197      0.023      0.850      0.395      -0.026       0.065
# ar.L1.D.Accidents_Qns     0.2194      0.021     10.220      0.000       0.177       0.261
# ar.L2.D.Accidents_Qns    -0.0739      0.021     -3.512      0.000      -0.115      -0.033
# ar.L3.D.Accidents_Qns     0.0407      0.021      1.917      0.055      -0.001       0.082
# ma.L1.D.Accidents_Qns    -0.9620      0.008   -121.428      0.000      -0.978      -0.946
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            2.8911           -0.0000j            2.8911           -0.0000
# AR.2           -0.5376           -2.8657j            2.9157           -0.2795
# AR.3           -0.5376           +2.8657j            2.9157            0.2795
# MA.1            1.0395           +0.0000j            1.0395            0.0000
# -----------------------------------------------------------------------------
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:        D.Accidents_Qns   No. Observations:                 2530
# Model:                 ARIMA(0, 1, 3)   Log Likelihood              -11708.024
# Method:                       css-mle   S.D. of innovations             24.737
# Date:                Tue, 16 Feb 2021   AIC                          23426.048
# Time:                        11:24:52   BIC                          23455.228
# Sample:                    07-02-2012   HQIC                         23436.636
#                          - 06-05-2019
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                     0.0199      0.024      0.817      0.414      -0.028       0.067
# ma.L1.D.Accidents_Qns    -0.7435      0.020    -37.392      0.000      -0.782      -0.705
# ma.L2.D.Accidents_Qns    -0.2306      0.023     -9.906      0.000      -0.276      -0.185
# ma.L3.D.Accidents_Qns     0.0231      0.019      1.210      0.226      -0.014       0.060
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# MA.1            1.0428           +0.0000j            1.0428            0.0000
# MA.2           -3.3720           +0.0000j            3.3720            0.5000
# MA.3           12.3187           +0.0000j           12.3187            0.0000
# -----------------------------------------------------------------------------
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:        D.Accidents_Qns   No. Observations:                 2530
# Model:                 ARIMA(1, 1, 2)   Log Likelihood              -11708.101
# Method:                       css-mle   S.D. of innovations             24.738
# Date:                Tue, 16 Feb 2021   AIC                          23426.203
# Time:                        11:24:53   BIC                          23455.383
# Sample:                    07-02-2012   HQIC                         23436.790
#                          - 06-05-2019
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                     0.0198      0.024      0.824      0.410      -0.027       0.067
# ar.L1.D.Accidents_Qns    -0.0932      0.079     -1.172      0.241      -0.249       0.063
# ma.L1.D.Accidents_Qns    -0.6497      0.076     -8.591      0.000      -0.798      -0.501
# ma.L2.D.Accidents_Qns    -0.2973      0.070     -4.225      0.000      -0.435      -0.159
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1          -10.7352           +0.0000j           10.7352            0.5000
# MA.1            1.0422           +0.0000j            1.0422            0.0000
# MA.2           -3.2277           +0.0000j            3.2277            0.5000
# -----------------------------------------------------------------------------
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:        D.Accidents_Qns   No. Observations:                 2530
# Model:                 ARIMA(2, 1, 1)   Log Likelihood              -11708.728
# Method:                       css-mle   S.D. of innovations             24.744
# Date:                Tue, 16 Feb 2021   AIC                          23427.456
# Time:                        11:24:53   BIC                          23456.636
# Sample:                    07-02-2012   HQIC                         23438.043
#                          - 06-05-2019
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                     0.0200      0.025      0.792      0.428      -0.029       0.069
# ar.L1.D.Accidents_Qns     0.2114      0.021      9.962      0.000       0.170       0.253
# ar.L2.D.Accidents_Qns    -0.0701      0.021     -3.332      0.001      -0.111      -0.029
# ma.L1.D.Accidents_Qns    -0.9564      0.008   -117.897      0.000      -0.972      -0.941
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.5069           -3.4625j            3.7762           -0.1847
# AR.2            1.5069           +3.4625j            3.7762            0.1847
# MA.1            1.0456           +0.0000j            1.0456            0.0000
# -----------------------------------------------------------------------------
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:        D.Accidents_Qns   No. Observations:                 2530
# Model:                 ARIMA(3, 1, 2)   Log Likelihood              -11706.855
# Method:                       css-mle   S.D. of innovations             24.725
# Date:                Tue, 16 Feb 2021   AIC                          23427.711
# Time:                        11:24:55   BIC                          23468.563
# Sample:                    07-02-2012   HQIC                         23442.533
#                          - 06-05-2019
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                     0.0197      0.023      0.855      0.393      -0.025       0.065
# ar.L1.D.Accidents_Qns     0.2852      0.264      1.080      0.280      -0.233       0.803
# ar.L2.D.Accidents_Qns    -0.0878      0.060     -1.475      0.140      -0.205       0.029
# ar.L3.D.Accidents_Qns     0.0456      0.028      1.649      0.099      -0.009       0.100
# ma.L1.D.Accidents_Qns    -1.0279      0.264     -3.895      0.000      -1.545      -0.511
# ma.L2.D.Accidents_Qns     0.0630      0.252      0.250      0.803      -0.432       0.558
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            2.6660           -0.0000j            2.6660           -0.0000
# AR.2           -0.3698           -2.8446j            2.8685           -0.2706
# AR.3           -0.3698           +2.8446j            2.8685            0.2706
# MA.1            1.0391           +0.0000j            1.0391            0.0000
# MA.2           15.2765           +0.0000j           15.2765            0.0000
# -----------------------------------------------------------------------------
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:        D.Accidents_Qns   No. Observations:                 2530
# Model:                 ARIMA(2, 1, 2)   Log Likelihood              -11707.877
# Method:                       css-mle   S.D. of innovations             24.736
# Date:                Tue, 16 Feb 2021   AIC                          23427.755
# Time:                        11:24:56   BIC                          23462.770
# Sample:                    07-02-2012   HQIC                         23440.459
#                          - 06-05-2019
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                     0.0199      0.025      0.806      0.420      -0.028       0.068
# ar.L1.D.Accidents_Qns    -0.0092      0.151     -0.061      0.952      -0.305       0.287
# ar.L2.D.Accidents_Qns    -0.0275      0.040     -0.692      0.489      -0.105       0.050
# ma.L1.D.Accidents_Qns    -0.7342      0.150     -4.898      0.000      -1.028      -0.440
# ma.L2.D.Accidents_Qns    -0.2143      0.145     -1.478      0.139      -0.498       0.070
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -0.1670           -6.0308j            6.0331           -0.2544
# AR.2           -0.1670           +6.0308j            6.0331            0.2544
# MA.1            1.0440           +0.0000j            1.0440            0.0000
# MA.2           -4.4699           +0.0000j            4.4699            0.5000
# -----------------------------------------------------------------------------

# %% [markdown]
# From the above, we see that none of these parameters have significant p-values. We will now look at the next 10 lowest AIC scores in search of our best ARIMA model.

# %%
for pdq in df_AIC['pdq'][10:20]:
    mod = ARIMA(y_train[:-1], order=pdq)
    mod_fit = mod.fit()
    print(mod_fit.summary())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:        D.Accidents_Qns   No. Observations:                 2530
# Model:                 ARIMA(1, 1, 3)   Log Likelihood              -11708.013
# Method:                       css-mle   S.D. of innovations             24.737
# Date:                Tue, 16 Feb 2021   AIC                          23428.026
# Time:                        11:27:08   BIC                          23463.041
# Sample:                    07-02-2012   HQIC                         23440.730
#                          - 06-05-2019
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                     0.0199      0.024      0.815      0.415      -0.028       0.068
# ar.L1.D.Accidents_Qns     0.0566      0.383      0.148      0.883      -0.695       0.808
# ma.L1.D.Accidents_Qns    -0.8000      0.383     -2.090      0.037      -1.550      -0.050
# ma.L2.D.Accidents_Qns    -0.1891      0.283     -0.669      0.504      -0.743       0.365
# ma.L3.D.Accidents_Qns     0.0355      0.085      0.419      0.675      -0.131       0.202
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           17.6587           +0.0000j           17.6587            0.0000
# MA.1            1.0431           +0.0000j            1.0431            0.0000
# MA.2           -3.4794           +0.0000j            3.4794            0.5000
# MA.3            7.7683           +0.0000j            7.7683            0.0000
# -----------------------------------------------------------------------------
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:       D2.Accidents_Qns   No. Observations:                 2529
# Model:                 ARIMA(0, 2, 3)   Log Likelihood              -11712.152
# Method:                       css-mle   S.D. of innovations             24.764
# Date:                Tue, 16 Feb 2021   AIC                          23434.303
# Time:                        11:27:12   BIC                          23463.481
# Sample:                    07-03-2012   HQIC                         23444.890
#                          - 06-05-2019
# ==========================================================================================
#                              coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                  -1.932e-06   4.79e-05     -0.040      0.968   -9.58e-05    9.19e-05
# ma.L1.D2.Accidents_Qns    -1.7336      0.001  -2987.867      0.000      -1.735      -1.733
# ma.L2.D2.Accidents_Qns     0.5203      0.002    251.269      0.000       0.516       0.524
# ma.L3.D2.Accidents_Qns     0.2134      0.002    107.969      0.000       0.210       0.217
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# MA.1            1.0011           +0.0000j            1.0011            0.0000
# MA.2            1.0440           +0.0000j            1.0440            0.0000
# MA.3           -4.4837           +0.0000j            4.4837            0.5000
# -----------------------------------------------------------------------------
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:          Accidents_Qns   No. Observations:                 2531
# Model:                     ARMA(1, 2)   Log Likelihood              -11712.559
# Method:                       css-mle   S.D. of innovations             24.738
# Date:                Tue, 16 Feb 2021   AIC                          23435.118
# Time:                        11:27:13   BIC                          23464.300
# Sample:                    07-01-2012   HQIC                         23445.706
#                          - 06-05-2019
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                 150.1857     11.099     13.532      0.000     128.433     171.938
# ar.L1.Accidents_Qns     0.9981      0.001    737.314      0.000       0.995       1.001
# ma.L1.Accidents_Qns    -0.7360      0.020    -36.916      0.000      -0.775      -0.697
# ma.L2.Accidents_Qns    -0.2133      0.020    -10.550      0.000      -0.253      -0.174
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0019           +0.0000j            1.0019            0.0000
# MA.1            1.0433           +0.0000j            1.0433            0.0000
# MA.2           -4.4947           +0.0000j            4.4947            0.5000
# -----------------------------------------------------------------------------
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:          Accidents_Qns   No. Observations:                 2531
# Model:                     ARMA(1, 3)   Log Likelihood              -11711.689
# Method:                       css-mle   S.D. of innovations             24.729
# Date:                Tue, 16 Feb 2021   AIC                          23435.379
# Time:                        11:27:14   BIC                          23470.397
# Sample:                    07-01-2012   HQIC                         23448.084
#                          - 06-05-2019
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                 150.2910     10.697     14.050      0.000     129.325     171.257
# ar.L1.Accidents_Qns     0.9979      0.001    686.758      0.000       0.995       1.001
# ma.L1.Accidents_Qns    -0.7421      0.020    -37.203      0.000      -0.781      -0.703
# ma.L2.Accidents_Qns    -0.2296      0.023     -9.870      0.000      -0.275      -0.184
# ma.L3.Accidents_Qns     0.0252      0.019      1.315      0.188      -0.012       0.063
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0021           +0.0000j            1.0021            0.0000
# MA.1            1.0472           +0.0000j            1.0472            0.0000
# MA.2           -3.3281           +0.0000j            3.3281            0.5000
# MA.3           11.4086           +0.0000j           11.4086            0.0000
# -----------------------------------------------------------------------------
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:          Accidents_Qns   No. Observations:                 2531
# Model:                     ARMA(2, 2)   Log Likelihood              -11711.797
# Method:                       css-mle   S.D. of innovations             24.730
# Date:                Tue, 16 Feb 2021   AIC                          23435.595
# Time:                        11:27:15   BIC                          23470.613
# Sample:                    07-01-2012   HQIC                         23448.300
#                          - 06-05-2019
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                 150.2944     10.789     13.930      0.000     129.149     171.440
# ar.L1.Accidents_Qns     0.8977      0.079     11.326      0.000       0.742       1.053
# ar.L2.Accidents_Qns     0.1000      0.079      1.267      0.205      -0.055       0.255
# ma.L1.Accidents_Qns    -0.6411      0.075     -8.502      0.000      -0.789      -0.493
# ma.L2.Accidents_Qns    -0.3008      0.070     -4.321      0.000      -0.437      -0.164
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0021           +0.0000j            1.0021            0.0000
# AR.2           -9.9772           +0.0000j            9.9772            0.5000
# MA.1            1.0462           +0.0000j            1.0462            0.0000
# MA.2           -3.1773           +0.0000j            3.1773            0.5000
# -----------------------------------------------------------------------------
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:        D.Accidents_Qns   No. Observations:                 2530
# Model:                 ARIMA(1, 1, 1)   Log Likelihood              -11714.266
# Method:                       css-mle   S.D. of innovations             24.798
# Date:                Tue, 16 Feb 2021   AIC                          23436.531
# Time:                        11:27:15   BIC                          23459.875
# Sample:                    07-02-2012   HQIC                         23445.001
#                          - 06-05-2019
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                     0.0196      0.022      0.887      0.375      -0.024       0.063
# ar.L1.D.Accidents_Qns     0.2069      0.021      9.846      0.000       0.166       0.248
# ma.L1.D.Accidents_Qns    -0.9649      0.007   -143.874      0.000      -0.978      -0.952
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            4.8341           +0.0000j            4.8341            0.0000
# MA.1            1.0364           +0.0000j            1.0364            0.0000
# -----------------------------------------------------------------------------
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:          Accidents_Qns   No. Observations:                 2531
# Model:                     ARMA(3, 1)   Log Likelihood              -11712.281
# Method:                       css-mle   S.D. of innovations             24.735
# Date:                Tue, 16 Feb 2021   AIC                          23436.563
# Time:                        11:27:16   BIC                          23471.581
# Sample:                    07-01-2012   HQIC                         23449.268
#                          - 06-05-2019
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                 150.3609     10.383     14.481      0.000     130.010     170.712
# ar.L1.Accidents_Qns     1.2063      0.022     55.843      0.000       1.164       1.249
# ar.L2.Accidents_Qns    -0.2807      0.031     -9.175      0.000      -0.341      -0.221
# ar.L3.Accidents_Qns     0.0725      0.021      3.440      0.001       0.031       0.114
# ma.L1.Accidents_Qns    -0.9519      0.009   -103.175      0.000      -0.970      -0.934
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0023           -0.0000j            1.0023           -0.0000
# AR.2            1.4351           -3.4209j            3.7098           -0.1868
# AR.3            1.4351           +3.4209j            3.7098            0.1868
# MA.1            1.0506           +0.0000j            1.0506            0.0000
# -----------------------------------------------------------------------------
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:          Accidents_Qns   No. Observations:                 2531
# Model:                     ARMA(2, 3)   Log Likelihood              -11711.491
# Method:                       css-mle   S.D. of innovations             24.727
# Date:                Tue, 16 Feb 2021   AIC                          23436.982
# Time:                        11:27:17   BIC                          23477.836
# Sample:                    07-01-2012   HQIC                         23451.804
#                          - 06-05-2019
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                 151.6811     10.804     14.039      0.000     130.505     172.857
# ar.L1.Accidents_Qns     0.0150      0.016      0.951      0.341      -0.016       0.046
# ar.L2.Accidents_Qns     0.9810      0.016     62.310      0.000       0.950       1.012
# ma.L1.Accidents_Qns     0.2454      0.026      9.608      0.000       0.195       0.295
# ma.L2.Accidents_Qns    -0.9404      0.012    -76.488      0.000      -0.965      -0.916
# ma.L3.Accidents_Qns    -0.2024      0.021     -9.416      0.000      -0.244      -0.160
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0020           +0.0000j            1.0020            0.0000
# AR.2           -1.0173           +0.0000j            1.0173            0.5000
# MA.1            1.0444           +0.0000j            1.0444            0.0000
# MA.2           -1.0109           +0.0000j            1.0109            0.5000
# MA.3           -4.6808           +0.0000j            4.6808            0.5000
# -----------------------------------------------------------------------------
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:          Accidents_Qns   No. Observations:                 2531
# Model:                     ARMA(3, 2)   Log Likelihood              -11711.495
# Method:                       css-mle   S.D. of innovations             24.728
# Date:                Tue, 16 Feb 2021   AIC                          23436.990
# Time:                        11:27:19   BIC                          23477.844
# Sample:                    07-01-2012   HQIC                         23451.812
#                          - 06-05-2019
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                 150.3213     10.558     14.238      0.000     129.628     171.015
# ar.L1.Accidents_Qns     0.9945      0.148      6.699      0.000       0.704       1.285
# ar.L2.Accidents_Qns    -0.0285      0.182     -0.157      0.875      -0.385       0.327
# ar.L3.Accidents_Qns     0.0318      0.039      0.815      0.415      -0.045       0.108
# ma.L1.Accidents_Qns    -0.7385      0.148     -5.005      0.000      -1.028      -0.449
# ma.L2.Accidents_Qns    -0.2052      0.142     -1.442      0.149      -0.484       0.074
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0022           -0.0000j            1.0022           -0.0000
# AR.2           -0.0517           -5.6052j            5.6055           -0.2515
# AR.3           -0.0517           +5.6052j            5.6055            0.2515
# MA.1            1.0486           +0.0000j            1.0486            0.0000
# MA.2           -4.6482           +0.0000j            4.6482            0.5000
# -----------------------------------------------------------------------------
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:          Accidents_Qns   No. Observations:                 2531
# Model:                     ARMA(2, 1)   Log Likelihood              -11718.190
# Method:                       css-mle   S.D. of innovations             24.793
# Date:                Tue, 16 Feb 2021   AIC                          23446.380
# Time:                        11:27:20   BIC                          23475.562
# Sample:                    07-01-2012   HQIC                         23456.968
#                          - 06-05-2019
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                 150.0819     11.464     13.091      0.000     127.612     172.552
# ar.L1.Accidents_Qns     1.2028      0.021     56.821      0.000       1.161       1.244
# ar.L2.Accidents_Qns    -0.2042      0.021     -9.735      0.000      -0.245      -0.163
# ma.L1.Accidents_Qns    -0.9616      0.007   -131.719      0.000      -0.976      -0.947
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0017           +0.0000j            1.0017            0.0000
# AR.2            4.8887           +0.0000j            4.8887            0.0000
# MA.1            1.0399           +0.0000j            1.0399            0.0000
# -----------------------------------------------------------------------------

# %% [markdown]
# From the above, we see that parameters (1,0,2), (3,0,1), and (2,0,1) and significant p-values. We will compare RMSE values for these parameters to determine our best ARIMA parameters.

# %% [markdown]
# **Determine Best ARIMA Model**

# %%
# Create RMSE function
def RMSE(pred):
    return np.sqrt(((pred-y_test)**2).mean())

# For loop to apply RMSE function to significant parameters
for pdq in [(1,0,2),(3,0,1),(2,0,1)]:
    mod = ARIMA(y_train[:-1], order=pdq)
    mod_fit = mod.fit()
    mod_pred = mod_fit.predict(start='2019-06-06', end='2020-03-13', dynamic=False)
    print(pdq,': RMSE: ', RMSE(mod_pred), 'AIC: ', mod_fit.aic)
# Out:
# (1, 0, 2) : RMSE:  29.86647351171352 AIC:  23435.117787872263
# (3, 0, 1) : RMSE:  29.630639592651963 AIC:  23436.562817326376
# (2, 0, 1) : RMSE:  29.953345821989473 AIC:  23446.37976038227

# %% [markdown]
# The above models have *very* similar RMSEs and AIC scores, so none is signficantly better than the others. We will choose the model with parameters (3,0,1) as our best because it has the lowest RMSE score, albeit by only a small margin. We will prioritize RMSE over AIC in this case because it more directly relates to the accuracy of the results themselves.

# %%
# Define baseline model for future comparison
base = ARIMA(y_train[:-1], order=(3,0,1))
base_fit = base.fit()
base_pred = base_fit.predict(start='2019-06-06', end='2020-03-13', dynamic=False)
base_RMSE = RMSE(base_pred)
base_AIC = base_fit.aic

print('Baseline model RMSE: ', base_RMSE)
print('Baseline model RMSE adj for range: ',
      base_RMSE/(df_qns['Accidents_Qns'].max()-df_qns['Accidents_Qns'].min()))
print('Baseline model AIC: ', base_AIC)
# Out:
# Baseline model RMSE:  29.630639592651963
# Baseline model RMSE adj for range:  0.11223727118428774
# Baseline model AIC:  23436.562817326376

# %% [markdown]
# ## Model #2: Introducing Exogenous Variables: ARIMAX Model

# %% [markdown]
# Now that we have our baseline ARIMA model, we will try incorporating exogenous variables with an ARIMAX model.

# %% [markdown]
# **Clean Data for ARIMAX Model**

# %%
# Turn exogenous variables into integers so they work in the model
# Season
df_qns['Season'] = np.where(df_qns['Season']=='Fall', 1, df_qns['Season'])
df_qns['Season'] = np.where(df_qns['Season']=='Winter', 2, df_qns['Season'])
df_qns['Season'] = np.where(df_qns['Season']=='Spring', 3, df_qns['Season'])
df_qns['Season'] = np.where(df_qns['Season']=='Summer', 4, df_qns['Season'])

# Day of Week
df_qns['Day of Week'] = np.where(df_qns['Day of Week']=='Sunday', 1, df_qns['Day of Week'])
df_qns['Day of Week'] = np.where(df_qns['Day of Week']=='Monday', 2, df_qns['Day of Week'])
df_qns['Day of Week'] = np.where(df_qns['Day of Week']=='Tuesday', 3, df_qns['Day of Week'])
df_qns['Day of Week'] = np.where(df_qns['Day of Week']=='Wednesday', 4, df_qns['Day of Week'])
df_qns['Day of Week'] = np.where(df_qns['Day of Week']=='Thursday', 5, df_qns['Day of Week'])
df_qns['Day of Week'] = np.where(df_qns['Day of Week']=='Friday', 6, df_qns['Day of Week'])
df_qns['Day of Week'] = np.where(df_qns['Day of Week']=='Saturday', 7, df_qns['Day of Week'])

# Weekend (these turned into strings when the data was imported from the csv)
df_qns['Weekend'] = np.where(df_qns['Weekend']=='0', 0, df_qns['Weekend'])
df_qns['Weekend'] = np.where(df_qns['Weekend']=='1', 1, df_qns['Weekend'])

# Holiday (these turned into strings when the data was imported from the csv)
df_qns['Holiday'] = np.where(df_qns['Holiday']=='0', 0, df_qns['Holiday'])
df_qns['Holiday'] = np.where(df_qns['Holiday']=='1', 1, df_qns['Holiday'])

# %% [markdown]
# **Redefine Train-Test Split with Cleaned Data**

# %%
# Train-test split
# Based on the above, 2019-06-06 will be the split point for our train and test sets

X = df_qns.index
y = df_qns['Accidents_Qns']

train = df_qns.loc[:'2019-06-06']
test = df_qns.loc['2019-06-06':]

X_train, X_test = train.index , test.index
y_train, y_test = train['Accidents_Qns'] , test['Accidents_Qns']

# %%
# Make list of lists of exogenous data to be used in the model
list_of_lists = []
for column in list(train.iloc[:,1:].columns):
    list_of_lists.append(list(train[column]))
    
exog=np.column_stack(list_of_lists)

# %% [markdown]
# **Grid Search**

# %%
# Determine best parameters for ARIMAX model

# Define the p, d, and q parameters to take any value between 0 and 4
p = d = q = range(0,4)

# Generate all different combinations of p, d, and q triplets
pdq = list(itertools.product(p, d, q))

# Run a grid with pdq parameters calculated to see corresponding AIC scores
ans_ARIMAX2 = []
for comb in pdq:
    try:
        mod = sm.tsa.ARIMA(endog=y_train,
                           exog=exog,
                           order=comb)
        output = mod.fit()
        ans_ARIMAX2.append([comb, output.aic])
        print('ARIMAX {} : AIC Calculated ={}'.format(comb,output.aic))
    except:
        continue
# Out:
# ARIMAX (0, 0, 0) : AIC Calculated =24167.71336543413
# ARIMAX (0, 0, 1) : AIC Calculated =23550.440222941696
# ARIMAX (0, 0, 2) : AIC Calculated =23340.296632475096
# ARIMAX (0, 0, 3) : AIC Calculated =23227.26498067534
# ARIMAX (0, 1, 0) : AIC Calculated =24068.97245094774
# ARIMAX (0, 1, 1) : AIC Calculated =22967.578355526726
# ARIMAX (0, 1, 2) : AIC Calculated =22917.972682335316
# ARIMAX (0, 1, 3) : AIC Calculated =22916.41322018263
# ARIMAX (0, 2, 0) : AIC Calculated =26944.304241629583
# ARIMAX (0, 2, 1) : AIC Calculated =24394.67596671964
# ARIMAX (0, 2, 2) : AIC Calculated =23187.39900830419
# ARIMAX (0, 2, 3) : AIC Calculated =23146.756077444985
# ARIMAX (1, 0, 0) : AIC Calculated =23165.728895586642
# ARIMAX (1, 0, 1) : AIC Calculated =22668.009816971695
# ARIMAX (1, 0, 2) : AIC Calculated =22610.52718141072
# ARIMAX (1, 0, 3) : AIC Calculated =22609.029698123148
# ARIMAX (1, 1, 0) : AIC Calculated =23610.20867261725
# ARIMAX (1, 1, 1) : AIC Calculated =22913.034968410575
# ARIMAX (1, 1, 2) : AIC Calculated =22899.71925172256
# ARIMAX (1, 1, 3) : AIC Calculated =22919.358237240398
# ARIMAX (1, 2, 0) : AIC Calculated =25855.233800081893
# ARIMAX (1, 2, 2) : AIC Calculated =23148.881195305214
# ARIMAX (1, 2, 3) : AIC Calculated =23189.292006517633
# ARIMAX (2, 0, 0) : AIC Calculated =22999.844445431736
# ARIMAX (2, 0, 1) : AIC Calculated =22606.31910734112
# ARIMAX (2, 0, 2) : AIC Calculated =22606.96484723909
# ARIMAX (2, 0, 3) : AIC Calculated =22610.447455530353
# ARIMAX (2, 1, 0) : AIC Calculated =23339.7880810586
# ARIMAX (2, 1, 1) : AIC Calculated =22912.666871220772
# ARIMAX (2, 1, 2) : AIC Calculated =22916.374142391724
# ARIMAX (2, 1, 3) : AIC Calculated =22898.4417676802
# ARIMAX (2, 2, 0) : AIC Calculated =25159.109496354515
# ARIMAX (2, 2, 1) : AIC Calculated =23553.899573033123
# ARIMAX (2, 2, 2) : AIC Calculated =23155.986725284263
# ARIMAX (2, 2, 3) : AIC Calculated =23157.623786718934
# ARIMAX (3, 0, 0) : AIC Calculated =22889.232407894146
# ARIMAX (3, 0, 1) : AIC Calculated =22607.52866382877
# ARIMAX (3, 0, 2) : AIC Calculated =22609.27062046147
# ARIMAX (3, 0, 3) : AIC Calculated =22610.942145791396
# ARIMAX (3, 1, 0) : AIC Calculated =23185.240877559216
# ARIMAX (3, 1, 1) : AIC Calculated =22903.679715474835
# ARIMAX (3, 1, 2) : AIC Calculated =22889.760318160697
# ARIMAX (3, 1, 3) : AIC Calculated =22799.937492019013
# ARIMAX (3, 2, 0) : AIC Calculated =24529.63591426516
# ARIMAX (3, 2, 1) : AIC Calculated =23421.776330748027
# ARIMAX (3, 2, 2) : AIC Calculated =23124.359133454258
# ARIMAX (3, 2, 3) : AIC Calculated =23157.674942780217

# %%
# Find parameters with minimal AIC value
df_AIC = pd.DataFrame(ans_ARIMAX2, columns=['pdq', 'aic'])
df_AIC.sort_values(by='aic', ascending=True, inplace=True)
df_AIC[:10]
# Out:
#           pdq           aic
# 24  (2, 0, 1)  22606.319107
# 25  (2, 0, 2)  22606.964847
# 36  (3, 0, 1)  22607.528664
# 15  (1, 0, 3)  22609.029698
# 37  (3, 0, 2)  22609.270620
# 26  (2, 0, 3)  22610.447456
# 14  (1, 0, 2)  22610.527181
# 38  (3, 0, 3)  22610.942146
# 13  (1, 0, 1)  22668.009817
# 42  (3, 1, 3)  22799.937492

# %% [markdown]
# **Determining Best Parameters**

# %% [markdown]
# Observe lowest 10 AIC score parameter values to determine best model. Make sure p values are significant, and observe RMSEs to determind best overall model.

# %%
for pdq in df_AIC['pdq'][:10]:
    mod = sm.tsa.ARIMA(endog=y_train,
                       exog=exog,
                       order=pdq)
    mod_fit = mod.fit()
    print(mod_fit.summary())
# Out:
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:          Accidents_Qns   No. Observations:                 2532
# Model:                     ARMA(2, 1)   Log Likelihood              -11294.160
# Method:                       css-mle   S.D. of innovations             20.932
# Date:                Tue, 16 Feb 2021   AIC                          22606.319
# Time:                        11:55:04   BIC                          22658.850
# Sample:                    07-01-2012   HQIC                         22625.378
#                          - 06-06-2019
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                 153.3685     10.067     15.235      0.000     133.638     173.099
# x1                     -1.5672      0.935     -1.675      0.094      -3.401       0.266
# x2                      2.4571      0.209     11.738      0.000       2.047       2.867
# x3                    -24.0957      0.943    -25.561      0.000     -25.943     -22.248
# x4                    -37.0951      2.359    -15.723      0.000     -41.719     -32.471
# ar.L1.Accidents_Qns     1.1860      0.023     52.127      0.000       1.141       1.231
# ar.L2.Accidents_Qns    -0.1882      0.022     -8.398      0.000      -0.232      -0.144
# ma.L1.Accidents_Qns    -0.9418      0.010    -95.266      0.000      -0.961      -0.922
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0027           +0.0000j            1.0027            0.0000
# AR.2            5.3000           +0.0000j            5.3000            0.0000
# MA.1            1.0618           +0.0000j            1.0618            0.0000
# -----------------------------------------------------------------------------
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:          Accidents_Qns   No. Observations:                 2532
# Model:                     ARMA(2, 2)   Log Likelihood              -11293.482
# Method:                       css-mle   S.D. of innovations             20.926
# Date:                Tue, 16 Feb 2021   AIC                          22606.965
# Time:                        11:55:08   BIC                          22665.332
# Sample:                    07-01-2012   HQIC                         22628.141
#                          - 06-06-2019
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                 153.2714     10.638     14.408      0.000     132.422     174.121
# x1                     -1.5803      0.919     -1.720      0.085      -3.381       0.221
# x2                      2.4643      0.207     11.907      0.000       2.059       2.870
# x3                    -24.0386      0.932    -25.797      0.000     -25.865     -22.212
# x4                    -36.5829      2.389    -15.310      0.000     -41.266     -31.900
# ar.L1.Accidents_Qns     1.3673      0.135     10.148      0.000       1.103       1.631
# ar.L2.Accidents_Qns    -0.3687      0.134     -2.747      0.006      -0.632      -0.106
# ma.L1.Accidents_Qns    -1.1300      0.143     -7.926      0.000      -1.409      -0.851
# ma.L2.Accidents_Qns     0.1716      0.131      1.310      0.190      -0.085       0.428
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0023           +0.0000j            1.0023            0.0000
# AR.2            2.7057           +0.0000j            2.7057            0.0000
# MA.1            1.0536           +0.0000j            1.0536            0.0000
# MA.2            5.5295           +0.0000j            5.5295            0.0000
# -----------------------------------------------------------------------------
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:          Accidents_Qns   No. Observations:                 2532
# Model:                     ARMA(3, 1)   Log Likelihood              -11293.764
# Method:                       css-mle   S.D. of innovations             20.928
# Date:                Tue, 16 Feb 2021   AIC                          22607.529
# Time:                        11:55:13   BIC                          22665.896
# Sample:                    07-01-2012   HQIC                         22628.705
#                          - 06-06-2019
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                 153.3277     10.350     14.815      0.000     133.043     173.613
# x1                     -1.5762      0.927     -1.701      0.089      -3.393       0.240
# x2                      2.4645      0.209     11.820      0.000       2.056       2.873
# x3                    -24.1003      0.934    -25.793      0.000     -25.932     -22.269
# x4                    -36.8297      2.375    -15.509      0.000     -41.484     -32.175
# ar.L1.Accidents_Qns     1.1866      0.022     52.833      0.000       1.143       1.231
# ar.L2.Accidents_Qns    -0.1692      0.031     -5.483      0.000      -0.230      -0.109
# ar.L3.Accidents_Qns    -0.0194      0.022     -0.890      0.373      -0.062       0.023
# ma.L1.Accidents_Qns    -0.9455      0.010    -93.876      0.000      -0.965      -0.926
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0025           +0.0000j            1.0025            0.0000
# AR.2            3.8004           +0.0000j            3.8004            0.0000
# AR.3          -13.5166           +0.0000j           13.5166            0.5000
# MA.1            1.0577           +0.0000j            1.0577            0.0000
# -----------------------------------------------------------------------------
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:          Accidents_Qns   No. Observations:                 2532
# Model:                     ARMA(1, 3)   Log Likelihood              -11294.515
# Method:                       css-mle   S.D. of innovations             20.935
# Date:                Tue, 16 Feb 2021   AIC                          22609.030
# Time:                        11:55:18   BIC                          22667.397
# Sample:                    07-01-2012   HQIC                         22630.206
#                          - 06-06-2019
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                 153.3521      9.976     15.372      0.000     133.800     172.905
# x1                     -1.5648      0.939     -1.667      0.095      -3.404       0.275
# x2                      2.4631      0.210     11.732      0.000       2.052       2.875
# x3                    -24.1352      0.945    -25.542      0.000     -25.987     -22.283
# x4                    -37.0717      2.370    -15.643      0.000     -41.717     -32.427
# ar.L1.Accidents_Qns     0.9972      0.002    588.009      0.000       0.994       1.001
# ma.L1.Accidents_Qns    -0.7564      0.020    -37.651      0.000      -0.796      -0.717
# ma.L2.Accidents_Qns    -0.1345      0.025     -5.454      0.000      -0.183      -0.086
# ma.L3.Accidents_Qns    -0.0364      0.019     -1.875      0.061      -0.074       0.002
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0028           +0.0000j            1.0028            0.0000
# MA.1            1.0632           -0.0000j            1.0632           -0.0000
# MA.2           -2.3796           -4.4924j            5.0837           -0.3275
# MA.3           -2.3796           +4.4924j            5.0837            0.3275
# -----------------------------------------------------------------------------
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:          Accidents_Qns   No. Observations:                 2532
# Model:                     ARMA(3, 2)   Log Likelihood              -11293.635
# Method:                       css-mle   S.D. of innovations             20.927
# Date:                Tue, 16 Feb 2021   AIC                          22609.271
# Time:                        11:55:25   BIC                          22673.475
# Sample:                    07-01-2012   HQIC                         22632.565
#                          - 06-06-2019
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                 153.3424     10.193     15.044      0.000     133.364     173.321
# x1                     -1.5723      0.931     -1.688      0.091      -3.398       0.253
# x2                      2.4647      0.209     11.800      0.000       2.055       2.874
# x3                    -24.1483      0.939    -25.704      0.000     -25.990     -22.307
# x4                    -36.9231      2.363    -15.624      0.000     -41.555     -32.291
# ar.L1.Accidents_Qns     0.4475      0.217      2.061      0.039       0.022       0.873
# ar.L2.Accidents_Qns     0.7031      0.251      2.800      0.005       0.211       1.195
# ar.L3.Accidents_Qns    -0.1543      0.042     -3.697      0.000      -0.236      -0.073
# ma.L1.Accidents_Qns    -0.2052      0.217     -0.946      0.344      -0.631       0.220
# ma.L2.Accidents_Qns    -0.6965      0.203     -3.425      0.001      -1.095      -0.298
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0026           +0.0000j            1.0026            0.0000
# AR.2           -1.3248           +0.0000j            1.3248            0.5000
# AR.3            4.8795           +0.0000j            4.8795            0.0000
# MA.1            1.0600           +0.0000j            1.0600            0.0000
# MA.2           -1.3546           +0.0000j            1.3546            0.5000
# -----------------------------------------------------------------------------
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:          Accidents_Qns   No. Observations:                 2532
# Model:                     ARMA(2, 3)   Log Likelihood              -11294.224
# Method:                       css-mle   S.D. of innovations             20.932
# Date:                Tue, 16 Feb 2021   AIC                          22610.447
# Time:                        11:55:29   BIC                          22674.652
# Sample:                    07-01-2012   HQIC                         22633.742
#                          - 06-06-2019
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                 153.3627      9.713     15.790      0.000     134.326     172.400
# x1                     -1.5518      0.948     -1.637      0.102      -3.409       0.306
# x2                      2.4537      0.210     11.697      0.000       2.043       2.865
# x3                    -24.1284      0.949    -25.437      0.000     -25.988     -22.269
# x4                    -37.2441      2.364    -15.757      0.000     -41.877     -32.611
# ar.L1.Accidents_Qns     0.3323      0.194      1.715      0.086      -0.047       0.712
# ar.L2.Accidents_Qns     0.6627      0.193      3.433      0.001       0.284       1.041
# ma.L1.Accidents_Qns    -0.0906      0.194     -0.468      0.640      -0.470       0.289
# ma.L2.Accidents_Qns    -0.6450      0.152     -4.255      0.000      -0.942      -0.348
# ma.L3.Accidents_Qns    -0.1386      0.033     -4.225      0.000      -0.203      -0.074
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0030           +0.0000j            1.0030            0.0000
# AR.2           -1.5044           +0.0000j            1.5044            0.5000
# MA.1            1.0674           +0.0000j            1.0674            0.0000
# MA.2           -1.6677           +0.0000j            1.6677            0.5000
# MA.3           -4.0541           +0.0000j            4.0541            0.5000
# -----------------------------------------------------------------------------
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:          Accidents_Qns   No. Observations:                 2532
# Model:                     ARMA(1, 2)   Log Likelihood              -11296.264
# Method:                       css-mle   S.D. of innovations             20.949
# Date:                Tue, 16 Feb 2021   AIC                          22610.527
# Time:                        11:55:33   BIC                          22663.058
# Sample:                    07-01-2012   HQIC                         22629.586
#                          - 06-06-2019
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                 153.3570      9.404     16.308      0.000     134.925     171.788
# x1                     -1.5342      0.960     -1.599      0.110      -3.415       0.347
# x2                      2.4371      0.210     11.625      0.000       2.026       2.848
# x3                    -23.9576      0.947    -25.304      0.000     -25.813     -22.102
# x4                    -37.4679      2.363    -15.853      0.000     -42.100     -32.836
# ar.L1.Accidents_Qns     0.9967      0.002    530.751      0.000       0.993       1.000
# ma.L1.Accidents_Qns    -0.7608      0.019    -39.362      0.000      -0.799      -0.723
# ma.L2.Accidents_Qns    -0.1600      0.020     -8.026      0.000      -0.199      -0.121
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0033           +0.0000j            1.0033            0.0000
# MA.1            1.0725           +0.0000j            1.0725            0.0000
# MA.2           -5.8269           +0.0000j            5.8269            0.5000
# -----------------------------------------------------------------------------
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:          Accidents_Qns   No. Observations:                 2532
# Model:                     ARMA(3, 3)   Log Likelihood              -11293.471
# Method:                       css-mle   S.D. of innovations             20.926
# Date:                Tue, 16 Feb 2021   AIC                          22610.942
# Time:                        11:55:39   BIC                          22680.983
# Sample:                    07-01-2012   HQIC                         22636.354
#                          - 06-06-2019
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                 153.2763     10.574     14.495      0.000     132.551     174.002
# x1                     -1.5797      0.921     -1.716      0.086      -3.384       0.225
# x2                      2.4656      0.207     11.891      0.000       2.059       2.872
# x3                    -24.0654      0.949    -25.347      0.000     -25.926     -22.205
# x4                    -36.6256      2.419    -15.139      0.000     -41.367     -31.884
# ar.L1.Accidents_Qns     0.5419      0.409      1.326      0.185      -0.259       1.343
# ar.L2.Accidents_Qns     0.7319      0.495      1.480      0.139      -0.238       1.701
# ar.L3.Accidents_Qns    -0.2765      0.235     -1.175      0.240      -0.738       0.185
# ma.L1.Accidents_Qns    -0.3038      0.413     -0.735      0.462      -1.114       0.506
# ma.L2.Accidents_Qns    -0.7342      0.410     -1.790      0.073      -1.538       0.070
# ma.L3.Accidents_Qns     0.1166      0.203      0.574      0.566      -0.281       0.515
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -1.2476           +0.0000j            1.2476            0.5000
# AR.2            1.0024           +0.0000j            1.0024            0.0000
# AR.3            2.8916           +0.0000j            2.8916            0.0000
# MA.1            1.0545           +0.0000j            1.0545            0.0000
# MA.2           -1.2523           +0.0000j            1.2523            0.5000
# MA.3            6.4926           +0.0000j            6.4926            0.0000
# -----------------------------------------------------------------------------
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:          Accidents_Qns   No. Observations:                 2532
# Model:                     ARMA(1, 1)   Log Likelihood              -11326.005
# Method:                       css-mle   S.D. of innovations             21.198
# Date:                Tue, 16 Feb 2021   AIC                          22668.010
# Time:                        11:55:42   BIC                          22714.704
# Sample:                    07-01-2012   HQIC                         22684.951
#                          - 06-06-2019
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                 152.5081      6.676     22.845      0.000     139.424     165.592
# x1                     -1.3301      1.131     -1.176      0.239      -3.546       0.886
# x2                      2.4062      0.200     12.035      0.000       2.014       2.798
# x3                    -23.1661      0.883    -26.224      0.000     -24.897     -21.435
# x4                    -36.5346      2.339    -15.620      0.000     -41.119     -31.950
# ar.L1.Accidents_Qns     0.9911      0.004    277.746      0.000       0.984       0.998
# ma.L1.Accidents_Qns    -0.8698      0.018    -47.129      0.000      -0.906      -0.834
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0089           +0.0000j            1.0089            0.0000
# MA.1            1.1497           +0.0000j            1.1497            0.0000
# -----------------------------------------------------------------------------
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:        D.Accidents_Qns   No. Observations:                 2531
# Model:                 ARIMA(3, 1, 3)   Log Likelihood              -11387.969
# Method:                       css-mle   S.D. of innovations             21.725
# Date:                Tue, 16 Feb 2021   AIC                          22799.937
# Time:                        11:56:10   BIC                          22869.974
# Sample:                    07-02-2012   HQIC                         22825.348
#                          - 06-06-2019
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    14.4231      1.031     13.987      0.000      12.402      16.444
# x1                       -0.0535      0.026     -2.023      0.043      -0.105      -0.002
# x2                       -2.3076      0.244     -9.463      0.000      -2.786      -1.830
# x3                      -16.8497      1.117    -15.083      0.000     -19.039     -14.660
# x4                       -6.8188      0.893     -7.640      0.000      -8.568      -5.069
# ar.L1.D.Accidents_Qns    -0.2554      0.005    -55.288      0.000      -0.264      -0.246
# ar.L2.D.Accidents_Qns    -0.9155      0.002   -446.007      0.000      -0.919      -0.911
# ar.L3.D.Accidents_Qns     0.1896      0.005     41.147      0.000       0.181       0.199
# ma.L1.D.Accidents_Qns    -0.5188      0.010    -54.194      0.000      -0.538      -0.500
# ma.L2.D.Accidents_Qns     0.5760      0.005    110.614      0.000       0.566       0.586
# ma.L3.D.Accidents_Qns    -0.9599      0.010    -95.463      0.000      -0.980      -0.940
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -0.2225           -0.9750j            1.0001           -0.2857
# AR.2           -0.2225           +0.9750j            1.0001            0.2857
# AR.3            5.2724           -0.0000j            5.2724           -0.0000
# MA.1           -0.2207           -0.9755j            1.0001           -0.2854
# MA.2           -0.2207           +0.9755j            1.0001            0.2854
# MA.3            1.0415           -0.0000j            1.0415           -0.0000
# -----------------------------------------------------------------------------

# %% [markdown]
# We don't see any significant p values above, so will look at the next 10 lowest AIC scores.

# %%
for pdq in df_AIC['pdq'][10:20]:
    mod = sm.tsa.ARIMA(endog=y_train,
                       exog=exog,
                       order=pdq)
    mod_fit = mod.fit()
    print(mod_fit.summary())
# Out:
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:          Accidents_Qns   No. Observations:                 2532
# Model:                     ARMA(3, 0)   Log Likelihood              -11435.616
# Method:                       css-mle   S.D. of innovations             22.140
# Date:                Tue, 16 Feb 2021   AIC                          22889.232
# Time:                        11:56:12   BIC                          22941.763
# Sample:                    07-01-2012   HQIC                         22908.291
#                          - 06-06-2019
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                 150.3973      3.765     39.950      0.000     143.019     157.776
# x1                     -0.6452      1.293     -0.499      0.618      -3.179       1.888
# x2                      2.3968      0.192     12.480      0.000       2.020       2.773
# x3                    -23.0790      0.873    -26.426      0.000     -24.791     -21.367
# x4                    -34.3542      2.354    -14.594      0.000     -38.968     -29.740
# ar.L1.Accidents_Qns     0.3700      0.020     18.927      0.000       0.332       0.408
# ar.L2.Accidents_Qns     0.1664      0.021      8.067      0.000       0.126       0.207
# ar.L3.Accidents_Qns     0.2124      0.020     10.754      0.000       0.174       0.251
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.1695           -0.0000j            1.1695           -0.0000
# AR.2           -0.9765           -1.7530j            2.0066           -0.3309
# AR.3           -0.9765           +1.7530j            2.0066            0.3309
# -----------------------------------------------------------------------------
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:        D.Accidents_Qns   No. Observations:                 2531
# Model:                 ARIMA(3, 1, 2)   Log Likelihood              -11433.880
# Method:                       css-mle   S.D. of innovations             22.154
# Date:                Tue, 16 Feb 2021   AIC                          22889.760
# Time:                        11:56:20   BIC                          22953.960
# Sample:                    07-02-2012   HQIC                         22913.053
#                          - 06-06-2019
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    15.8857      0.932     17.046      0.000      14.059      17.712
# x1                       -0.0764      0.025     -3.045      0.002      -0.126      -0.027
# x2                       -2.3713      0.220    -10.772      0.000      -2.803      -1.940
# x3                      -20.8355      1.031    -20.214      0.000     -22.856     -18.815
# x4                       -7.1860      0.972     -7.395      0.000      -9.091      -5.281
# ar.L1.D.Accidents_Qns     0.8911      0.081     11.046      0.000       0.733       1.049
# ar.L2.D.Accidents_Qns    -0.1024      0.030     -3.411      0.001      -0.161      -0.044
# ar.L3.D.Accidents_Qns     0.0518      0.024      2.136      0.033       0.004       0.099
# ma.L1.D.Accidents_Qns    -1.6901      0.078    -21.777      0.000      -1.842      -1.538
# ma.L2.D.Accidents_Qns     0.6929      0.076      9.068      0.000       0.543       0.843
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.1869           -0.0000j            1.1869           -0.0000
# AR.2            0.3944           -4.0128j            4.0322           -0.2344
# AR.3            0.3944           +4.0128j            4.0322            0.2344
# MA.1            1.0094           +0.0000j            1.0094            0.0000
# MA.2            1.4298           +0.0000j            1.4298            0.0000
# -----------------------------------------------------------------------------
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:        D.Accidents_Qns   No. Observations:                 2531
# Model:                 ARIMA(2, 1, 3)   Log Likelihood              -11438.221
# Method:                       css-mle   S.D. of innovations             22.192
# Date:                Tue, 16 Feb 2021   AIC                          22898.442
# Time:                        11:56:30   BIC                          22962.642
# Sample:                    07-02-2012   HQIC                         22921.735
#                          - 06-06-2019
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    16.0120      0.904     17.711      0.000      14.240      17.784
# x1                       -0.0733      0.025     -2.980      0.003      -0.121      -0.025
# x2                       -2.4116      0.214    -11.263      0.000      -2.831      -1.992
# x3                      -20.7614      0.957    -21.697      0.000     -22.637     -18.886
# x4                       -7.0170      0.947     -7.413      0.000      -8.872      -5.162
# ar.L1.D.Accidents_Qns    -0.1487      0.063     -2.367      0.018      -0.272      -0.026
# ar.L2.D.Accidents_Qns     0.7771      0.053     14.535      0.000       0.672       0.882
# ma.L1.D.Accidents_Qns    -0.6812      0.072     -9.491      0.000      -0.822      -0.541
# ma.L2.D.Accidents_Qns    -0.9504      0.037    -25.711      0.000      -1.023      -0.878
# ma.L3.D.Accidents_Qns     0.6386      0.062     10.224      0.000       0.516       0.761
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -1.0427           +0.0000j            1.0427            0.5000
# AR.2            1.2340           +0.0000j            1.2340            0.0000
# MA.1           -1.0287           +0.0000j            1.0287            0.5000
# MA.2            1.0107           +0.0000j            1.0107            0.0000
# MA.3            1.5062           +0.0000j            1.5062            0.0000
# -----------------------------------------------------------------------------
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:        D.Accidents_Qns   No. Observations:                 2531
# Model:                 ARIMA(1, 1, 2)   Log Likelihood              -11440.860
# Method:                       css-mle   S.D. of innovations             22.216
# Date:                Tue, 16 Feb 2021   AIC                          22899.719
# Time:                        11:56:34   BIC                          22952.247
# Sample:                    07-02-2012   HQIC                         22918.777
#                          - 06-06-2019
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    16.0145      0.901     17.782      0.000      14.249      17.780
# x1                       -0.0720      0.024     -2.957      0.003      -0.120      -0.024
# x2                       -2.4099      0.213    -11.294      0.000      -2.828      -1.992
# x3                      -20.8126      0.956    -21.760      0.000     -22.687     -18.938
# x4                       -6.9550      0.934     -7.446      0.000      -8.786      -5.124
# ar.L1.D.Accidents_Qns     0.7961      0.057     13.898      0.000       0.684       0.908
# ma.L1.D.Accidents_Qns    -1.6323      0.070    -23.416      0.000      -1.769      -1.496
# ma.L2.D.Accidents_Qns     0.6363      0.068      9.355      0.000       0.503       0.770
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.2560           +0.0000j            1.2560            0.0000
# MA.1            1.0112           +0.0000j            1.0112            0.0000
# MA.2            1.5542           +0.0000j            1.5542            0.0000
# -----------------------------------------------------------------------------
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:        D.Accidents_Qns   No. Observations:                 2531
# Model:                 ARIMA(3, 1, 1)   Log Likelihood              -11441.840
# Method:                       css-mle   S.D. of innovations             22.225
# Date:                Tue, 16 Feb 2021   AIC                          22903.680
# Time:                        11:56:39   BIC                          22962.043
# Sample:                    07-02-2012   HQIC                         22924.855
#                          - 06-06-2019
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    15.7979      0.937     16.868      0.000      13.962      17.634
# x1                       -0.0588      0.023     -2.572      0.010      -0.104      -0.014
# x2                       -2.3615      0.222    -10.652      0.000      -2.796      -1.927
# x3                      -20.9055      1.037    -20.161      0.000     -22.938     -18.873
# x4                       -6.4561      0.810     -7.972      0.000      -8.043      -4.869
# ar.L1.D.Accidents_Qns     0.1869      0.021      8.781      0.000       0.145       0.229
# ar.L2.D.Accidents_Qns     0.0279      0.021      1.324      0.185      -0.013       0.069
# ar.L3.D.Accidents_Qns     0.0730      0.022      3.343      0.001       0.030       0.116
# ma.L1.D.Accidents_Qns    -0.9786      0.007   -144.652      0.000      -0.992      -0.965
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.9396           -0.0000j            1.9396           -0.0000
# AR.2           -1.1606           -2.3905j            2.6574           -0.3219
# AR.3           -1.1606           +2.3905j            2.6574            0.3219
# MA.1            1.0218           +0.0000j            1.0218            0.0000
# -----------------------------------------------------------------------------
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:        D.Accidents_Qns   No. Observations:                 2531
# Model:                 ARIMA(2, 1, 1)   Log Likelihood              -11447.333
# Method:                       css-mle   S.D. of innovations             22.274
# Date:                Tue, 16 Feb 2021   AIC                          22912.667
# Time:                        11:56:42   BIC                          22965.194
# Sample:                    07-02-2012   HQIC                         22931.725
#                          - 06-06-2019
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    16.0358      0.986     16.262      0.000      14.103      17.969
# x1                       -0.0525      0.024     -2.199      0.028      -0.099      -0.006
# x2                       -2.3480      0.234    -10.028      0.000      -2.807      -1.889
# x3                      -21.9922      1.051    -20.917      0.000     -24.053     -19.931
# x4                       -6.3621      0.812     -7.834      0.000      -7.954      -4.770
# ar.L1.D.Accidents_Qns     0.1843      0.022      8.387      0.000       0.141       0.227
# ar.L2.D.Accidents_Qns     0.0331      0.021      1.546      0.122      -0.009       0.075
# ma.L1.D.Accidents_Qns    -0.9706      0.008   -114.587      0.000      -0.987      -0.954
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            3.3762           +0.0000j            3.3762            0.0000
# AR.2           -8.9390           +0.0000j            8.9390            0.5000
# MA.1            1.0303           +0.0000j            1.0303            0.0000
# -----------------------------------------------------------------------------
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:        D.Accidents_Qns   No. Observations:                 2531
# Model:                 ARIMA(1, 1, 1)   Log Likelihood              -11448.517
# Method:                       css-mle   S.D. of innovations             22.285
# Date:                Tue, 16 Feb 2021   AIC                          22913.035
# Time:                        11:56:46   BIC                          22959.726
# Sample:                    07-02-2012   HQIC                         22929.975
#                          - 06-06-2019
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    15.9537      0.996     16.010      0.000      14.001      17.907
# x1                       -0.0501      0.025     -2.003      0.045      -0.099      -0.001
# x2                       -2.3324      0.237     -9.852      0.000      -2.796      -1.868
# x3                      -21.9374      1.068    -20.533      0.000     -24.031     -19.843
# x4                       -6.4120      0.836     -7.665      0.000      -8.052      -4.773
# ar.L1.D.Accidents_Qns     0.1841      0.023      8.147      0.000       0.140       0.228
# ma.L1.D.Accidents_Qns    -0.9652      0.009   -103.975      0.000      -0.983      -0.947
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            5.4317           +0.0000j            5.4317            0.0000
# MA.1            1.0361           +0.0000j            1.0361            0.0000
# -----------------------------------------------------------------------------
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:        D.Accidents_Qns   No. Observations:                 2531
# Model:                 ARIMA(2, 1, 2)   Log Likelihood              -11448.187
# Method:                       css-mle   S.D. of innovations             22.282
# Date:                Tue, 16 Feb 2021   AIC                          22916.374
# Time:                        11:56:51   BIC                          22974.738
# Sample:                    07-02-2012   HQIC                         22937.550
#                          - 06-06-2019
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    15.9984      0.998     16.032      0.000      14.043      17.954
# x1                       -0.0507      0.025     -2.057      0.040      -0.099      -0.002
# x2                       -2.3362      0.237     -9.869      0.000      -2.800      -1.872
# x3                      -22.0388      1.073    -20.541      0.000     -24.142     -19.936
# x4                       -6.3881      0.828     -7.717      0.000      -8.011      -4.766
# ar.L1.D.Accidents_Qns    -0.4030      0.594     -0.678      0.498      -1.568       0.762
# ar.L2.D.Accidents_Qns     0.1228      0.104      1.177      0.239      -0.082       0.327
# ma.L1.D.Accidents_Qns    -0.3799      0.595     -0.638      0.523      -1.546       0.787
# ma.L2.D.Accidents_Qns    -0.5675      0.573     -0.990      0.322      -1.691       0.556
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -1.6509           +0.0000j            1.6509            0.5000
# AR.2            4.9320           +0.0000j            4.9320            0.0000
# MA.1            1.0343           +0.0000j            1.0343            0.0000
# MA.2           -1.7037           +0.0000j            1.7037            0.5000
# -----------------------------------------------------------------------------
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:        D.Accidents_Qns   No. Observations:                 2531
# Model:                 ARIMA(0, 1, 3)   Log Likelihood              -11449.207
# Method:                       css-mle   S.D. of innovations             22.291
# Date:                Tue, 16 Feb 2021   AIC                          22916.413
# Time:                        11:56:55   BIC                          22968.941
# Sample:                    07-02-2012   HQIC                         22935.471
#                          - 06-06-2019
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    15.9927      0.999     16.012      0.000      14.035      17.950
# x1                       -0.0495      0.025     -1.955      0.051      -0.099       0.000
# x2                       -2.3384      0.237     -9.873      0.000      -2.803      -1.874
# x3                      -21.9940      1.078    -20.395      0.000     -24.108     -19.880
# x4                       -6.4275      0.845     -7.609      0.000      -8.083      -4.772
# ma.L1.D.Accidents_Qns    -0.7872      0.020    -38.830      0.000      -0.827      -0.748
# ma.L2.D.Accidents_Qns    -0.1321      0.025     -5.228      0.000      -0.182      -0.083
# ma.L3.D.Accidents_Qns    -0.0367      0.019     -1.895      0.058      -0.075       0.001
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# MA.1            1.0375           -0.0000j            1.0375           -0.0000
# MA.2           -2.3208           -4.5720j            5.1273           -0.3248
# MA.3           -2.3208           +4.5720j            5.1273            0.3248
# -----------------------------------------------------------------------------
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:        D.Accidents_Qns   No. Observations:                 2531
# Model:                 ARIMA(0, 1, 2)   Log Likelihood              -11450.986
# Method:                       css-mle   S.D. of innovations             22.308
# Date:                Tue, 16 Feb 2021   AIC                          22917.973
# Time:                        11:56:57   BIC                          22964.664
# Sample:                    07-02-2012   HQIC                         22934.913
#                          - 06-06-2019
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    15.8674      0.994     15.966      0.000      13.919      17.815
# x1                       -0.0473      0.027     -1.727      0.084      -0.101       0.006
# x2                       -2.3324      0.236     -9.881      0.000      -2.795      -1.870
# x3                      -21.6364      1.057    -20.467      0.000     -23.708     -19.565
# x4                       -6.5949      0.901     -7.317      0.000      -8.362      -4.828
# ma.L1.D.Accidents_Qns    -0.7908      0.019    -40.612      0.000      -0.829      -0.753
# ma.L2.D.Accidents_Qns    -0.1577      0.021     -7.584      0.000      -0.198      -0.117
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# MA.1            1.0462           +0.0000j            1.0462            0.0000
# MA.2           -6.0602           +0.0000j            6.0602            0.5000
# -----------------------------------------------------------------------------

# %% [markdown]
# From the above, we see that the following parameters have significant p values:
#
# (3,1,2)
#
# (2,1,3)
#
# (1,1,2)
#
# (1,1,1)
#
# We will observe RMSE and AIC values for these to determine our best working model.

# %%
# For loop to apply RMSE function to significant parameters
for (pdq) in [(3,1,2),(2,1,3),(1,1,2),(1,1,1)]:
    mod = sm.tsa.ARIMA(endog=y_train,
                           exog=exog,
                           order=pdq)
    mod_fit = mod.fit()
    mod_pred = mod_fit.predict(start='2019-06-06', end='2020-03-13', exog = test.iloc[:,1:], dynamic=False)
    mod_RMSE = RMSE(mod_pred)
    mod_AIC = mod_fit.aic
    print(pdq,' RMSE: ', mod_RMSE)
    print(pdq,' AIC: ', mod_AIC)
# Out:
# (3, 1, 2)  RMSE:  160.729223671927
# (3, 1, 2)  AIC:  22889.760318160697
# (2, 1, 3)  RMSE:  160.7341750982656
# (2, 1, 3)  AIC:  22898.4417676802
# (1, 1, 2)  RMSE:  160.73398154191722
# (1, 1, 2)  AIC:  22899.71925172256
# (1, 1, 1)  RMSE:  160.72935921152285
# (1, 1, 1)  AIC:  22913.034968410575

# %% [markdown]
# Although by a tiny margin in both cases, our ARIMAX model with parameters (3,1,2) has slightly a better RMSE and AIC than the others. We will therefore consider this our best ARIMAX model.

# %%
# Define ARIMAX model
ARIMAX = sm.tsa.ARIMA(endog=y_train, exog=exog, order=(3,1,2))
ARIMAX_fit = ARIMAX.fit()
ARIMAX_pred = ARIMAX_fit.predict(start='2019-06-06', end='2020-03-13', exog = test.iloc[:,1:], dynamic=False)
ARIMAX_RMSE = RMSE(ARIMAX_pred)
ARIMAX_AIC = ARIMAX_fit.aic

# Compare ARIMA and ARIMAX model RMSEs and AICs

print('ARIMA model RMSE: ', base_RMSE)
print('ARIMA model AIC: ', base_AIC)

print('ARIMAX model RMSE: ', ARIMAX_RMSE)
print('ARIMAX model AIC: ', ARIMAX_AIC)
# Out:
# ARIMA model RMSE:  29.630639592651963
# ARIMA model AIC:  23436.562817326376
# ARIMAX model RMSE:  160.729223671927
# ARIMAX model AIC:  22889.760318160697

# %% [markdown]
# We see from the above that though our baseline model has a worse AIC score, it performs significantly better with RMSE. Since RMSE is what tells us more clearly how far off our predictions are, we will consider this the better model.

# %% [markdown]
# ## Model #3: Introducing Seasonality: SARIMA Model

# %% [markdown]
# Or data is seasonal, so we would expect a SARIMA model to produce better results than our baseline ARIMA one.

# %% [markdown]
# **Resample Weekly Data**

# %% [markdown]
# Since data is seasonal by year, our period value would ordinarily be 365 observations. This is too large for a SARIMA model, so will create a df with weekly data and instead use a period value of 52.

# %%
# Create df of weekly data
df_qns_wk = df_qns.resample('W')
df_qns_wk_mean = df_qns_wk.mean()

# %%
# When we introduce exogenous data, the weekend column won't be valuable--remove it
df_qns_wk_mean.drop(columns=['Weekend'], inplace=True)

# Change holiday column to be a 1 if there is any holiday that week,
# ie if the value is greater than 0
df_qns_wk_mean['Holiday'] = np.where(df_qns_wk_mean['Holiday']>0, 1, 0)

# Add in Season
df_qns_wk_mean['Season'] = 0

def season(month,season):
    df_qns_wk_mean['Season'] = np.where((df_qns_wk_mean.index.month==month),
                                         season,df_qns_wk_mean['Season'])

for month in range (1,4):
    season(month,2)
    
for month in range (4,7):
    season(month,3)
    
for month in range (7,10):
    season(month,4)

for month in range (10,13):
    season(month,1)

# Holiday
df_qns_wk_mean['Holiday'] = np.where(df_qns_wk_mean['Holiday']=='0',
                                      0, df_qns_wk_mean['Holiday'])
df_qns_wk_mean['Holiday'] = np.where(df_qns_wk_mean['Holiday']=='1',
                                      1, df_qns_wk_mean['Holiday'])

# Observe new df head
df_qns_wk_mean.head()
# Out:
#             Accidents_Qns  Holiday  Season
# Date
# 2012-07-01     119.000000        0       4
# 2012-07-08     127.571429        1       4
# 2012-07-15     115.571429        0       4
# 2012-07-22     134.428571        0       4
# 2012-07-29     124.571429        0       4

# %%
# Plot weekly data compared to daily
plt.plot(df_qns['Accidents_Qns'],color='mediumseagreen', label='Original')
plt.plot(df_qns_wk_mean['Accidents_Qns'], color='mediumblue', label='Weekly Mean')
plt.legend(loc='best')
plt.title('Weekly Mean, Queens')
plt.xlabel('Year')
plt.ylabel('Accidents')
plt.show(block=False)

# Dickey-Fuller test
test = adfuller(df_qns_wk_mean['Accidents_Qns'][:-1])
dfoutput = pd.Series(test[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
dfoutput
# Out:
# Test Statistic                  -2.397318
# p-value                          0.142495
# #Lags Used                       8.000000
# Number of Observations Used    393.000000
# dtype: float64

# %% [markdown]
# Based on the above Dickey-Fuller p-value, this data is not stationary. We will difference this data to attempt stationarity.

# %% [markdown]
# **Differencing**

# %%
# Difference data
diff = df_qns_wk_mean['Accidents_Qns'].diff()

# Plot differenced data
plt.plot(diff, color='palevioletred', label='Differenced Rolling Weekly Mean')
plt.title('Differenced Weekly Mean, Queens')
plt.xlabel('Year')
plt.ylabel('Accidents')
plt.show(block=False)

# Dickey-Fuller test
test = adfuller(diff[1:-1])
dfoutput = pd.Series(test[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
dfoutput
# Out:
# Test Statistic                -7.491219e+00
# p-value                        4.500260e-11
# #Lags Used                     1.700000e+01
# Number of Observations Used    3.830000e+02
# dtype: float64

# %% [markdown]
# Differencing once achieved stationarity, so we would expect our SARIMA model to have a d value of at least 1.

# %% [markdown]
# **ACF, PACF for Weekly Data**

# %%
# ACF for weekly data
plot_acf(df_qns_wk_mean['Accidents_Qns'], alpha=.05);

# PACF for weekly data
plot_pacf(df_qns_wk_mean['Accidents_Qns'], alpha=.05, lags=20);

# %% [markdown]
# **Redo Train-Test Split for Weekly Data**

# %%
# Determine split point for 90%/10% train-test split
split_point = int(len(df_qns_wk_mean) * 0.9)
df_qns_wk_mean.iloc[split_point]
# Out:
# Accidents_Qns    182.571429
# Holiday            0.000000
# Season             3.000000
# Name: 2019-06-09 00:00:00, dtype: float64

# %%
# Train-test split
# Based on the above, 2019-06-06 will be the split point for our train and test sets

X = df_qns_wk_mean.index
y = df_qns_wk_mean['Accidents_Qns']

train = df_qns_wk_mean.loc[:'2019-06-06']
test = df_qns_wk_mean.loc['2019-06-06':]

X_train, X_test = train.index , test.index
y_train, y_test = train['Accidents_Qns'] , test['Accidents_Qns']

# %% [markdown]
# **Grid Search for SARIMA Model**

# %%
# Determine best parameters for SARIMA model

# Define the p, d, and q parameters to take any value between 0 and 2
# Using smaller range due to many combinations
p = d = q = range(0,2)

# Generate all different combinations of p, d, and q triplets
pdq = list(itertools.product(p,d,q))

# Generate all different combinations of seasonal p, d, q triplets
# Choose s value of 52 because data is now weekly and a cycle is one year

pdqs = [(x[0],x[1],x[2], 52) for x in pdq]

# Run a grid search with pdq parameters calculated to see corresponding AIC scores
ans_SARIMA = []
for comb in pdq:
    for combs in tqdm_notebook(pdqs):
        try:
            mod = sm.tsa.statespace.SARIMAX(y_train,
                                            order=comb,
                                            seasonal_order=combs,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False)

            output = mod.fit()
            ans_SARIMA.append([comb, combs, output.aic])
            print('ARIMA {} x {}52 : AIC Calculated ={}'.format(comb, combs, output.aic))
        except:
            continue
# Out:
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# ARIMA (0, 0, 0) x (0, 0, 0, 52)52 : AIC Calculated =4654.545940008415
# ARIMA (0, 0, 0) x (0, 0, 1, 52)52 : AIC Calculated =3719.3256125236885
# ARIMA (0, 0, 0) x (0, 1, 0, 52)52 : AIC Calculated =2633.7152235485073
# ARIMA (0, 0, 0) x (0, 1, 1, 52)52 : AIC Calculated =2205.743200966206
# ARIMA (0, 0, 0) x (1, 0, 0, 52)52 : AIC Calculated =2589.9650271463747
# ARIMA (0, 0, 0) x (1, 0, 1, 52)52 : AIC Calculated =2492.956229202775
# ARIMA (0, 0, 0) x (1, 1, 0, 52)52 : AIC Calculated =2214.508976236013
# ARIMA (0, 0, 0) x (1, 1, 1, 52)52 : AIC Calculated =2207.741394010781
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# ARIMA (0, 0, 1) x (0, 0, 0, 52)52 : AIC Calculated =4201.037626323253
# ARIMA (0, 0, 1) x (0, 0, 1, 52)52 : AIC Calculated =3378.811608505699
# ARIMA (0, 0, 1) x (0, 1, 0, 52)52 : AIC Calculated =2575.8953868295835
# ARIMA (0, 0, 1) x (0, 1, 1, 52)52 : AIC Calculated =2143.5271675385648
# ARIMA (0, 0, 1) x (1, 0, 0, 52)52 : AIC Calculated =2563.0698176419774
# ARIMA (0, 0, 1) x (1, 0, 1, 52)52 : AIC Calculated =2556.1580118260795
# ARIMA (0, 0, 1) x (1, 1, 0, 52)52 : AIC Calculated =2157.226225222059
# ARIMA (0, 0, 1) x (1, 1, 1, 52)52 : AIC Calculated =2141.1613860094562
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# ARIMA (0, 1, 0) x (0, 0, 0, 52)52 : AIC Calculated =2973.810374703991
# ARIMA (0, 1, 0) x (0, 0, 1, 52)52 : AIC Calculated =2540.837449158304
# ARIMA (0, 1, 0) x (0, 1, 0, 52)52 : AIC Calculated =2650.145044495958
# ARIMA (0, 1, 0) x (0, 1, 1, 52)52 : AIC Calculated =2108.6110153110003
# ARIMA (0, 1, 0) x (1, 0, 0, 52)52 : AIC Calculated =2536.789125439712
# ARIMA (0, 1, 0) x (1, 0, 1, 52)52 : AIC Calculated =2523.953681913865
# ARIMA (0, 1, 0) x (1, 1, 0, 52)52 : AIC Calculated =2142.946397879461
# ARIMA (0, 1, 0) x (1, 1, 1, 52)52 : AIC Calculated =2113.865761106602
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# ARIMA (0, 1, 1) x (0, 0, 0, 52)52 : AIC Calculated =2845.7519194439533
# ARIMA (0, 1, 1) x (0, 0, 1, 52)52 : AIC Calculated =2427.271626533343
# ARIMA (0, 1, 1) x (0, 1, 0, 52)52 : AIC Calculated =2514.125103672593
# ARIMA (0, 1, 1) x (0, 1, 1, 52)52 : AIC Calculated =1990.9609664358263
# ARIMA (0, 1, 1) x (1, 0, 0, 52)52 : AIC Calculated =2425.759716787073
# ARIMA (0, 1, 1) x (1, 0, 1, 52)52 : AIC Calculated =2395.8462149875377
# ARIMA (0, 1, 1) x (1, 1, 0, 52)52 : AIC Calculated =2041.1332231735153
# ARIMA (0, 1, 1) x (1, 1, 1, 52)52 : AIC Calculated =2004.5761456712721
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# ARIMA (1, 0, 0) x (0, 0, 0, 52)52 : AIC Calculated =2982.7906171005097
# ARIMA (1, 0, 0) x (0, 0, 1, 52)52 : AIC Calculated =2549.442470290397
# ARIMA (1, 0, 0) x (0, 1, 0, 52)52 : AIC Calculated =2562.8470434697924
# ARIMA (1, 0, 0) x (0, 1, 1, 52)52 : AIC Calculated =2090.125073371376
# ARIMA (1, 0, 0) x (1, 0, 0, 52)52 : AIC Calculated =2537.516387213488
# ARIMA (1, 0, 0) x (1, 0, 1, 52)52 : AIC Calculated =2452.220400245241
# ARIMA (1, 0, 0) x (1, 1, 0, 52)52 : AIC Calculated =2097.3765981089973
# ARIMA (1, 0, 0) x (1, 1, 1, 52)52 : AIC Calculated =2093.8602752609722
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# ARIMA (1, 0, 1) x (0, 0, 0, 52)52 : AIC Calculated =2855.3259298830135
# ARIMA (1, 0, 1) x (0, 0, 1, 52)52 : AIC Calculated =2436.5134224005396
# ARIMA (1, 0, 1) x (0, 1, 0, 52)52 : AIC Calculated =2522.2347607363163
# ARIMA (1, 0, 1) x (0, 1, 1, 52)52 : AIC Calculated =1998.9875255575919
# ARIMA (1, 0, 1) x (1, 0, 0, 52)52 : AIC Calculated =2427.668362617168
# ARIMA (1, 0, 1) x (1, 0, 1, 52)52 : AIC Calculated =2405.812488286084
# ARIMA (1, 0, 1) x (1, 1, 0, 52)52 : AIC Calculated =2042.4940414498578
# ARIMA (1, 0, 1) x (1, 1, 1, 52)52 : AIC Calculated =2000.951877885503
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# ARIMA (1, 1, 0) x (0, 0, 0, 52)52 : AIC Calculated =2923.8830466505015
# ARIMA (1, 1, 0) x (0, 0, 1, 52)52 : AIC Calculated =2495.348088393099
# ARIMA (1, 1, 0) x (0, 1, 0, 52)52 : AIC Calculated =2602.602732182285
# ARIMA (1, 1, 0) x (0, 1, 1, 52)52 : AIC Calculated =2063.161353145329
# ARIMA (1, 1, 0) x (1, 0, 0, 52)52 : AIC Calculated =2483.690063543945
# ARIMA (1, 1, 0) x (1, 0, 1, 52)52 : AIC Calculated =2474.6028757750933
# ARIMA (1, 1, 0) x (1, 1, 0, 52)52 : AIC Calculated =2096.1336845824435
# ARIMA (1, 1, 0) x (1, 1, 1, 52)52 : AIC Calculated =2070.9426352731803
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# ARIMA (1, 1, 1) x (0, 0, 0, 52)52 : AIC Calculated =2839.1342905262363
# ARIMA (1, 1, 1) x (0, 0, 1, 52)52 : AIC Calculated =2420.9225106237454
# ARIMA (1, 1, 1) x (0, 1, 0, 52)52 : AIC Calculated =2506.4547916744696
# ARIMA (1, 1, 1) x (0, 1, 1, 52)52 : AIC Calculated =1987.7061120212716
# ARIMA (1, 1, 1) x (1, 0, 0, 52)52 : AIC Calculated =2411.539799251661
# ARIMA (1, 1, 1) x (1, 0, 1, 52)52 : AIC Calculated =2390.03687561669
# ARIMA (1, 1, 1) x (1, 1, 0, 52)52 : AIC Calculated =2026.8173445317002
# ARIMA (1, 1, 1) x (1, 1, 1, 52)52 : AIC Calculated =2000.092169128281

# %%
# Find parameters with minimal AIC value
SARIMA_AIC = pd.DataFrame(ans_SARIMA, columns=['pdq', 'pdqs', 'aic'])
SARIMA_AIC.sort_values(by='aic', ascending=True, inplace=True)
SARIMA_AIC[:10]
# Out:
#           pdq           pdqs          aic
# 59  (1, 1, 1)  (0, 1, 1, 52)  1987.706112
# 27  (0, 1, 1)  (0, 1, 1, 52)  1990.960966
# 43  (1, 0, 1)  (0, 1, 1, 52)  1998.987526
# 63  (1, 1, 1)  (1, 1, 1, 52)  2000.092169
# 47  (1, 0, 1)  (1, 1, 1, 52)  2000.951878
# 31  (0, 1, 1)  (1, 1, 1, 52)  2004.576146
# 62  (1, 1, 1)  (1, 1, 0, 52)  2026.817345
# 30  (0, 1, 1)  (1, 1, 0, 52)  2041.133223
# 46  (1, 0, 1)  (1, 1, 0, 52)  2042.494041
# 51  (1, 1, 0)  (0, 1, 1, 52)  2063.161353

# %% [markdown]
# **Narrowing Down Parameter Values**

# %% [markdown]
# Observe lowest 10 AIC score parameter values to determine best model. Make sure p values are significant, and observe RMSEs to determind best overall model.

# %%
for index,row in SARIMA_AIC[:10].iterrows():
    mod = sm.tsa.statespace.SARIMAX(y_train,
                                    order=SARIMA_AIC['pdq'][index],
                                    seasonal_order=SARIMA_AIC['pdqs'][index],
                                    enforce_stationarity=False,
                                    enforce_invertibility=False)

    mod_fit = mod.fit()
    print(mod_fit.summary())
# Out:
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                      Accidents_Qns   No. Observations:                  362
# Model:             SARIMAX(1, 1, 1)x(0, 1, 1, 52)   Log Likelihood                -989.853
# Date:                            Tue, 16 Feb 2021   AIC                           1987.706
# Time:                                    12:18:06   BIC                           2001.871
# Sample:                                07-01-2012   HQIC                          1993.404
#                                      - 06-02-2019
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.1590      0.065      2.456      0.014       0.032       0.286
# ma.L1         -0.9145      0.033    -27.894      0.000      -0.979      -0.850
# ma.S.L52      -0.7504      0.091     -8.218      0.000      -0.929      -0.571
# sigma2       127.9771     11.065     11.566      0.000     106.289     149.665
# ===================================================================================
# Ljung-Box (Q):                       47.71   Jarque-Bera (JB):                 6.42
# Prob(Q):                              0.19   Prob(JB):                         0.04
# Heteroskedasticity (H):               0.87   Skew:                            -0.19
# Prob(H) (two-sided):                  0.53   Kurtosis:                         3.68
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                      Accidents_Qns   No. Observations:                  362
# Model:             SARIMAX(0, 1, 1)x(0, 1, 1, 52)   Log Likelihood                -992.480
# Date:                            Tue, 16 Feb 2021   AIC                           1990.961
# Time:                                    12:18:11   BIC                           2001.585
# Sample:                                07-01-2012   HQIC                          1995.234
#                                      - 06-02-2019
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.8815      0.032    -27.421      0.000      -0.945      -0.818
# ma.S.L52      -0.7584      0.091     -8.332      0.000      -0.937      -0.580
# sigma2       130.2007     11.501     11.321      0.000     107.660     152.742
# ===================================================================================
# Ljung-Box (Q):                       50.00   Jarque-Bera (JB):                 6.61
# Prob(Q):                              0.13   Prob(JB):                         0.04
# Heteroskedasticity (H):               0.90   Skew:                            -0.25
# Prob(H) (two-sided):                  0.62   Kurtosis:                         3.60
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                      Accidents_Qns   No. Observations:                  362
# Model:             SARIMAX(1, 0, 1)x(0, 1, 1, 52)   Log Likelihood                -995.494
# Date:                            Tue, 16 Feb 2021   AIC                           1998.988
# Time:                                    12:18:26   BIC                           2013.168
# Sample:                                07-01-2012   HQIC                          2004.691
#                                      - 06-02-2019
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9960      0.004    237.301      0.000       0.988       1.004
# ma.L1         -0.8818      0.033    -26.880      0.000      -0.946      -0.818
# ma.S.L52      -0.7598      0.091     -8.349      0.000      -0.938      -0.581
# sigma2       129.1472     11.406     11.322      0.000     106.791     151.503
# ===================================================================================
# Ljung-Box (Q):                       49.84   Jarque-Bera (JB):                 6.97
# Prob(Q):                              0.14   Prob(JB):                         0.03
# Heteroskedasticity (H):               0.89   Skew:                            -0.25
# Prob(H) (two-sided):                  0.60   Kurtosis:                         3.63
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                      Accidents_Qns   No. Observations:                  362
# Model:             SARIMAX(1, 1, 1)x(1, 1, 1, 52)   Log Likelihood                -995.046
# Date:                            Tue, 16 Feb 2021   AIC                           2000.092
# Time:                                    12:18:33   BIC                           2017.798
# Sample:                                07-01-2012   HQIC                          2007.214
#                                      - 06-02-2019
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.1795      0.067      2.671      0.008       0.048       0.311
# ma.L1         -0.9087      0.035    -26.185      0.000      -0.977      -0.841
# ar.S.L52      -0.2805      0.087     -3.234      0.001      -0.451      -0.111
# ma.S.L52      -0.5074      0.107     -4.747      0.000      -0.717      -0.298
# sigma2       135.0143     10.684     12.638      0.000     114.075     155.954
# ===================================================================================
# Ljung-Box (Q):                       39.54   Jarque-Bera (JB):                 7.73
# Prob(Q):                              0.49   Prob(JB):                         0.02
# Heteroskedasticity (H):               0.79   Skew:                            -0.15
# Prob(H) (two-sided):                  0.28   Kurtosis:                         3.79
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                      Accidents_Qns   No. Observations:                  362
# Model:             SARIMAX(1, 0, 1)x(1, 1, 1, 52)   Log Likelihood                -995.476
# Date:                            Tue, 16 Feb 2021   AIC                           2000.952
# Time:                                    12:18:53   BIC                           2018.678
# Sample:                                07-01-2012   HQIC                          2008.081
#                                      - 06-02-2019
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9960      0.004    237.092      0.000       0.988       1.004
# ma.L1         -0.8820      0.033    -26.505      0.000      -0.947      -0.817
# ar.S.L52      -0.0012      0.030     -0.040      0.968      -0.061       0.058
# ma.S.L52      -0.7593      0.092     -8.225      0.000      -0.940      -0.578
# sigma2       129.1199     11.427     11.300      0.000     106.724     151.516
# ===================================================================================
# Ljung-Box (Q):                       49.85   Jarque-Bera (JB):                 6.96
# Prob(Q):                              0.14   Prob(JB):                         0.03
# Heteroskedasticity (H):               0.89   Skew:                            -0.25
# Prob(H) (two-sided):                  0.60   Kurtosis:                         3.63
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                      Accidents_Qns   No. Observations:                  362
# Model:             SARIMAX(0, 1, 1)x(1, 1, 1, 52)   Log Likelihood                -998.288
# Date:                            Tue, 16 Feb 2021   AIC                           2004.576
# Time:                                    12:18:59   BIC                           2018.741
# Sample:                                07-01-2012   HQIC                          2010.274
#                                      - 06-02-2019
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.8668      0.033    -25.883      0.000      -0.932      -0.801
# ar.S.L52      -0.2869      0.084     -3.424      0.001      -0.451      -0.123
# ma.S.L52      -0.5025      0.103     -4.868      0.000      -0.705      -0.300
# sigma2       138.7727     11.135     12.463      0.000     116.949     160.596
# ===================================================================================
# Ljung-Box (Q):                       45.50   Jarque-Bera (JB):                 7.17
# Prob(Q):                              0.25   Prob(JB):                         0.03
# Heteroskedasticity (H):               0.82   Skew:                            -0.23
# Prob(H) (two-sided):                  0.35   Kurtosis:                         3.68
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                       Accidents_Qns   No. Observations:                  362
# Model:             SARIMAX(1, 1, 1)x(1, 1, [], 52)   Log Likelihood               -1009.409
# Date:                             Tue, 16 Feb 2021   AIC                           2026.817
# Time:                                     12:19:03   BIC                           2040.998
# Sample:                                 07-01-2012   HQIC                          2032.521
#                                       - 06-02-2019
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.1870      0.066      2.814      0.005       0.057       0.317
# ma.L1         -0.9146      0.034    -27.299      0.000      -0.980      -0.849
# ar.S.L52      -0.5149      0.049    -10.469      0.000      -0.611      -0.418
# sigma2       155.1029     12.534     12.374      0.000     130.536     179.670
# ===================================================================================
# Ljung-Box (Q):                       41.19   Jarque-Bera (JB):                 4.81
# Prob(Q):                              0.42   Prob(JB):                         0.09
# Heteroskedasticity (H):               0.83   Skew:                            -0.25
# Prob(H) (two-sided):                  0.40   Kurtosis:                         3.45
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                       Accidents_Qns   No. Observations:                  362
# Model:             SARIMAX(0, 1, 1)x(1, 1, [], 52)   Log Likelihood               -1017.567
# Date:                             Tue, 16 Feb 2021   AIC                           2041.133
# Time:                                     12:19:06   BIC                           2051.780
# Sample:                                 07-01-2012   HQIC                          2045.415
#                                       - 06-02-2019
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.8766      0.031    -27.905      0.000      -0.938      -0.815
# ar.S.L52      -0.5109      0.047    -10.783      0.000      -0.604      -0.418
# sigma2       159.9969     13.064     12.247      0.000     134.392     185.602
# ===================================================================================
# Ljung-Box (Q):                       50.02   Jarque-Bera (JB):                 5.47
# Prob(Q):                              0.13   Prob(JB):                         0.07
# Heteroskedasticity (H):               0.85   Skew:                            -0.30
# Prob(H) (two-sided):                  0.45   Kurtosis:                         3.38
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                       Accidents_Qns   No. Observations:                  362
# Model:             SARIMAX(1, 0, 1)x(1, 1, [], 52)   Log Likelihood               -1017.247
# Date:                             Tue, 16 Feb 2021   AIC                           2042.494
# Time:                                     12:19:13   BIC                           2056.690
# Sample:                                 07-01-2012   HQIC                          2048.203
#                                       - 06-02-2019
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9931      0.007    140.322      0.000       0.979       1.007
# ma.L1         -0.8685      0.034    -25.275      0.000      -0.936      -0.801
# ar.S.L52      -0.5108      0.047    -10.762      0.000      -0.604      -0.418
# sigma2       159.4611     13.467     11.841      0.000     133.066     185.856
# ===================================================================================
# Ljung-Box (Q):                       49.83   Jarque-Bera (JB):                 5.14
# Prob(Q):                              0.14   Prob(JB):                         0.08
# Heteroskedasticity (H):               0.84   Skew:                            -0.29
# Prob(H) (two-sided):                  0.43   Kurtosis:                         3.38
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                        Accidents_Qns   No. Observations:                  362
# Model:             SARIMAX(1, 1, 0)x(0, 1, [1], 52)   Log Likelihood               -1028.581
# Date:                              Tue, 16 Feb 2021   AIC                           2063.161
# Time:                                      12:19:16   BIC                           2073.797
# Sample:                                  07-01-2012   HQIC                          2067.439
#                                        - 06-02-2019
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.4055      0.047     -8.658      0.000      -0.497      -0.314
# ma.S.L52      -0.7550      0.082     -9.162      0.000      -0.916      -0.593
# sigma2       167.7290     14.224     11.792      0.000     139.851     195.607
# ===================================================================================
# Ljung-Box (Q):                       82.72   Jarque-Bera (JB):                 8.19
# Prob(Q):                              0.00   Prob(JB):                         0.02
# Heteroskedasticity (H):               0.88   Skew:                            -0.17
# Prob(H) (two-sided):                  0.56   Kurtosis:                         3.81
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# Based on the above, we see that the following parameters yield significant p-values:
#
# (1,1,1)x(0,1,1,52)
#
# (0,1,1)x(0,1,1,52)
#
# (1,0,1)x(0,1,1,52)
#
# (1,1,1)x(1,1,1,52)
#
# (0,1,1)x(1,1,1,52)
#
# (1,1,1)x(1,1,0,52)
#
# (0,1,1)x(1,1,0,52)
#
# (1,0,1)x(1,1,0,52)
#
# (1,1,0)x(0,1,1,52)
#
#
# We wil observe RMSE and AIC values for these parameters to determine our best working model.

# %%
# For loop to apply RMSE function to significant parameters
for (pdq,pdqs) in [((1,1,1),(0,1,1,52)),((0,1,1),(0,1,1,52)),((1,0,1),(0,1,1,52)),
                 ((1,1,1),(1,1,1,52)),((0,1,1),(1,1,1,52)),((1,1,1),(1,1,0,52)),((0,1,1),(1,1,0,52)),
                  ((1,0,1),(1,1,0,52)),((1,1,0),(0,1,1,52))]:
    mod = sm.tsa.statespace.SARIMAX(y_train,
                                    order=pdq,
                                    seasonal_order=pdqs,
                                    enforce_stationarity=False,
                                    enforce_invertibility=False)
    mod_fit = mod.fit()
    mod_pred = mod_fit.predict(start='2019-06-06', end='2020-03-13',dynamic=False)
    print(pdq, 'x', pdqs,': RMSE: ', RMSE(mod_pred), 'AIC: ', mod_fit.aic)
# Out:
# (1, 1, 1) x (0, 1, 1, 52) : RMSE:  20.295852511472113 AIC:  1987.7061120212716
# (0, 1, 1) x (0, 1, 1, 52) : RMSE:  19.780061560646896 AIC:  1990.9609664358263
# (1, 0, 1) x (0, 1, 1, 52) : RMSE:  18.621181249077807 AIC:  1998.9875255575919
# (1, 1, 1) x (1, 1, 1, 52) : RMSE:  20.632962966823552 AIC:  2000.092169128281
# (0, 1, 1) x (1, 1, 1, 52) : RMSE:  20.044903956246817 AIC:  2004.5761456712721
# (1, 1, 1) x (1, 1, 0, 52) : RMSE:  17.598496886005567 AIC:  2026.8173445317002
# (0, 1, 1) x (1, 1, 0, 52) : RMSE:  17.083026657380817 AIC:  2041.1332231735153
# (1, 0, 1) x (1, 1, 0, 52) : RMSE:  17.472664875848437 AIC:  2042.4940414498578
# (1, 1, 0) x (0, 1, 1, 52) : RMSE:  17.52650204128359 AIC:  2063.161353145329

# %% [markdown]
# Based on its best RMSE value and only slightly worse AIC value, we see that parameters (0,1,1) x (1,1,0,52) give us our best SARIMA model. We will define this as our SARIMA model and compare it to our baseline ARIMA model.
#
# In order to compare RMSEs between daily and weekly data, we will divide RMSEs by the range of the number of accidents in each dataset. A smaller RMSE-to-range ratio will tell us which is our better RMSE. These will be labeled "Adjusted RMSE".

# %%
SARIMA = sm.tsa.statespace.SARIMAX(y_train,
                                   order=(0,1,1),
                                   seasonal_order=(1,1,0,52),
                                   enforce_stationarity=False,
                                   enforce_invertibility=False)
SARIMA_fit = SARIMA.fit()
SARIMA_pred = SARIMA_fit.predict(start='2019-06-06', end='2020-03-13',dynamic=False)
print('SARIMA RMSE: ', RMSE(SARIMA_pred))
print('Adjusted SARIMA RMSE: ',
      RMSE(SARIMA_pred)/(df_qns_wk_mean['Accidents_Qns'].max()-df_qns_wk_mean['Accidents_Qns'].min()))
print('SARIMA AIC: ', SARIMA_fit.aic)

print('ARIMA RMSE: ', base_RMSE)
print('Adjusted ARIMA RMSE: ',
      base_RMSE/(df_qns['Accidents_Qns'].max()-df_qns['Accidents_Qns'].min()))
print('ARIMA AIC: ', base_AIC)
# Out:
# SARIMA RMSE:  17.083026657380817
# Adjusted SARIMA RMSE:  0.146905634645781
# SARIMA AIC:  2041.1332231735153
# ARIMA RMSE:  29.630639592651963
# Adjusted ARIMA RMSE:  0.11223727118428774
# ARIMA AIC:  23436.562817326376

# %% [markdown]
# It is hard to determine which of the above models is better. Before narrowing down between these, let's take a look at a SARIMAX model to add into the mix.

# %% [markdown]
# ## Model #4: Incorporating Both Exogenous and Seasonal Variables: SARIMAX Model

# %% [markdown]
# Attempting a SARIMAX model incorporating both holiday and season variables as exogenous data did not yield any usable models. The p-value associated with "season" were consistently extremely high. Therefore re-ran only incorporating holiday as the exogenous variable. Other exogenous variables used in the earlier ARIMAX model are not replicable on a weekly basis.

# %% [markdown]
# **Grid Search**

# %%
# Determine best parameters for SARIMAX model
# Define the p, d, and q parameters to take any value between 0 and 2
p = d = q = range(0,2)

# Generate all different combinations of p, d, and q triplets
pdq = list(itertools.product(p,d,q))

# Generate all different combinations of seasonal p, d, q triplets
# Choose s value of 365 because data is daily and a cycle is one year

pdqs = [(x[0],x[1],x[2], 52) for x in pdq]

# Run a grid search with pdq parameters calculated to see corresponding AIC scores
ans_SARIMAX = []
for comb in pdq:
    for combs in tqdm_notebook(pdqs):
        try:
            mod = sm.tsa.statespace.SARIMAX(y_train,
                                            exog = train.iloc[:,1],
                                            order=comb,
                                            seasonal_order=combs,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False)

            output = mod.fit()
            ans_SARIMAX.append([comb, combs, output.aic])
            print('SARIMAX {} x {}52 : AIC Calculated ={}'.format(comb, combs, output.aic))
        except:
            continue
# Out:
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# SARIMAX (0, 0, 0) x (0, 0, 0, 52)52 : AIC Calculated =4595.928693045313
# SARIMAX (0, 0, 0) x (0, 0, 1, 52)52 : AIC Calculated =3695.1870544290737
# SARIMAX (0, 0, 0) x (0, 1, 0, 52)52 : AIC Calculated =2630.0002648824075
# SARIMAX (0, 0, 0) x (0, 1, 1, 52)52 : AIC Calculated =2202.174835895008
# SARIMAX (0, 0, 0) x (1, 0, 0, 52)52 : AIC Calculated =2584.902282275321
# SARIMAX (0, 0, 0) x (1, 0, 1, 52)52 : AIC Calculated =2486.7447273248117
# SARIMAX (0, 0, 0) x (1, 1, 0, 52)52 : AIC Calculated =2211.045249704941
# SARIMAX (0, 0, 0) x (1, 1, 1, 52)52 : AIC Calculated =2204.1729026299517
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# SARIMAX (0, 0, 1) x (0, 0, 0, 52)52 : AIC Calculated =4199.198620866657
# SARIMAX (0, 0, 1) x (0, 0, 1, 52)52 : AIC Calculated =3380.810684467896
# SARIMAX (0, 0, 1) x (0, 1, 0, 52)52 : AIC Calculated =2573.365983750158
# SARIMAX (0, 0, 1) x (0, 1, 1, 52)52 : AIC Calculated =2141.5861108797626
# SARIMAX (0, 0, 1) x (1, 0, 0, 52)52 : AIC Calculated =2559.298572970556
# SARIMAX (0, 0, 1) x (1, 0, 1, 52)52 : AIC Calculated =2609.526453667623
# SARIMAX (0, 0, 1) x (1, 1, 0, 52)52 : AIC Calculated =2156.069760068588
# SARIMAX (0, 0, 1) x (1, 1, 1, 52)52 : AIC Calculated =2140.4332260763085
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# SARIMAX (0, 1, 0) x (0, 0, 0, 52)52 : AIC Calculated =2932.0602928031153
# SARIMAX (0, 1, 0) x (0, 0, 1, 52)52 : AIC Calculated =2508.45740423638
# SARIMAX (0, 1, 0) x (0, 1, 0, 52)52 : AIC Calculated =2645.2200747136885
# SARIMAX (0, 1, 0) x (0, 1, 1, 52)52 : AIC Calculated =2094.6656771265316
# SARIMAX (0, 1, 0) x (1, 0, 0, 52)52 : AIC Calculated =2510.693948936121
# SARIMAX (0, 1, 0) x (1, 0, 1, 52)52 : AIC Calculated =2503.8598731556085
# SARIMAX (0, 1, 0) x (1, 1, 0, 52)52 : AIC Calculated =2138.4942766836057
# SARIMAX (0, 1, 0) x (1, 1, 1, 52)52 : AIC Calculated =2099.5887678867502
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# SARIMAX (0, 1, 1) x (0, 0, 0, 52)52 : AIC Calculated =2803.47919537312
# SARIMAX (0, 1, 1) x (0, 0, 1, 52)52 : AIC Calculated =2394.728265876667
# SARIMAX (0, 1, 1) x (0, 1, 0, 52)52 : AIC Calculated =2506.8615787560543
# SARIMAX (0, 1, 1) x (0, 1, 1, 52)52 : AIC Calculated =1976.4539546842107
# SARIMAX (0, 1, 1) x (1, 0, 0, 52)52 : AIC Calculated =2400.6742519165623
# SARIMAX (0, 1, 1) x (1, 0, 1, 52)52 : AIC Calculated =2379.7915741912
# SARIMAX (0, 1, 1) x (1, 1, 0, 52)52 : AIC Calculated =2034.0154079522254
# SARIMAX (0, 1, 1) x (1, 1, 1, 52)52 : AIC Calculated =1991.404634206007
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# SARIMAX (1, 0, 0) x (0, 0, 0, 52)52 : AIC Calculated =2942.3156240109884
# SARIMAX (1, 0, 0) x (0, 0, 1, 52)52 : AIC Calculated =2517.109421601952
# SARIMAX (1, 0, 0) x (0, 1, 0, 52)52 : AIC Calculated =2558.5008136008382
# SARIMAX (1, 0, 0) x (0, 1, 1, 52)52 : AIC Calculated =2080.1954700683355
# SARIMAX (1, 0, 0) x (1, 0, 0, 52)52 : AIC Calculated =2544.777416816488
# SARIMAX (1, 0, 0) x (1, 0, 1, 52)52 : AIC Calculated =2441.0535332552167
# SARIMAX (1, 0, 0) x (1, 1, 0, 52)52 : AIC Calculated =2093.480131735225
# SARIMAX (1, 0, 0) x (1, 1, 1, 52)52 : AIC Calculated =2085.551523932174
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# SARIMAX (1, 0, 1) x (0, 0, 0, 52)52 : AIC Calculated =4002.94529192126
# SARIMAX (1, 0, 1) x (0, 0, 1, 52)52 : AIC Calculated =3258.2979300674715
# SARIMAX (1, 0, 1) x (0, 1, 0, 52)52 : AIC Calculated =2514.889645509505
# SARIMAX (1, 0, 1) x (0, 1, 1, 52)52 : AIC Calculated =1984.427881877276
# SARIMAX (1, 0, 1) x (1, 0, 0, 52)52 : AIC Calculated =2560.7135805995485
# SARIMAX (1, 0, 1) x (1, 0, 1, 52)52 : AIC Calculated =3187.5645455938648
# SARIMAX (1, 0, 1) x (1, 1, 0, 52)52 : AIC Calculated =2035.3356490249398
# SARIMAX (1, 0, 1) x (1, 1, 1, 52)52 : AIC Calculated =1986.3887842622526
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# SARIMAX (1, 1, 0) x (0, 0, 0, 52)52 : AIC Calculated =2869.0909163976294
# SARIMAX (1, 1, 0) x (0, 0, 1, 52)52 : AIC Calculated =2453.267777750091
# SARIMAX (1, 1, 0) x (0, 1, 0, 52)52 : AIC Calculated =2593.115388753981
# SARIMAX (1, 1, 0) x (0, 1, 1, 52)52 : AIC Calculated =2041.7342034728658
# SARIMAX (1, 1, 0) x (1, 0, 0, 52)52 : AIC Calculated =2448.897914045715
# SARIMAX (1, 1, 0) x (1, 0, 1, 52)52 : AIC Calculated =2448.938183648441
# SARIMAX (1, 1, 0) x (1, 1, 0, 52)52 : AIC Calculated =2085.9113337069793
# SARIMAX (1, 1, 0) x (1, 1, 1, 52)52 : AIC Calculated =2050.261366051629
# HBox(children=(FloatProgress(value=0.0, max=8.0), HTML(value='')))
# SARIMAX (1, 1, 1) x (0, 0, 0, 52)52 : AIC Calculated =2799.10406795291
# SARIMAX (1, 1, 1) x (0, 0, 1, 52)52 : AIC Calculated =2390.748521805299
# SARIMAX (1, 1, 1) x (0, 1, 0, 52)52 : AIC Calculated =2500.364095201606
# SARIMAX (1, 1, 1) x (0, 1, 1, 52)52 : AIC Calculated =1973.9349210655687
# SARIMAX (1, 1, 1) x (1, 0, 0, 52)52 : AIC Calculated =2388.9927288726367
# SARIMAX (1, 1, 1) x (1, 0, 1, 52)52 : AIC Calculated =2375.2823499034503
# SARIMAX (1, 1, 1) x (1, 1, 0, 52)52 : AIC Calculated =2021.0779201808887
# SARIMAX (1, 1, 1) x (1, 1, 1, 52)52 : AIC Calculated =1975.9332456358834

# %%
# Find parameters with minimal AIC value
SARIMAX_AIC = pd.DataFrame(ans_SARIMAX, columns=['pdq', 'pdqs', 'aic'])
SARIMAX_AIC.sort_values(by='aic', ascending=True, inplace=True)
SARIMAX_AIC[:10]
# Out:
#           pdq           pdqs          aic
# 59  (1, 1, 1)  (0, 1, 1, 52)  1973.934921
# 63  (1, 1, 1)  (1, 1, 1, 52)  1975.933246
# 27  (0, 1, 1)  (0, 1, 1, 52)  1976.453955
# 43  (1, 0, 1)  (0, 1, 1, 52)  1984.427882
# 47  (1, 0, 1)  (1, 1, 1, 52)  1986.388784
# 31  (0, 1, 1)  (1, 1, 1, 52)  1991.404634
# 62  (1, 1, 1)  (1, 1, 0, 52)  2021.077920
# 30  (0, 1, 1)  (1, 1, 0, 52)  2034.015408
# 46  (1, 0, 1)  (1, 1, 0, 52)  2035.335649
# 51  (1, 1, 0)  (0, 1, 1, 52)  2041.734203

# %% [markdown]
# **Narrowing Down Model Parameters**

# %% [markdown]
# Observe lowest 10 AIC score parameter values to determine best model. Make sure p values are significant, and observe RMSEs to determind best overall model.

# %%
for index,row in SARIMAX_AIC[:10].iterrows():
    mod = sm.tsa.statespace.SARIMAX(y_train,
                                    exog = train.iloc[:,1],
                                    order=SARIMAX_AIC['pdq'][index],
                                    seasonal_order=SARIMAX_AIC['pdqs'][index],
                                    enforce_stationarity=False,
                                    enforce_invertibility=False)

    
    
    mod_fit = mod.fit()
    print(mod_fit.summary())
# Out:
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                      Accidents_Qns   No. Observations:                  362
# Model:             SARIMAX(1, 1, 1)x(0, 1, 1, 52)   Log Likelihood                -981.967
# Date:                            Tue, 16 Feb 2021   AIC                           1973.935
# Time:                                    12:38:20   BIC                           1991.641
# Sample:                                07-01-2012   HQIC                          1981.057
#                                      - 06-02-2019
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Holiday       -8.0109      2.194     -3.651      0.000     -12.312      -3.710
# ar.L1          0.1520      0.067      2.283      0.022       0.022       0.282
# ma.L1         -0.9081      0.035    -26.308      0.000      -0.976      -0.840
# ma.S.L52      -1.2187      0.182     -6.707      0.000      -1.575      -0.863
# sigma2        78.1840     18.424      4.244      0.000      42.074     114.294
# ===================================================================================
# Ljung-Box (Q):                       41.08   Jarque-Bera (JB):                10.97
# Prob(Q):                              0.42   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.78   Skew:                            -0.22
# Prob(H) (two-sided):                  0.26   Kurtosis:                         3.91
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                      Accidents_Qns   No. Observations:                  362
# Model:             SARIMAX(1, 1, 1)x(1, 1, 1, 52)   Log Likelihood                -981.967
# Date:                            Tue, 16 Feb 2021   AIC                           1975.933
# Time:                                    12:38:40   BIC                           1997.181
# Sample:                                07-01-2012   HQIC                          1984.480
#                                      - 06-02-2019
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Holiday       -8.0104      2.202     -3.638      0.000     -12.326      -3.695
# ar.L1          0.1520      0.067      2.267      0.023       0.021       0.283
# ma.L1         -0.9081      0.035    -25.838      0.000      -0.977      -0.839
# ar.S.L52   -8.385e-05      0.047     -0.002      0.999      -0.092       0.092
# ma.S.L52      -0.8204      0.133     -6.178      0.000      -1.081      -0.560
# sigma2       116.1291     12.256      9.475      0.000      92.108     140.151
# ===================================================================================
# Ljung-Box (Q):                       41.08   Jarque-Bera (JB):                10.97
# Prob(Q):                              0.42   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.78   Skew:                            -0.22
# Prob(H) (two-sided):                  0.26   Kurtosis:                         3.91
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                      Accidents_Qns   No. Observations:                  362
# Model:             SARIMAX(0, 1, 1)x(0, 1, 1, 52)   Log Likelihood                -984.227
# Date:                            Tue, 16 Feb 2021   AIC                           1976.454
# Time:                                    12:38:52   BIC                           1990.619
# Sample:                                07-01-2012   HQIC                          1982.152
#                                      - 06-02-2019
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Holiday       -8.6602      2.291     -3.781      0.000     -13.150      -4.170
# ma.L1         -0.8706      0.033    -26.225      0.000      -0.936      -0.805
# ma.S.L52      -0.8281      0.125     -6.649      0.000      -1.072      -0.584
# sigma2       117.6850     12.851      9.158      0.000      92.497     142.873
# ===================================================================================
# Ljung-Box (Q):                       47.58   Jarque-Bera (JB):                 9.59
# Prob(Q):                              0.19   Prob(JB):                         0.01
# Heteroskedasticity (H):               0.80   Skew:                            -0.26
# Prob(H) (two-sided):                  0.32   Kurtosis:                         3.79
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                      Accidents_Qns   No. Observations:                  362
# Model:             SARIMAX(1, 0, 1)x(0, 1, 1, 52)   Log Likelihood                -987.214
# Date:                            Tue, 16 Feb 2021   AIC                           1984.428
# Time:                                    12:39:09   BIC                           2002.154
# Sample:                                07-01-2012   HQIC                          1991.557
#                                      - 06-02-2019
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Holiday       -8.6574      2.310     -3.749      0.000     -13.184      -4.131
# ar.L1          0.9960      0.004    233.256      0.000       0.988       1.004
# ma.L1         -0.8712      0.034    -25.703      0.000      -0.938      -0.805
# ma.S.L52      -0.8299      0.125     -6.628      0.000      -1.075      -0.584
# sigma2       116.6743     12.735      9.162      0.000      91.715     141.634
# ===================================================================================
# Ljung-Box (Q):                       47.59   Jarque-Bera (JB):                10.21
# Prob(Q):                              0.19   Prob(JB):                         0.01
# Heteroskedasticity (H):               0.80   Skew:                            -0.26
# Prob(H) (two-sided):                  0.30   Kurtosis:                         3.83
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                      Accidents_Qns   No. Observations:                  362
# Model:             SARIMAX(1, 0, 1)x(1, 1, 1, 52)   Log Likelihood                -987.194
# Date:                            Tue, 16 Feb 2021   AIC                           1986.389
# Time:                                    12:39:42   BIC                           2007.660
# Sample:                                07-01-2012   HQIC                          1994.944
#                                      - 06-02-2019
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Holiday       -8.6577      2.320     -3.732      0.000     -13.205      -4.111
# ar.L1          0.9960      0.004    233.984      0.000       0.988       1.004
# ma.L1         -0.8715      0.034    -25.348      0.000      -0.939      -0.804
# ar.S.L52      -0.0015      0.024     -0.064      0.949      -0.048       0.045
# ma.S.L52      -0.8301      0.126     -6.601      0.000      -1.077      -0.584
# sigma2       116.7231     12.885      9.059      0.000      91.468     141.978
# ===================================================================================
# Ljung-Box (Q):                       47.63   Jarque-Bera (JB):                10.18
# Prob(Q):                              0.19   Prob(JB):                         0.01
# Heteroskedasticity (H):               0.80   Skew:                            -0.26
# Prob(H) (two-sided):                  0.30   Kurtosis:                         3.82
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                      Accidents_Qns   No. Observations:                  362
# Model:             SARIMAX(0, 1, 1)x(1, 1, 1, 52)   Log Likelihood                -990.702
# Date:                            Tue, 16 Feb 2021   AIC                           1991.405
# Time:                                    12:39:53   BIC                           2009.111
# Sample:                                07-01-2012   HQIC                          1998.527
#                                      - 06-02-2019
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Holiday       -8.5620      2.403     -3.564      0.000     -13.271      -3.853
# ma.L1         -0.8545      0.035    -24.416      0.000      -0.923      -0.786
# ar.S.L52      -0.2537      0.083     -3.065      0.002      -0.416      -0.092
# ma.S.L52      -0.5923      0.114     -5.206      0.000      -0.815      -0.369
# sigma2       127.2477     10.640     11.959      0.000     106.393     148.102
# ===================================================================================
# Ljung-Box (Q):                       45.93   Jarque-Bera (JB):                10.20
# Prob(Q):                              0.24   Prob(JB):                         0.01
# Heteroskedasticity (H):               0.74   Skew:                            -0.21
# Prob(H) (two-sided):                  0.17   Kurtosis:                         3.89
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                       Accidents_Qns   No. Observations:                  362
# Model:             SARIMAX(1, 1, 1)x(1, 1, [], 52)   Log Likelihood               -1005.539
# Date:                             Tue, 16 Feb 2021   AIC                           2021.078
# Time:                                     12:40:04   BIC                           2038.804
# Sample:                                 07-01-2012   HQIC                          2028.207
#                                       - 06-02-2019
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Holiday       -6.4945      2.868     -2.264      0.024     -12.116      -0.873
# ar.L1          0.1731      0.068      2.557      0.011       0.040       0.306
# ma.L1         -0.9099      0.034    -26.822      0.000      -0.976      -0.843
# ar.S.L52      -0.5113      0.048    -10.729      0.000      -0.605      -0.418
# sigma2       150.5106     11.889     12.659      0.000     127.208     173.813
# ===================================================================================
# Ljung-Box (Q):                       42.54   Jarque-Bera (JB):                 7.43
# Prob(Q):                              0.36   Prob(JB):                         0.02
# Heteroskedasticity (H):               0.79   Skew:                            -0.28
# Prob(H) (two-sided):                  0.28   Kurtosis:                         3.62
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                       Accidents_Qns   No. Observations:                  362
# Model:             SARIMAX(0, 1, 1)x(1, 1, [], 52)   Log Likelihood               -1013.008
# Date:                             Tue, 16 Feb 2021   AIC                           2034.015
# Time:                                     12:40:14   BIC                           2048.212
# Sample:                                 07-01-2012   HQIC                          2039.724
#                                       - 06-02-2019
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Holiday       -7.5432      3.076     -2.452      0.014     -13.572      -1.514
# ma.L1         -0.8706      0.032    -27.219      0.000      -0.933      -0.808
# ar.S.L52      -0.5079      0.046    -10.989      0.000      -0.599      -0.417
# sigma2       154.4575     12.403     12.454      0.000     130.149     178.766
# ===================================================================================
# Ljung-Box (Q):                       52.20   Jarque-Bera (JB):                 6.75
# Prob(Q):                              0.09   Prob(JB):                         0.03
# Heteroskedasticity (H):               0.80   Skew:                            -0.30
# Prob(H) (two-sided):                  0.31   Kurtosis:                         3.52
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                       Accidents_Qns   No. Observations:                  362
# Model:             SARIMAX(1, 0, 1)x(1, 1, [], 52)   Log Likelihood               -1012.668
# Date:                             Tue, 16 Feb 2021   AIC                           2035.336
# Time:                                     12:40:27   BIC                           2053.081
# Sample:                                 07-01-2012   HQIC                          2042.472
#                                       - 06-02-2019
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Holiday       -7.5429      3.089     -2.441      0.015     -13.598      -1.488
# ar.L1          0.9927      0.007    134.880      0.000       0.978       1.007
# ma.L1         -0.8615      0.035    -24.469      0.000      -0.931      -0.793
# ar.S.L52      -0.5077      0.046    -10.966      0.000      -0.598      -0.417
# sigma2       153.8925     12.774     12.047      0.000     128.856     178.929
# ===================================================================================
# Ljung-Box (Q):                       51.93   Jarque-Bera (JB):                 6.50
# Prob(Q):                              0.10   Prob(JB):                         0.04
# Heteroskedasticity (H):               0.80   Skew:                            -0.29
# Prob(H) (two-sided):                  0.30   Kurtosis:                         3.52
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                        Accidents_Qns   No. Observations:                  362
# Model:             SARIMAX(1, 1, 0)x(0, 1, [1], 52)   Log Likelihood               -1016.867
# Date:                              Tue, 16 Feb 2021   AIC                           2041.734
# Time:                                      12:40:34   BIC                           2055.915
# Sample:                                  07-01-2012   HQIC                          2047.438
#                                        - 06-02-2019
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Holiday       -9.1571      1.926     -4.754      0.000     -12.932      -5.382
# ar.L1         -0.4332      0.046     -9.480      0.000      -0.523      -0.344
# ma.S.L52      -0.8753      0.167     -5.242      0.000      -1.203      -0.548
# sigma2       142.8557     20.605      6.933      0.000     102.470     183.242
# ===================================================================================
# Ljung-Box (Q):                       77.85   Jarque-Bera (JB):                14.65
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.75   Skew:                            -0.28
# Prob(H) (two-sided):                  0.18   Kurtosis:                         4.03
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# Based on the above, we see that the following parameters have significant p values:
#
# (1,1,1) x (0,1,1,52)
#
# (0,1,1) x (0,1,1,52)
#
# (1,0,1) x (0,1,1,52)
#
# (0,1,1) x (1,1,1,52)
#
# (1,1,1) x (1,1,0,52)
#
# (0,1,1) x (1,1,0,52)
#
# (1,0,1) x (1,1,0,52)
#
# (1,1,0) x (0,1,1,52)

# %% [markdown]
# We will observe these models' RMSE and AIC score to determine which is our best SARIMAX model.

# %% [markdown]
# **Determine Best SARIMAX Model**

# %%
# For loop to apply RMSE function to significant parameters
for (pdq,pdqs) in [((1,1,1),(0,1,1,52)),((0,1,1),(0,1,1,52)),((1,0,1),(0,1,1,52)),((0,1,1),(1,1,1,52)),
                   ((1,1,1),(1,1,0,52)),((0,1,1),(1,1,0,52)),((1,0,1),(1,1,0,52)),((1,1,0),(0,1,1,52))]:
    mod = sm.tsa.statespace.SARIMAX(y_train,
                                    exog = train.iloc[:,1],
                                    order=pdq,
                                    seasonal_order=pdqs,
                                    enforce_stationarity=False,
                                    enforce_invertibility=False)
    mod_fit = mod.fit()
    mod_pred = mod_fit.predict(start='2019-06-06', end='2020-03-13', exog = test.iloc[:,1],
                               dynamic=False)
    print(pdq, 'x', pdqs,': RMSE: ', RMSE(mod_pred), 'AIC: ', mod_fit.aic)
# Out:
# (1, 1, 1) x (0, 1, 1, 52) : RMSE:  19.876333405133344 AIC:  1973.9349210655687
# (0, 1, 1) x (0, 1, 1, 52) : RMSE:  19.325743113563387 AIC:  1976.4539546842107
# (1, 0, 1) x (0, 1, 1, 52) : RMSE:  17.847052418581935 AIC:  1984.427881877276
# (0, 1, 1) x (1, 1, 1, 52) : RMSE:  20.044045897044363 AIC:  1991.404634206007
# (1, 1, 1) x (1, 1, 0, 52) : RMSE:  17.275526581528958 AIC:  2021.0779201808887
# (0, 1, 1) x (1, 1, 0, 52) : RMSE:  16.818416573841045 AIC:  2034.0154079522254
# (1, 0, 1) x (1, 1, 0, 52) : RMSE:  17.240991547849394 AIC:  2035.3356490249398
# (1, 1, 0) x (0, 1, 1, 52) : RMSE:  17.89428136864754 AIC:  2041.7342034728658

# %% [markdown]
# Based on the above, parameters (0,1,1) x (1,1,0,52) yield our best SARIMAX model. It has the best RMSE/AIC combination, prioritizing RMSE.
#
# Now we will define this as our SARIMAX model and compare to our SARIMA and ARIMA models.

# %%
SARIMAX = sm.tsa.statespace.SARIMAX(y_train,
                                    exog = train.iloc[:,1],
                                    order=(0,1,1),
                                    seasonal_order=(1,1,0,52),
                                    enforce_stationarity=False,
                                    enforce_invertibility=False)
SARIMAX_fit = SARIMAX.fit()
SARIMAX_pred = SARIMAX_fit.predict(start='2019-06-06', end='2020-03-13', exog = test.iloc[:,1],
                                   dynamic=False)

SARIMAX_RMSE = RMSE(SARIMAX_pred)
SARIMAX_adj_RMSE = SARIMAX_RMSE/(df_qns_wk_mean['Accidents_Qns'].max()-df_qns_wk_mean['Accidents_Qns'].min())
SARIMAX_AIC = SARIMAX_fit.aic


print('ARIMA RMSE: ', base_RMSE)
print('Adjusted ARIMA RMSE: ',
      base_RMSE/(df_qns['Accidents_Qns'].max()-df_qns['Accidents_Qns'].min()))
print('ARIMA AIC: ', base_AIC)

print('SARIMA RMSE: ', RMSE(SARIMA_pred))
print('Adjusted SARIMA RMSE: ',
      RMSE(SARIMA_pred)/(df_qns_wk_mean['Accidents_Qns'].max()-df_qns_wk_mean['Accidents_Qns'].min()))
print('SARIMA AIC: ', SARIMA_fit.aic)

print('SARIMAX RMSE: ', SARIMAX_RMSE)
print('Adjusted SARIMAX RMSE: ', SARIMAX_adj_RMSE)
print('SARIMAX AIC: ', SARIMAX_AIC)
# Out:
# ARIMA RMSE:  29.630639592651963
# Adjusted ARIMA RMSE:  0.11223727118428774
# ARIMA AIC:  23436.562817326376
# SARIMA RMSE:  17.083026657380817
# Adjusted SARIMA RMSE:  0.146905634645781
# SARIMA AIC:  2041.1332231735153
# SARIMAX RMSE:  16.818416573841045
# Adjusted SARIMAX RMSE:  0.14463011795686403
# SARIMAX AIC:  2034.0154079522254

# %% [markdown]
# We see from the above that our SARIMAX model is better than our SARIMA model, both in terms of RMSE and AIC. Between our ARIMA and SARIMAX models, our ARIMA model is more useful for the following reasons:
#
# - Although its RMSE is higher, its adjusted RMSE is lower, albeit very slightly.
# - Although its AIC score is significantly higher, we cannot compare AIC scores between these two different types of models. This metric is more useful when comparing parameter options within the same model type.
# - Based on how our model will be used, it is much more useful to know how many accidents are predicted per day rather than by week. This applies to individuals assessing their own risk as well as officials allocating resources on a daily basis rather than weekly basis.

# %% [markdown]
# **Of our models until this point, the baseline ARIMA model is our best model**

# %% [markdown]
# # Final Model Analysis

# %% [markdown]
# Now that we have determined our best model based on RMSE and AIC, let's dig into it a bit more deeply.

# %% [markdown]
# **Model Metrics**

# %%
# Visualize residuals/error
residuals = pd.DataFrame(base_fit.resid)
residuals.plot(color='royalblue')
plt.show();

# %%
# Check for linearity
residuals = pd.DataFrame(base_fit.resid)
residuals.plot(kind='kde', color='royalblue')
plt.show()

# %% [markdown]
# Based on the first graph above, we see residuals centered and concentrated at 0, though with more variance than is ideal. With a mean at approximately 0, the second graph shows that our model is mostly linear.

# %% [markdown]
# **Test Predictions**

# %% [markdown]
# We know that this ARIMA model yielded our best test predictions from its RMSE and AIC score, but let's visualize our predictions compared to the true data.

# %%
# Plot real vs predicted values
fix,ax = plt.subplots(figsize=(15, 8))

# Plot observed values
ax = df_qns['Accidents_Qns'].plot(label='Observed', color='sandybrown')

# Plot predicted train values
base_pred_train = base_fit.predict(start='2012-07-01', end='2020-03-13', dynamic=False)
base_pred_train.plot(ax=ax, label='Train Predictions', alpha=0.9, color='purple')

# Plot predicted values
base_pred.plot(ax=ax, label='Test Predictions', alpha=0.9, color='mediumseagreen')

# Set axes labels and title
ax.set_xlabel('Year', size=12)
ax.set_ylabel('Car Accidents',size=12)
ax.set_title('Real vs Predicted Queens Car Accidents,', size=15)

plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7c271ca8bf1d> in <module>
#       1 # Plot real vs predicted values
# ----> 2 fix,ax = plt.subplots(figsize=(15, 8))
#       3
#       4 # Plot observed values
#       5 ax = df_qns['Accidents_Qns'].plot(label='Observed', color='sandybrown')
#
# NameError: name 'plt' is not defined

# %% [markdown]
# # Forecasting

# %% [markdown]
# Now that we see how our data performed on our train and test data, it is time to apply it to the future.

# %% [markdown]
# ## July 1, 2021 through the end of 2021

# %% [markdown]
# As discussed in the EDA notebook, we will use our current model to predict accident numbers starting on July 1, 2021, assuming a 25% decrease from our model predictions.

# %%
# Create df including all Queens data, not only pre-Covid like we've been using for modeling
df_qns_total = df_TS.drop(columns = ['Injuries', 'Deaths','Accidents_Bx', 'Accidents_Man', 'Accidents_Bkln', 'Accidents_SI',
                               'Accidents_Total'])

# %%
# Generate forcast from 3/14/20-12/31/2022
forecast = base_fit.forecast(steps=658)
pred_values = pd.DataFrame(forecast[0])
pred_values['Date'] = pd.date_range(start='2020-03-14', periods=658)
pred_values.set_index(pred_values['Date'],inplace=True)
pred_values = pred_values[0]
pred_values.drop(columns=['Date',0],inplace=True)
pred_values

# Plot forecast
fix,ax = plt.subplots(figsize=(15, 8))
ax = df_qns_total['Accidents_Qns']['2019-01-01':].plot(label='Observed', color='sandybrown')
pred_values.plot(ax=ax, label='Forecast',color='mediumseagreen')

ax.set_xlabel('Date')
ax.set_ylabel('Car Accidents')

plt.legend()
plt.show()

# %% [markdown]
# The above shows us what our predictions would have been through the end of 2021, if it hadn't been for the COVID-19 pandemic. Now let's look at what our actual predictions are, given what we do know about te pandemic and related predictions discussed earlier.

# %%
# Create df of adjusted COVID predictions
# Starting 7/1/21, 75% of original predictions
TS_pred_cov = pred_values['2021-07-01':] * 0.75

# Create linear data connecting last known data point and predicted data linearly
# Create df for connection data
connection = pd.DataFrame(pd.date_range(start='2021-01-30', end='2021-06-30'))
connection['Date'] = pd.DataFrame(pd.date_range(start='2021-01-30', end='2021-06-30'))

# Find how much the accident count will rise each day
# There are 152 days between 1/29/21 and 7/1/21
daily_interval=(TS_pred_cov['2021-07-01'] - df_qns_total['Accidents_Qns']['2021-01-29'])/152

# Add daily interval to each date in connection df
connection_forecasts = []
i = df_qns_total['Accidents_Qns']['2021-01-29']
for num in range(0,152):
    i+=daily_interval
    connection_forecasts.append(i)

# Add list of forecasts to connection df
connection['Forecast'] = connection_forecasts

# Make date index of connection df
connection.set_index('Date', inplace=True)
connection.drop(columns=0,inplace=True)

#Observe connection df
connection
# Out:
#               Forecast
# Date
# 2021-01-30   69.326673
# 2021-01-31   69.653347
# 2021-02-01   69.980020
# 2021-02-02   70.306693
# 2021-02-03   70.633367
# ...                ...
# 2021-06-26  117.347652
# 2021-06-27  117.674326
# 2021-06-28  118.000999
# 2021-06-29  118.327672
# 2021-06-30  118.654346
#
# [152 rows x 1 columns]

# %%
fix,ax = plt.subplots(figsize=(15, 8))

# Plot known data
ax = df_qns_total['Accidents_Qns']['2019-01-01':].plot(label='Observed', color='sandybrown')

# Plot predicted data based on model, starting 7/1/20, 75% of model prediction
TS_pred_cov.plot(ax=ax, label='Forecast',color='mediumseagreen')

# Plot linear connection
connection.plot(ax=ax, color='mediumseagreen')

ax.set_xlabel('Date')
ax.set_ylabel('Car Accidents')

plt.legend()
plt.show()

# %% [markdown]
# The above shows our best predictions for car accidents in Queens with an ARIMA-type model. In a separate notebook, we will create a Facebook Prophet model and compare it to this one.
